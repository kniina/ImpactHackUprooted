# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import requests as req
import json
from datetime import datetime, timedelta

pd.options.display.max_rows = 400

# %% [markdown]
# # Retrieve RW Metadata

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}
for ix, dset in enumerate(data):
    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }

# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %% [markdown]
# # Import, Format, Export data

# %% [markdown]
# ## Connecting refugee data with wri_bounds

# %%
refugees_csv = pd.read_csv('Refugees_CSV.csv').drop(["Year"], axis=1)
refugees_csv
# Out:
#                     Country of residence  \
# 0                                  Aruba
# 1                                  Aruba
# 2                                  Aruba
# 3                            Afghanistan
# 4                            Afghanistan
# 5                            Afghanistan
# 6                            Afghanistan
# 7                            Afghanistan
# 8                            Afghanistan
# 9                            Afghanistan
# 10                                Angola
# 11                                Angola
# 12                                Angola
# 13                                Angola
# 14                                Angola
# 15                                Angola
# 16                                Angola
# 17                                Angola
# 18                                Angola
# 19                                Angola
# 20                                Angola
# 21                                Angola
# 22                                Angola
# 23                                Angola
# 24                                Angola
# 25                                Angola
# 26                                Angola
# 27                                Angola
# 28                                Angola
# 29                                Angola
# 30                                Angola
# 31                                Angola
# 32                                Angola
# 33                                Angola
# 34                                Angola
# 35                                Angola
# 36                                Angola
# 37                                Angola
# 38                                Angola
# 39                                Angola
# 40                                Angola
# 41                                Angola
# 42                                Angola
# 43                                Angola
# 44                                Angola
# 45                                Angola
# 46                              Anguilla
# 47                               Albania
# 48                               Albania
# 49                               Albania
# 50                               Albania
# 51                               Albania
# 52                               Albania
# 53                               Albania
# 54                               Albania
# 55                               Albania
# 56                               Albania
# 57                               Albania
# 58                               Albania
# 59                               Albania
# 60                               Albania
# 61                               Albania
# 62                               Albania
# 63                               Albania
# 64                               Albania
# 65                               Albania
# 66                               Albania
# 67                               Albania
# 68                               Albania
# 7064                               Yemen
# 7065                               Yemen
# 7066                               Yemen
# 7067                               Yemen
# 7068                               Yemen
# 7069                               Yemen
# 7070                               Yemen
# 7071                               Yemen
# 7072                        South Africa
# 7073                        South Africa
# 7074                        South Africa
# 7075                        South Africa
# 7076                        South Africa
# 7077                        South Africa
# 7078                        South Africa
# 7079                        South Africa
# 7080                        South Africa
# 7081                        South Africa
# 7082                        South Africa
# 7083                        South Africa
# 7084                        South Africa
# 7085                        South Africa
# 7086                        South Africa
# 7087                        South Africa
# 7088                        South Africa
# 7089                        South Africa
# 7090                        South Africa
# 7091                        South Africa
# 7092                        South Africa
# 7093                        South Africa
# 7094                        South Africa
# 7095                        South Africa
# 7096                        South Africa
# 7097                        South Africa
# 7098                        South Africa
# 7099                        South Africa
# 7100                        South Africa
# 7101                        South Africa
# 7102                        South Africa
# 7103                              Zambia
# 7104                              Zambia
# 7105                              Zambia
# 7106                              Zambia
# 7107                              Zambia
# 7108                              Zambia
# 7109                              Zambia
# 7110                              Zambia
# 7111                              Zambia
# 7112                              Zambia
# 7113                              Zambia
# 7114                              Zambia
# 7115                              Zambia
# 7116                              Zambia
# 7117                              Zambia
# 7118                              Zambia
# 7119                              Zambia
# 7120                              Zambia
# 7121                              Zambia
# 7122                              Zambia
# 7123                              Zambia
# 7124                            Zimbabwe
# 7125                            Zimbabwe
# 7126                            Zimbabwe
# 7127                            Zimbabwe
# 7128                            Zimbabwe
# 7129                            Zimbabwe
# 7130                            Zimbabwe
# 7131                            Zimbabwe
# 7132                            Zimbabwe
# 7133                            Zimbabwe
# 7134                            Zimbabwe
# 7135                            Zimbabwe
# 7136                            Zimbabwe
# 7137                            Zimbabwe
# 7138                            Zimbabwe
# 7139                            Zimbabwe
# 7140                            Zimbabwe
# 7141                            Zimbabwe
# 7142                            Zimbabwe
# 7143                            Zimbabwe
# 7144                            Zimbabwe
# 7145                            Zimbabwe
# 7146                            Zimbabwe
# 7147                            Zimbabwe
#
#                                         Country Refugee  Refugees
# 0                                      Colombia       0         0
# 1                                          Cuba       *         0
# 2            Venezuela (Bolivarian Republic of)       0         0
# 3                                   Afghanistan       0         0
# 4                        Iran (Islamic Rep. of)      34        34
# 5                                          Iraq       *         0
# 6                                      Pakistan   75893     75893
# 7                                    Tajikistan       0         0
# 8                                        Turkey       0         0
# 9                                    Uzbekistan       0         0
# 10                                  Afghanistan       0         0
# 11                                      Burundi       9         9
# 12                         Central African Rep.       9         9
# 13                                Cote d'Ivoire     510       510
# 14                                     Cameroon       *         0
# 15                       Dem. Rep. of the Congo   38516     38516
# 16                                        Congo       *         0
# 17                                     Djibouti       0         0
# 18                                      Algeria       *         0
# 19                                      Eritrea      34        34
# 20                               Western Sahara      18        18
# 21                                     Ethiopia       *         0
# 22                                       Guinea     107       107
# 23                                       Gambia       0         0
# 24                                Guinea-Bissau       *         0
# 25                                        Haiti       *         0
# 26                                         Iraq       0         0
# 27                                      Liberia     155       155
# 28                                        Libya       *         0
# 29                                         Mali       *         0
# 7132                                    Eritrea      20        20
# 7133                                   Ethiopia      68        68
# 7134                                      Ghana       0         0
# 7135                                      Kenya       0         0
# 7136                                    Lebanon       *         0
# 7137                                       Mali       *         0
# 7138                                 Mozambique       0         0
# 7139                                     Rwanda     500       500
# 7140                                      Sudan       5         5
# 7141                                    Somalia      19        19
# 7142                                   Slovenia       *         0
# 7143                           Syrian Arab Rep.       0         0
# 7144                                     Uganda       8         8
# 7145                               South Africa       *         0
# 7146                                     Zambia       0         0
# 7147                                   Zimbabwe       0         0
#
# [7148 rows x 4 columns]

# %%
refugees = refugees_csv.groupby("Country").sum().reset_index()

#refugees["Country"][0].type()

refugees_list = refugees["Refugees"].astype(list)
countries_list = refugees["Country"]

refugees_df = pd.DataFrame({"Country": refugees["Country"], "Refugees": refugees_list}).set_index("Country")
refugees = refugees.set_index("Country")

print(type(refugees_df["Refugees"][0]))
refugees_df
# Out:
# <class 'int'>
#                                           Refugees
# Country
# Afghanistan                                2624225
# Albania                                      12163
# Algeria                                       3991
# American Samoa                                   0
# Andorra                                          0
# Angola                                        8267
# Antigua and Barbuda                             94
# Argentina                                      111
# Armenia                                      10766
# Australia                                        0
# Austria                                          0
# Azerbaijan                                   10878
# Bahamas                                        373
# Bahrain                                        487
# Bangladesh                                   16755
# Barbados                                       167
# Belarus                                       3635
# Belgium                                         52
# Belize                                          59
# Benin                                          557
# Bhutan                                        7929
# Bolivia (Plurinational State of)               505
# Bosnia and Herzegovina                       17669
# Botswana                                       279
# Brazil                                         836
# Brunei Darussalam                                0
# Bulgaria                                       716
# Burkina Faso                                  2679
# Burundi                                     439280
# Cabo Verde                                       0
# Cambodia                                     12213
# Cameroon                                     10982
# Canada                                          75
# Cayman Islands                                   6
# Central African Rep.                        545498
# Chad                                         16295
# Chile                                          483
# China                                       207691
# China, Hong Kong SAR                             6
# China, Macao SAR                                 0
# Colombia                                    191607
# Comoros                                        575
# Congo                                        13225
# Cook Islands                                     0
# Costa Rica                                     190
# Cote d'Ivoire                                39939
# Croatia                                      24859
# Cuba                                          5316
# Curaçao                                         35
# Cyprus                                           0
# Czech Rep.                                    1272
# Dem. People's Rep. of Korea                   1161
# Dem. Rep. of the Congo                      620775
# Denmark                                          0
# Djibouti                                      1741
# Dominica                                        26
# Dominican Rep.                                 412
# Ecuador                                       1236
# Egypt                                        22056
# El Salvador                                  25861
# Equatorial Guinea                              122
# Eritrea                                     486169
# Estonia                                        278
# Ethiopia                                     87388
# Fiji                                           734
# Finland                                          0
# France                                          49
# French Guiana                                    0
# Gabon                                          211
# Gambia                                       14539
# Georgia                                       6485
# Germany                                         66
# Ghana                                        16929
# Gibraltar                                        0
# Greece                                         101
# Grenada                                        103
# Guadeloupe                                       0
# Guam                                             0
# Guatemala                                    16274
# Guinea                                       20313
# Guinea-Bissau                                 1855
# Guyana                                         255
# Haiti                                        28414
# Honduras                                     14404
# Hungary                                       3331
# Iceland                                          0
# India                                         7891
# Indonesia                                    12480
# Iran (Islamic Rep. of)                      118595
# Palau                                             0
# Palestinian                                   99585
# Panama                                           31
# Papua New Guinea                                396
# Paraguay                                         62
# Peru                                           2578
# Philippines                                     433
# Poland                                         1108
# Portugal                                          6
# Puerto Rico                                       0
# Qatar                                            31
# Rep. of Korea                                   234
# Rep. of Moldova                                2314
# Romania                                        1200
# Russian Federation                            61569
# Rwanda                                       258956
# Saint Kitts and Nevis                            46
# Saint Lucia                                     995
# Saint Vincent and the Grenadines               1301
# Saint-Pierre-et-Miquelon                          0
# Samoa                                             0
# San Marino                                        0
# Sao Tome and Principe                            26
# Saudi Arabia                                   1169
# Senegal                                       26559
# Serbia and Kosovo (S/RES/1244 (1999))         35072
# Seychelles                                        5
# Sierra Leone                                   4436
# Singapore                                        43
# Slovakia                                        913
# Slovenia                                          7
# Solomon Islands                                  57
# Somalia                                      986356
# South Africa                                    446
# South Sudan                                 2439868
# Spain                                            34
# Sri Lanka                                    115612
# Stateless                                     53342
# Sudan                                        694506
# Suriname                                         17
# Swaziland                                       221
# Sweden                                           14
# Switzerland                                       0
# Syrian Arab Rep.                            6308619
# Tajikistan                                     1354
# Thailand                                        154
# The former Yugoslav Republic of Macedonia      1633
# Tibetan                                       13531
# Timor-Leste                                       8
# Togo                                           8100
# Tonga                                            34
# Trinidad and Tobago                             310
# Tunisia                                        1806
# Turkey                                        61338
# Turkmenistan                                    340
# Turks and Caicos Islands                         14
# Tuvalu                                            0
# Uganda                                         6369
# Ukraine                                      139561
# United Arab Emirates                            132
# United Kingdom                                   85
# United Rep. of Tanzania                         630
# United States of America                        285
# Uruguay                                           7
# Uzbekistan                                     3380
# Vanuatu                                           0
# Various/Unknown                              202185
# Venezuela (Bolivarian Republic of)             9247
# Viet Nam                                     334044
# Western Sahara                               116758
# Yemen                                         23500
# Zambia                                          250
# Zimbabwe                                      17390

# %%
bounds = req.get('https://raw.githubusercontent.com/wri/wri-bounds/master/dist/all_primary_countries.geojson').json()

# %%
for ix, cntry in enumerate(bounds['features']):
    name = cntry['properties']['name']
    if name not in refugees_df.index:
        print(name)
        new_name = input('What should new name be?')
        if new_name: 
            bounds['features'][ix]['properties']['name'] = new_name
            bounds['features'][ix]['properties']['Refugees'] = refugees_df.loc[new_name, 'Refugees']
            print(type(refugees_df.loc[new_name, 'Refugees']))
            
        else:
            print('no data')
            bounds['features'][ix]['properties']['Refugees'] = None
    else:
        bounds['features'][ix]['properties']['Refugees'] = refugees.loc[name, 'Refugees']
# Out:
# The Bahamas
# What should new name be?Bahamas
# <class 'int'>
# Bolivia
# What should new name be?k
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [k] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-0d2871c1e5e3> in <module>()
#       6         if new_name:
#       7             bounds['features'][ix]['properties']['name'] = new_name
# ----> 8             bounds['features'][ix]['properties']['Refugees'] = refugees_df.loc[new_name, 'Refugees']
#       9             print(type(refugees_df.loc[new_name, 'Refugees']))
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     856     def _getitem_tuple(self, tup):
#     857         try:
# --> 858             return self._getitem_lowerdim(tup)
#     859         except IndexingError:
#     860             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     989         for i, key in enumerate(tup):
#     990             if is_label_like(key) or isinstance(key, tuple):
# --> 991                 section = self._getitem_axis(key, axis=i)
#     992
#     993                 # we have yielded a scalar ?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625         # fall thru to straight lookup
# -> 1626         self._has_valid_type(key, axis)
#    1627         return self._get_label(key, axis=axis)
#    1628
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1512                 raise
#    1513             except:
# -> 1514                 error()
#    1515
#    1516         return True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1499                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#    1503             try:
#
# KeyError: 'the label [k] is not in the [index]'

# %%
#for ix, cntry in enumerate(bounds['features']):
   # name = cntry['properties']['name']
   # bounds['features'][ix]['properties']['Refugees'] = bounds['features'][ix]['properties']['Refugees'].astype(int)

# %%
json.dump(bounds, open('bounds_with_refugee_counts.geojson','w'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-64b1f7c9b7b9> in <module>()
# ----> 1 json.dump(bounds, open('bounds_with_refugee_counts.geojson','w'))
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
# --> 430             yield from _iterencode_dict(o, _current_indent_level)
#     431         else:
#     432             if markers is not None:
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'int64' is not JSON serializable

# %% [markdown]
# ## Creating data frame for scatter plots

# %%
refugees = refugees.reset_index()
refugees

# %% [markdown]
# ### Water Stress

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {}"
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

today = datetime.today()
five_years_ago = today - timedelta(days=360*5)
cutoff = datetime.strftime(five_years_ago, DT_FORMAT)

#[ds for ds in current_datasets_on_api.index if 'stress' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'stress' in ds.lower()][0]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

#query_sql = sql.format(table_name, cutoff)
query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()
water_stress = pd.DataFrame(res['data'])

# %%
water_stress = water_stress[['all_sectors', 'name']]

# %% [markdown]
# ### GDP

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {} WHERE year = 2015"
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

#[ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()][0]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()

gdp = pd.DataFrame(res['data'])

# %%
gdp = gdp[['rw_country_code', 'rw_country_name', 'yr_data']]

# %% [markdown]
# ### Political Freedoms Index

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {} "
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

#[ds for ds in current_datasets_on_api.index if 'political' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'political' in ds.lower()][1]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()

political_freedoms = pd.DataFrame(res['data'])

# %%
political_freedoms = political_freedoms[['rw_country_code', 'rw_country_name', 'total_aggr']]

# %% [markdown]
# ## Joined

# %%
tmp = political_freedoms.merge(gdp, left_on='rw_country_code', right_on='rw_country_code')

# %%
aliases = tmp[['rw_country_code', 'rw_country_name_x']]
aliases.columns = ['code', 'name']

# %%
water_stress
# Out:
#      all_sectors                              name
# 0       5.000000               Antigua and Barbuda
# 98      1.362974                          Botswana
# 99      1.351786                       New Zealand
# 100     1.347722                            Belize
# 101     1.327988                             Egypt
# 102     1.307267                            Poland
# 103     1.304243                            Sweden
# 104     1.288331                            Kosovo
# 105     1.265798                          Bulgaria
# 106     1.247566                        Madagascar
# 107     1.234853                            Russia
# 108     1.205767                            Canada
# 109     1.193841                         Lithuania
# 110     1.134583                    Czech Republic
# 111     1.064087                       Switzerland
# 112     1.010346                         Guatemala
# 113     1.010016                         Nicaragua
# 114     1.008669                           Vietnam
# 115     0.982449                           Finland
# 116     0.952931                           Denmark
# 117     0.914442                            Brazil
# 118     0.912859                             Sudan
# 119     0.863199                           Uruguay
# 120     0.835612                           Romania
# 121     0.824087                        Mozambique
# 122     0.682812                             Kenya
# 123     0.677155                           Bolivia
# 124     0.647534                        Bangladesh
# 125     0.640418                          Zimbabwe
# 126     0.611777                          Ethiopia
# 127     0.604109                        Mauritania
# 128     0.596268                  Papua New Guinea
# 129     0.591421                           Belarus
# 130     0.583519                Republic of Serbia
# 131     0.536396                 Equatorial Guinea
# 132     0.522389                              Chad
# 133     0.508071                      Sierra Leone
# 134     0.494865                           Hungary
# 135     0.462063                     Liechtenstein
# 136     0.455283                           Somalia
# 137     0.450202                            Bhutan
# 138     0.442281                          Cambodia
# 139     0.427577             Republic of the Congo
# 140     0.422003                            Panama
# 141     0.416834                            Gambia
# 142     0.400525                            Norway
# 143     0.351614                            Latvia
# 144     0.327354                          Colombia
# 145     0.322036                           Austria
# 146     0.308811                        Montenegro
# 147     0.303092                           Myanmar
# 148     0.293372                           Nigeria
# 149     0.273278                           Liberia
# 150     0.253345                          Suriname
# 151     0.214814                           Senegal
# 152     0.204415                              Mali
# 153     0.197466                          Slovakia
# 154     0.166058                     Guinea Bissau
# 155     0.136670                           Iceland
# 156     0.120468                              Togo
# 157     0.112431                             Niger
# 158     0.108840                             Ghana
# 159     0.107044                          Cameroon
# 160     0.105264                            Malawi
# 161     0.102101                            Taiwan
# 162     0.077685                            Zambia
# 163     0.068148                          Honduras
# 164     0.058242                            Guinea
# 165     0.044008                       Ivory Coast
# 166     0.027711                          Slovenia
# 167     0.019933            Bosnia and Herzegovina
# 168     0.017394                           Croatia
# 169     0.014155                              Laos
# 170     0.011150                          Paraguay
# 171     0.008372                            Brunei
# 172     0.006046  Democratic Republic of the Congo
# 173     0.000343                            Uganda
# 174     0.000004                      Burkina Faso
# 175     0.000000                             Benin
# 176     0.000000                           Burundi
# 177     0.000000          Central African Republic
# 178     0.000000                            Rwanda
# 179     0.000000                       South Sudan
# 180     0.000000                        Cape Verde
# 181     0.000000                           Curacao
# 182     0.000000    Federated States of Micronesia
# 183     0.000000                              Fiji
# 184     0.000000                           Grenada
# 185     0.000000                          Kiribati
# 186     0.000000                          Maldives
# 187     0.000000                  Marshall Islands
# 188     0.000000                         Mauritius
# 189     0.000000                             Nauru
# 190     0.000000                             Palau
# 191     0.000000             Saint Kitts and Nevis
# 192     0.000000                             Samoa
# 193     0.000000             Sao Tome and Principe
# 194     0.000000                        Seychelles
# 195     0.000000                   Solomon Islands
# 196     0.000000                       The Bahamas
# 197     0.000000                             Tonga
# 198     0.000000                            Tuvalu
# 199     0.000000                           Vanuatu

# %%
def find_rw_country_code(name, aliases):
    if name in aliases['name'].values:
        code = aliases.loc[aliases['name'].isin([name]), 'code'].values[0]
        return code
    else:
        print(name)
        code = input("Country Code?")
        if code:
            return code
        else:
            return None
    
water_stress['rw_country_code'] = water_stress.apply(lambda row: find_rw_country_code(row['name'], aliases), axis = 1)
water_stress
# Out:
# Western Sahara
# Country Code?8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-050b99ca3616> in <module>()
#      11             return None
#      12
# ---> 13 water_stress['rw_country_code'] = water_stress.apply(lambda row: find_rw_country_code(row['name'], aliases), axis = 1)
#      14 water_stress
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4931                     labels = self._get_agg_axis(axis)
#    4932                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4933                                         labels=labels)
#    4934                     return Series(result, index=labels)
#    4935                 except Exception:
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.reduce()
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.Reducer.get_result()
#
# <ipython-input-57-050b99ca3616> in <lambda>(row)
#      11             return None
#      12
# ---> 13 water_stress['rw_country_code'] = water_stress.apply(lambda row: find_rw_country_code(row['name'], aliases), axis = 1)
#      14 water_stress
#
# <ipython-input-57-050b99ca3616> in find_rw_country_code(name, aliases)
#       5     else:
#       6         print(name)
# ----> 7         code = input("Country Code?")
#       8         if code:
#       9             return code
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
tmp = tmp.merge(water_stress, left_on='rw_country_code', right_on='rw_country_code')
tmp

# %%
refugees['rw_country_code'] = refugees.apply(lambda row: find_rw_country_code(row['Country'], aliases), axis = 1)

# %%
tmp = tmp.merge(refugees, left_on='rw_country_code', right_on='rw_country_code')

# %%
tmp = tmp.drop(['rw_country_name_y', 'name', 'Country'], axis=1)

# %%
tmp

# %%
final_data = tmp
final_data.columns = ['Country Code', 'Country Name', 'Political Freedoms Index', 'GDP', 'Water Stress, All Sectors', 'Number of Refugees from each Country to USA']
final_data = pd.melt(final_data, id_vars = ['Country Code', 'Country Name'], value_vars = ['Political Freedoms Index', 'GDP', 'Water Stress, All Sectors', 'Number of Refugees from each Country to USA'])
final_data.to_csv('scatterplotdata.csv')

# %%
final_data
