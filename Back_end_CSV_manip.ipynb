# %%
# !pip install pymongo

# %%
import pandas as pd
import numpy as np
import requests as req
import json
from pprint import pprint
from itertools import islice
#import pymongo

pd.options.display.max_rows = 400

# %%
full_df = pd.read_csv("All_COO_COD.csv", encoding='ISO-8859-1')
full_df.head()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Year Country / territory of asylum/residence           Origin  \
# 0  1951                               Australia  Various/Unknown
# 1  1951                                 Austria  Various/Unknown
# 2  1951                                 Belgium  Various/Unknown
# 3  1951                                  Canada  Various/Unknown
# 4  1951                             Switzerland  Various/Unknown
#
#                             Population type   Value
# 0  Refugees (incl. refugee-like situations)  180000
# 1  Refugees (incl. refugee-like situations)  282000
# 2  Refugees (incl. refugee-like situations)   55000
# 3  Refugees (incl. refugee-like situations)  168511
# 4  Refugees (incl. refugee-like situations)   10000

# %%
# Read in the full dataframe of origins and destinations
full_df = full_df.rename(columns={'Country / territory of asylum/residence':'Destination', 'Population type':'Type'})
full_df.head()
# Out:
#    Year  Destination           Origin  \
# 0  1951    Australia  Various/Unknown
# 1  1951      Austria  Various/Unknown
# 2  1951      Belgium  Various/Unknown
# 3  1951       Canada  Various/Unknown
# 4  1951  Switzerland  Various/Unknown
#
#                                        Type   Value
# 0  Refugees (incl. refugee-like situations)  180000
# 1  Refugees (incl. refugee-like situations)  282000
# 2  Refugees (incl. refugee-like situations)   55000
# 3  Refugees (incl. refugee-like situations)  168511
# 4  Refugees (incl. refugee-like situations)   10000

# %% [markdown]
# # Retrieve Resource Watch API Metadata

# %% [markdown]
# ### To get proper country codes

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}
for ix, dset in enumerate(data):
    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }

# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %% [markdown]
# ## Retrieve GDP Data from RW API

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {} WHERE year = 2015"
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

#[ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()][0]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()

gdp = pd.DataFrame(res['data'])

# %%
alias = gdp[['rw_country_code', 'rw_country_name']]

#temp_mrg = full_df.merge(gdp, left_on='Destination', right_on='rw_country_name')
#temp_mrg.head()
#temp_mrg['rw_country_code'].value_counts()
full_df.head()
full_df.describe()
# full_df has 197,665 rows
# Out:
#                 Year
# count  197665.000000
# mean     2008.078942
# std         7.734538
# min      1951.000000
# 25%      2004.000000
# 50%      2010.000000
# 75%      2014.000000
# max      2017.000000

# %%
def match_countries(name, alias):
    if name in alias['rw_country_name'].values:
        code = alias.loc[alias['rw_country_name'].isin([name]), 'rw_country_code'].values[0]
        return code
    else:
        print(name)
        code = input("Country Code? ")
        if code:
            return code
        else:
            return None

# %%
# Merge on Country of Destination

uq_names = full_df['Destination'].unique()
uq_names = pd.DataFrame(uq_names)
uq_names = uq_names.rename(columns={0:'country_name'})
uq_names.head()
# You need to make a unique() list from full_df... then get all the codes there, then merge to full_df on country_name

uq_names['dcode'] = uq_names.apply(lambda row: match_countries(row['country_name'], alias), axis=1)
uq_names
# Out:
# China, Hong Kong SAR
# Country Code? HKG
# Dem. Rep. of the Congo
# Country Code? COD
# United Rep. of Tanzania
# Country Code? TZA
# Iran (Islamic Rep. of)
# Country Code? IRN
# Central African Rep.
# Country Code? CAF
# China, Macao SAR
# Country Code? MAC
# Serbia and Kosovo (S/RES/1244 (1999))
# Country Code? SRB
# CÌ«te d'Ivoire
# Country Code? CIV
# Congo
# Country Code? COG
# Venezuela (Bolivarian Republic of)
# Country Code? VEN
# Dominican Rep.
# Country Code? DOM
# Viet Nam
# Country Code? VNM
# Bolivia (Plurinational State of)
# Country Code? BOL
# Lao People's Dem. Rep.
# Country Code? LAO
# Rep. of Korea
# Country Code? KOR
# Syrian Arab Rep.
# Country Code? SYR
# Guinea-Bissau
# Country Code? GNB
# French Guiana
# Country Code? GUF
# Cabo Verde
# Country Code? CPV
# Czech Rep.
# Country Code? CZE
# Bahamas
# Country Code? BHS
# The former Yugoslav Republic of Macedonia
# Country Code? MKD
# Russian Federation
# Country Code? RUS
# Rep. of Moldova
# Country Code? MDA
# Micronesia (Federated States of)
# Country Code? FSM
# Cayman Islands
# Country Code? CYM
# British Virgin Islands
# Country Code? VGB
# Aruba
# Country Code? ABW
# Bonaire
# Country Code? BES
# CuraÌ¤ao
# Country Code? CUW
# Montserrat
# Country Code? MSR
# Sint Maarten (Dutch part)
# Country Code? SXM
# Turks and Caicos Islands
# Country Code? TCA
# Brunei Darussalam
# Country Code? BRN
# Anguilla
# Country Code? AIA
# Dem. People's Rep. of Korea
# Country Code? PRK
#                                   country_name dcode
# 0                                    Australia   AUS
# 1                                      Austria   AUT
# 2                                      Belgium   BEL
# 3                                       Canada   CAN
# 4                                  Switzerland   CHE
# 5                                      Germany   DEU
# 6                                      Denmark   DNK
# 7                                        Spain   ESP
# 8                                       France   FRA
# 9                               United Kingdom   GBR
# 10                                      Greece   GRC
# 11                        China, Hong Kong SAR   HKG
# 12                                       Italy   ITA
# 13                                  Luxembourg   LUX
# 14                                     Morocco   MAR
# 15                                 Netherlands   NLD
# 16                                      Norway   NOR
# 17                                      Sweden   SWE
# 18                                     Tunisia   TUN
# 19                                      Turkey   TUR
# 20                    United States of America   USA
# 21                      Dem. Rep. of the Congo   COD
# 22                                     Burundi   BDI
# 23                                        Togo   TGO
# 24                     United Rep. of Tanzania   TZA
# 25                                      Uganda   UGA
# 26                      Iran (Islamic Rep. of)   IRN
# 27                                     Senegal   SEN
# 28                        Central African Rep.   CAF
# 29                                       Egypt   EGY
# 30                                       India   IND
# 31                                    Cambodia   KHM
# 32                                     Lebanon   LBN
# 33                            China, Macao SAR   MAC
# 34                                       Nepal   NPL
# 35                                      Rwanda   RWA
# 36       Serbia and Kosovo (S/RES/1244 (1999))   SRB
# 37                                      Zambia   ZMB
# 38                                      Bhutan   BTN
# 39                                       China   CHN
# 40                                 New Zealand   NZL
# 41                                       Sudan   SDN
# 42                        United Arab Emirates   ARE
# 43                                    Botswana   BWA
# 44                                      Cyprus   CYP
# 45                                    Ethiopia   ETH
# 46                           Equatorial Guinea   GNQ
# 47                                   Argentina   ARG
# 48                                       Benin   BEN
# 49                                      Brazil   BRA
# 50                                       Chile   CHL
# 51                              CÌ«te d'Ivoire   CIV
# 52                                       Congo   COG
# 53                                       Gabon   GAB
# 54                                       Ghana   GHA
# 55                                     Liberia   LBR
# 56                                    Paraguay   PRY
# 57                                Sierra Leone   SLE
# 58          Venezuela (Bolivarian Republic of)   VEN
# 59                                    Cameroon   CMR
# 60                                    Colombia   COL
# 61                              Dominican Rep.   DOM
# 62                                     Algeria   DZA
# 63                                       Kenya   KEN
# 64                                     Lesotho   LSO
# 65                                      Mexico   MEX
# 66                                        Peru   PER
# 67                                   Swaziland   SWZ
# 68                                     Uruguay   URY
# 69                                      Jordan   JOR
# 70                                        Mali   MLI
# 71                                    Viet Nam   VNM
# 72            Bolivia (Plurinational State of)   BOL
# 73                                  Costa Rica   CRI
# 74                                     Ecuador   ECU
# 75                                   Guatemala   GTM
# 76                                      Guyana   GUY
# 77                                    Honduras   HND
# 78                      Lao People's Dem. Rep.   LAO
# 79                                   Nicaragua   NIC
# 80                                      Panama   PAN
# 81                                 El Salvador   SLV
# 82                                     Bahrain   BHR
# 83                                        Cuba   CUB
# 84                                Saudi Arabia   SAU
# 85                                  Mozambique   MOZ
# 86                                 Philippines   PHL
# 87                                    Portugal   PRT
# 88                                    Thailand   THA
# 89                                      Angola   AGO
# 90                                     Nigeria   NGA
# 91                                    Djibouti   DJI
# 92                                       Japan   JPN
# 93                                    Malaysia   MYS
# 94                                       Niger   NER
# 95                                     Romania   ROU
# 96                                     Somalia   SOM
# 97                                       Yemen   YEM
# 98                                  Bangladesh   BGD
# 99                                   Indonesia   IDN
# 100                              Rep. of Korea   KOR
# 101                           Papua New Guinea   PNG
# 102                                  Singapore   SGP
# 103                           Syrian Arab Rep.   SYR
# 104                                       Iraq   IRQ
# 105                                     Kuwait   KWT
# 106                                   Pakistan   PAK
# 107                                     Belize   BLZ
# 108                                      Qatar   QAT
# 109                                   Zimbabwe   ZWE
# 110                              Guinea-Bissau   GNB
# 111                               Burkina Faso   BFA
# 112                                    Finland   FIN
# 113                                    Ireland   IRL
# 114                                     Malawi   MWI
# 115                                 Mauritania   MRT
# 116                              French Guiana   GUF
# 117                                    Hungary   HUN
# 118                                Afghanistan   AFG
# 119                                     Guinea   GIN
# 120                                     Gambia   GMB
# 121                                    Iceland   ISL
# 122                                 Cabo Verde   CPV
# 123                                 Czech Rep.   CZE
# 124                                    Jamaica   JAM
# 125                                  Sri Lanka   LKA
# 126                                    Namibia   NAM
# 127                                     Poland   POL
# 128                                    Albania   ALB
# 129                                    Armenia   ARM
# 130                                 Azerbaijan   AZE
# 131                                   Bulgaria   BGR
# 132                                    Bahamas   BHS
# 133                                    Croatia   HRV
# 134  The former Yugoslav Republic of Macedonia   MKD
# 135                                   Suriname   SUR
# 136                                   Slovenia   SVN
# 137                                       Chad   TCD
# 138                                 Tajikistan   TJK
# 139                                    Eritrea   ERI
# 140                                 Kazakhstan   KAZ
# 141                                 Kyrgyzstan   KGZ
# 142                                      Libya   LBY
# 143                                      Malta   MLT
# 144                                   Slovakia   SVK
# 145                               Turkmenistan   TKM
# 146                                 Uzbekistan   UZB
# 147                               South Africa   ZAF
# 148                                    Belarus   BLR
# 149                                 Madagascar   MDG
# 150                                    Ukraine   UKR
# 151                                       Fiji   FJI
# 152                                    Georgia   GEO
# 153                            Solomon Islands   SLB
# 154                         Russian Federation   RUS
# 155                     Bosnia and Herzegovina   BIH
# 156                                Saint Lucia   LCA
# 157                                  Lithuania   LTU
# 158                                     Israel   ISR
# 159                                     Latvia   LVA
# 160                                    Comoros   COM
# 161                            Rep. of Moldova   MDA
# 162                                  Mauritius   MUS
# 163                                    Estonia   EST
# 164                              Liechtenstein   LIE
# 165                                       Oman   OMN
# 166                                Timor-Leste   TLS
# 167                                   Mongolia   MNG
# 168           Micronesia (Federated States of)   FSM
# 169                                 Montenegro   MNE
# 170                                      Haiti   HTI
# 171                        Trinidad and Tobago   TTO
# 172                                    Vanuatu   VUT
# 173                             Cayman Islands   CYM
# 174                      Saint Kitts and Nevis   KNA
# 175                                      Palau   PLW
# 176           Saint Vincent and the Grenadines   VCT
# 177                     British Virgin Islands   VGB
# 178                                      Aruba   ABW
# 179                        Antigua and Barbuda   ATG
# 180                                    Bonaire   BES
# 181                                   CuraÌ¤ao   CUW
# 182                                    Grenada   GRD
# 183                                     Monaco   MCO
# 184                                 Montserrat   MSR
# 185                  Sint Maarten (Dutch part)   SXM
# 186                                      Tonga   TON
# 187                                South Sudan   SSD
# 188                   Turks and Caicos Islands   TCA
# 189                                      Nauru   NRU
# 190                                   Barbados   BRB
# 191                          Brunei Darussalam   BRN
# 192                                    Myanmar   MMR
# 193                                   Anguilla   AIA
# 194                Dem. People's Rep. of Korea   PRK
# 195                                      Samoa   WSM
# 196                                 Seychelles   SYC

# %%
my_df = full_df.merge(uq_names, left_on="Destination", right_on="country_name")
del my_df['country_name']
my_df.describe()
#my_df has 197,665 rows
# Out:
#                 Year
# count  197665.000000
# mean     2008.078942
# std         7.734538
# min      1951.000000
# 25%      2004.000000
# 50%      2010.000000
# 75%      2014.000000
# max      2017.000000

# %%
# Now merge on country of origin

uq_names_org = my_df['Origin'].unique()
uq_names_org = pd.DataFrame(uq_names_org)
uq_names_org = uq_names_org.rename(columns={0: 'country_name'})
uq_names_org.head()

uq_names_org['ocode'] = uq_names_org.apply(lambda row: match_countries(row['country_name'], alias), axis=1)
# Out:
# Various/Unknown
# Country Code?
# Dem. Rep. of the Congo
# Country Code? COD
# Czech Rep.
# Country Code? CZE
# Iran (Islamic Rep. of)
# Country Code? IRN
# Rep. of Korea
# Country Code? KOR
# Lao People's Dem. Rep.
# Country Code? LAO
# Rep. of Moldova
# Country Code? MDA
# The former Yugoslav Republic of Macedonia
# Country Code? MKD
# Dem. People's Rep. of Korea
# Country Code? PRK
# Palestinian
# Country Code? PSE
# Russian Federation
# Country Code? RUS
# Serbia and Kosovo (S/RES/1244 (1999))
# Country Code? SRB
# Syrian Arab Rep.
# Country Code? SYR
# United Rep. of Tanzania
# Country Code? TZA
# Viet Nam
# Country Code? VNM
# Stateless
# Country Code?
# Congo
# Country Code? COG
# Bolivia (Plurinational State of)
# Country Code? BOL
# China, Hong Kong SAR
# Country Code? HKG
# CÌ«te d'Ivoire
# Country Code? CIV
# Dominican Rep.
# Country Code? DOM
# Guinea-Bissau
# Country Code? GNB
# Venezuela (Bolivarian Republic of)
# Country Code? VEN
# French Polynesia
# Country Code? PYF
# Tibetan
# Country Code? TAR
# Brunei Darussalam
# Country Code? BRN
# Central African Rep.
# Country Code? CAF
# Cook Islands
# Country Code? COK
# Western Sahara
# Country Code? ESH
# China, Macao SAR
# Country Code? MAC
# American Samoa
# Country Code? ASM
# Bahamas
# Country Code? BHS
# Cabo Verde
# Country Code? CPV
# Puerto Rico
# Country Code? PRI
# Bermuda
# Country Code? BMU
# Turks and Caicos Islands
# Country Code? TCA
# Cayman Islands
# Country Code? CYM
# Holy See (the)
# Country Code? VAT
# Aruba
# Country Code? ABW
# Guadeloupe
# Country Code? GLP
# Saint-Pierre-et-Miquelon
# Country Code? SPM
# British Virgin Islands
# Country Code? VGB
# Micronesia (Federated States of)
# Country Code? FSM
# French Guiana
# Country Code? GUF
# Martinique
# Country Code? MTQ
# Gibraltar
# Country Code? GIB
# Niue
# Country Code? NIU
# New Caledonia
# Country Code? NCL
# CuraÌ¤ao
# Country Code? CUW
# Guam
# Country Code? GUM
# Anguilla
# Country Code? AIA
# Norfolk Island
# Country Code? NFK
# Wallis and Futuna Islands
# Country Code? WLF
# Svalbard and Jan Mayen
# Country Code? SJM

# %%
complete_df = my_df.merge(uq_names_org, left_on="Origin", right_on="country_name", how="left")
del complete_df['country_name']
complete_df.to_csv('fully_prepped.csv',index=False)

# %% [markdown]
# # Country of Origin v Destination 2007-2017

# %%
# Separate the Refugees 
complete_df['Value'] = complete_df['Value'].replace('*', 0)
complete_df['Value'] = pd.to_numeric(complete_df['Value'])
fugees_df = complete_df.loc[complete_df['Type']!='Asylum-seekers']
fugees_df.reset_index(drop=True, inplace=True)
fugees_df.describe()
fugees_df.to_csv('fugees_df.csv')
# 109,632 rows

# %%
# Create a df that just has COO refugee totals 2007-2017
del fugees_df['Type']
fugees_2 = fugees_df.loc[fugees_df['Year'] >= 2007,:]
origins = fugees_2.groupby('Origin')
origins = origins['Value'].sum()
origins = pd.DataFrame(origins)
origins.to_csv("origins.csv")

# There are 221 rows in origins

# %%
# Create a df that has COO x COD refugee totals 2007-2017
ref_dyads = fugees_2.groupby(['Origin', 'Destination'])
ref_dyads = ref_dyads['Value'].sum()
ref_dyads = pd.DataFrame(ref_dyads)
ref_dyads.head()
ref_dyads.to_csv('ref_dyads.csv')

# There should be 9,279 rows here!

# %%
# Merge uq_names AND uq_names_org with ref_dyads 
ref_dyads.reset_index(drop=False, inplace=True)
ref_dyads_2 = ref_dyads.merge(uq_names, left_on="Destination", right_on="country_name", how="left")
del ref_dyads_2['country_name']

ref_dyads_3 = ref_dyads_2.merge(uq_names_org, left_on="Origin", right_on="country_name", how="left")
del ref_dyads_3['country_name']
ref_dyads_3.head()

refugees_4 = ref_dyads_3.merge(origins, left_on="Origin", right_on="Origin", how="left")
refugees_4 = refugees_4.rename(columns={'Value_x': 'COO_COD', 'Value_y': 'COO_total'})
refugees_4.to_csv('refugees_4.csv')

# Execute a double_sort on Value and country of origin
refugees_4['Pct'] = refugees_4['COO_COD'] / refugees_4['COO_total'] 

refugees_4 = refugees_4.sort_values(['Origin', 'Pct'], ascending=[True, False])
refugees_4.reset_index(drop=True, inplace=True)
refugees_4.to_csv('refugees_4.csv')
refugees_4['Pct'] = round(refugees_4['Pct'], 3)
refugees_4.head()
# Out:
#    index       Origin             Destination   COO_COD dcode ocode  \
# 0     77  Afghanistan                Pakistan  18220178   PAK   AFG
# 1     46  Afghanistan  Iran (Islamic Rep. of)  10173716   IRN   AFG
# 2     39  Afghanistan                 Germany    404959   DEU   AFG
# 3    109  Afghanistan          United Kingdom    165161   GBR   AFG
# 4      7  Afghanistan                 Austria    133448   AUT   AFG
#
#    COO_total    Pct
# 0   30027956  0.607
# 1   30027956  0.339
# 2   30027956  0.013
# 3   30027956  0.006
# 4   30027956  0.004

# %%
del refugees_4['index']
refugees_4.head()
# Out:
#         Origin             Destination   COO_COD dcode ocode  COO_total    Pct
# 0  Afghanistan                Pakistan  18220178   PAK   AFG   30027956  0.607
# 1  Afghanistan  Iran (Islamic Rep. of)  10173716   IRN   AFG   30027956  0.339
# 2  Afghanistan                 Germany    404959   DEU   AFG   30027956  0.013
# 3  Afghanistan          United Kingdom    165161   GBR   AFG   30027956  0.006
# 4  Afghanistan                 Austria    133448   AUT   AFG   30027956  0.004

# %%
# Take the dataframe 'refugees_4' and jsonify
temp_df = pd.DataFrame()
coo_cod_array = {}

for country in refugees_4['Origin'].unique():
    temp_df = refugees_4.loc[refugees_4['Origin']==country,:]
    temp_df = temp_df.loc[temp_df['Pct'] >= 0.01,:]
    temp_array = {}
    for x in range(len(temp_df)):
        row = temp_df.iloc[x,:]
        temp_array[row[3]] = {row[1]: {'Number': row[2], 'Percentage': row[6]}}
        ocode = row[4]
    coo_cod_array[country] = {ocode: temp_array}
    
pprint(coo_cod_array)
# Out:
# {'Afghanistan': {'AFG': {'DEU': {'Germany': {'Number': 404959,
#                                              'Percentage': 0.013}},
#                          'IRN': {'Iran (Islamic Rep. of)': {'Number': 10173716,
#                                                             'Percentage': 0.339}},
#                          'PAK': {'Pakistan': {'Number': 18220178,
#                                               'Percentage': 0.607}}}},
#  'Albania': {'ALB': {'AUT': {'Austria': {'Number': 1554, 'Percentage': 0.011}},
#                      'BEL': {'Belgium': {'Number': 3683, 'Percentage': 0.026}},
#                      'CAN': {'Canada': {'Number': 19370, 'Percentage': 0.138}},
#                      'DEU': {'Germany': {'Number': 13896, 'Percentage': 0.099}},
#                      'FRA': {'France': {'Number': 24429, 'Percentage': 0.173}},
#                      'GBR': {'United Kingdom': {'Number': 17471,
#                                                 'Percentage': 0.124}},
#                      'IRL': {'Ireland': {'Number': 1372, 'Percentage': 0.01}},
#                      'ITA': {'Italy': {'Number': 2897, 'Percentage': 0.021}},
#                      'SWE': {'Sweden': {'Number': 2593, 'Percentage': 0.018}},
#                      'USA': {'United States of America': {'Number': 49082,
#                                                           'Percentage': 0.348}}}},
#  'Algeria': {'DZA': {'CAN': {'Canada': {'Number': 10593, 'Percentage': 0.164}},
#                      'CHE': {'Switzerland': {'Number': 2084,
#                                              'Percentage': 0.032}},
#                      'DEU': {'Germany': {'Number': 13416, 'Percentage': 0.207}},
#                      'ESP': {'Spain': {'Number': 916, 'Percentage': 0.014}},
#                      'FRA': {'France': {'Number': 14685, 'Percentage': 0.227}},
#                      'GBR': {'United Kingdom': {'Number': 10273,
#                                                 'Percentage': 0.159}},
#                      'IRL': {'Ireland': {'Number': 1934, 'Percentage': 0.03}},
#                      'ITA': {'Italy': {'Number': 1048, 'Percentage': 0.016}},
#                      'NLD': {'Netherlands': {'Number': 728,
#                                              'Percentage': 0.011}},
#                      'SWE': {'Sweden': {'Number': 826, 'Percentage': 0.013}},
#                      'USA': {'United States of America': {'Number': 3365,
#                                                           'Percentage': 0.052}}}},
#  'American Samoa': {'DZA': {}},
#  'Andorra': {'AND': {'DEU': {'Germany': {'Number': 3, 'Percentage': 0.051}},
#                      'NLD': {'Netherlands': {'Number': 8, 'Percentage': 0.136}},
#                      'USA': {'United States of America': {'Number': 43,
#                                                           'Percentage': 0.729}},
#                      'ZAF': {'South Africa': {'Number': 5,
#                                               'Percentage': 0.085}}}},
#  'Angola': {'AGO': {'BRA': {'Brazil': {'Number': 15510, 'Percentage': 0.019}},
#                     'CHE': {'Switzerland': {'Number': 13906,
#                                             'Percentage': 0.017}},
#                     'COD': {'Dem. Rep. of the Congo': {'Number': 469069,
#                                                        'Percentage': 0.565}},
#                     'COG': {'Congo': {'Number': 9929, 'Percentage': 0.012}},
#                     'DEU': {'Germany': {'Number': 21781, 'Percentage': 0.026}},
#                     'FRA': {'France': {'Number': 34934, 'Percentage': 0.042}},
#                     'GBR': {'United Kingdom': {'Number': 17373,
#                                                'Percentage': 0.021}},
#                     'NAM': {'Namibia': {'Number': 27771, 'Percentage': 0.033}},
#                     'NLD': {'Netherlands': {'Number': 13411,
#                                             'Percentage': 0.016}},
#                     'ZAF': {'South Africa': {'Number': 37749,
#                                              'Percentage': 0.045}},
#                     'ZMB': {'Zambia': {'Number': 141982,
#                                        'Percentage': 0.171}}}},
#  'Anguilla': {'AIA': {'ZAF': {'South Africa': {'Number': 3,
#                                                'Percentage': 1.0}}}},
#  'Antigua and Barbuda': {'ATG': {'CAN': {'Canada': {'Number': 486,
#                                                     'Percentage': 0.933}},
#                                  'DEU': {'Germany': {'Number': 6,
#                                                      'Percentage': 0.012}},
#                                  'GBR': {'United Kingdom': {'Number': 9,
#                                                             'Percentage': 0.017}},
#                                  'USA': {'United States of America': {'Number': 19,
#                                                                       'Percentage': 0.036}}}},
#  'Argentina': {'ARG': {'BRA': {'Brazil': {'Number': 121, 'Percentage': 0.022}},
#                        'CAN': {'Canada': {'Number': 2726, 'Percentage': 0.497}},
#                        'DEU': {'Germany': {'Number': 375, 'Percentage': 0.068}},
#                        'ESP': {'Spain': {'Number': 868, 'Percentage': 0.158}},
#                        'USA': {'United States of America': {'Number': 1225,
#                                                             'Percentage': 0.223}}}},
#  'Armenia': {'ARM': {'AUT': {'Austria': {'Number': 9238, 'Percentage': 0.059}},
#                      'CAN': {'Canada': {'Number': 1819, 'Percentage': 0.012}},
#                      'DEU': {'Germany': {'Number': 27410, 'Percentage': 0.175}},
#                      'FRA': {'France': {'Number': 37008, 'Percentage': 0.237}},
#                      'ITA': {'Italy': {'Number': 1693, 'Percentage': 0.011}},
#                      'NLD': {'Netherlands': {'Number': 9453,
#                                              'Percentage': 0.06}},
#                      'SWE': {'Sweden': {'Number': 6291, 'Percentage': 0.04}},
#                      'UKR': {'Ukraine': {'Number': 2177, 'Percentage': 0.014}},
#                      'USA': {'United States of America': {'Number': 51263,
#                                                           'Percentage': 0.328}}}},
#  'Aruba': {'ARM': {}},
#  'Australia': {'AUS': {'AUS': {'Australia': {'Number': 7, 'Percentage': 0.02}},
#                        'CAN': {'Canada': {'Number': 36, 'Percentage': 0.104}},
#                        'DEU': {'Germany': {'Number': 255, 'Percentage': 0.739}},
#                        'GBR': {'United Kingdom': {'Number': 12,
#                                                   'Percentage': 0.035}},
#                        'SWE': {'Sweden': {'Number': 20, 'Percentage': 0.058}},
#                        'USA': {'United States of America': {'Number': 10,
#                                                             'Percentage': 0.029}}}},
#  'Austria': {'AUT': {'BEL': {'Belgium': {'Number': 2, 'Percentage': 0.018}},
#                      'CAN': {'Canada': {'Number': 5, 'Percentage': 0.045}},
#                      'CHE': {'Switzerland': {'Number': 22,
#                                              'Percentage': 0.196}},
#                      'DEU': {'Germany': {'Number': 38, 'Percentage': 0.339}},
#                      'FRA': {'France': {'Number': 3, 'Percentage': 0.027}},
#                      'USA': {'United States of America': {'Number': 41,
#                                                           'Percentage': 0.366}}}},
#  'Azerbaijan': {'AZE': {'ARM': {'Armenia': {'Number': 24311,
#                                             'Percentage': 0.162}},
#                         'AUT': {'Austria': {'Number': 3983,
#                                             'Percentage': 0.027}},
#                         'CAN': {'Canada': {'Number': 5921, 'Percentage': 0.04}},
#                         'DEU': {'Germany': {'Number': 47199,
#                                             'Percentage': 0.315}},
#                         'FRA': {'France': {'Number': 26667,
#                                            'Percentage': 0.178}},
#                         'NLD': {'Netherlands': {'Number': 15160,
#                                                 'Percentage': 0.101}},
#                         'SWE': {'Sweden': {'Number': 8523,
#                                            'Percentage': 0.057}},
#                         'UKR': {'Ukraine': {'Number': 1908,
#                                             'Percentage': 0.013}},
#                         'USA': {'United States of America': {'Number': 8971,
#                                                              'Percentage': 0.06}}}},
#  'Bahamas': {'BHS': {'CAN': {'Canada': {'Number': 421, 'Percentage': 0.24}},
#                      'USA': {'United States of America': {'Number': 1309,
#                                                           'Percentage': 0.746}}}},
#  'Bahrain': {'BHR': {'AUS': {'Australia': {'Number': 673, 'Percentage': 0.238}},
#                      'CAN': {'Canada': {'Number': 148, 'Percentage': 0.052}},
#                      'DEU': {'Germany': {'Number': 372, 'Percentage': 0.132}},
#                      'GBR': {'United Kingdom': {'Number': 872,
#                                                 'Percentage': 0.309}},
#                      'LBN': {'Lebanon': {'Number': 80, 'Percentage': 0.028}},
#                      'NZL': {'New Zealand': {'Number': 159,
#                                              'Percentage': 0.056}},
#                      'SWE': {'Sweden': {'Number': 95, 'Percentage': 0.034}},
#                      'USA': {'United States of America': {'Number': 352,
#                                                           'Percentage': 0.125}}}},
#  'Bangladesh': {'BGD': {'AUS': {'Australia': {'Number': 3473,
#                                               'Percentage': 0.028}},
#                         'AUT': {'Austria': {'Number': 1301,
#                                             'Percentage': 0.01}},
#                         'CAN': {'Canada': {'Number': 20696,
#                                            'Percentage': 0.166}},
#                         'DEU': {'Germany': {'Number': 5947,
#                                             'Percentage': 0.048}},
#                         'FRA': {'France': {'Number': 33572,
#                                            'Percentage': 0.27}},
#                         'GBR': {'United Kingdom': {'Number': 15574,
#                                                    'Percentage': 0.125}},
#                         'ITA': {'Italy': {'Number': 18325,
#                                           'Percentage': 0.147}},
#                         'SWE': {'Sweden': {'Number': 2860,
#                                            'Percentage': 0.023}},
#                         'USA': {'United States of America': {'Number': 14770,
#                                                              'Percentage': 0.119}},
#                         'ZAF': {'South Africa': {'Number': 2869,
#                                                  'Percentage': 0.023}}}},
#  'Barbados': {'BRB': {'CAN': {'Canada': {'Number': 752, 'Percentage': 0.94}},
#                       'DEU': {'Germany': {'Number': 25, 'Percentage': 0.031}},
#                       'USA': {'United States of America': {'Number': 17,
#                                                            'Percentage': 0.021}}}},
#  'Belarus': {'BLR': {'AUT': {'Austria': {'Number': 987, 'Percentage': 0.018}},
#                      'BEL': {'Belgium': {'Number': 789, 'Percentage': 0.015}},
#                      'CAN': {'Canada': {'Number': 2721, 'Percentage': 0.05}},
#                      'CZE': {'Czech Rep.': {'Number': 3432,
#                                             'Percentage': 0.064}},
#                      'DEU': {'Germany': {'Number': 11735, 'Percentage': 0.217}},
#                      'FRA': {'France': {'Number': 5149, 'Percentage': 0.095}},
#                      'GBR': {'United Kingdom': {'Number': 1437,
#                                                 'Percentage': 0.027}},
#                      'IRL': {'Ireland': {'Number': 555, 'Percentage': 0.01}},
#                      'NLD': {'Netherlands': {'Number': 1050,
#                                              'Percentage': 0.019}},
#                      'POL': {'Poland': {'Number': 1973, 'Percentage': 0.037}},
#                      'SWE': {'Sweden': {'Number': 2040, 'Percentage': 0.038}},
#                      'USA': {'United States of America': {'Number': 19185,
#                                                           'Percentage': 0.355}}}},
#  'Belgium': {'BEL': {'CAN': {'Canada': {'Number': 140, 'Percentage': 0.181}},
#                      'DEU': {'Germany': {'Number': 54, 'Percentage': 0.07}},
#                      'IRL': {'Ireland': {'Number': 82, 'Percentage': 0.106}},
#                      'NOR': {'Norway': {'Number': 8, 'Percentage': 0.01}},
#                      'SWE': {'Sweden': {'Number': 121, 'Percentage': 0.157}},
#                      'USA': {'United States of America': {'Number': 357,
#                                                           'Percentage': 0.462}}}},
#  'Belize': {'BLZ': {'CAN': {'Canada': {'Number': 81, 'Percentage': 0.202}},
#                     'DEU': {'Germany': {'Number': 8, 'Percentage': 0.02}},
#                     'GBR': {'United Kingdom': {'Number': 12,
#                                                'Percentage': 0.03}},
#                     'MEX': {'Mexico': {'Number': 7, 'Percentage': 0.018}},
#                     'USA': {'United States of America': {'Number': 290,
#                                                          'Percentage': 0.725}}}},
#  'Benin': {'BEN': {'AUT': {'Austria': {'Number': 43, 'Percentage': 0.01}},
#                    'BEL': {'Belgium': {'Number': 168, 'Percentage': 0.038}},
#                    'CAN': {'Canada': {'Number': 580, 'Percentage': 0.13}},
#                    'CHE': {'Switzerland': {'Number': 274, 'Percentage': 0.061}},
#                    'DEU': {'Germany': {'Number': 1108, 'Percentage': 0.248}},
#                    'FRA': {'France': {'Number': 233, 'Percentage': 0.052}},
#                    'GBR': {'United Kingdom': {'Number': 96,
#                                               'Percentage': 0.022}},
#                    'ITA': {'Italy': {'Number': 839, 'Percentage': 0.188}},
#                    'NLD': {'Netherlands': {'Number': 101, 'Percentage': 0.023}},
#                    'SWE': {'Sweden': {'Number': 58, 'Percentage': 0.013}},
#                    'USA': {'United States of America': {'Number': 754,
#                                                         'Percentage': 0.169}}}},
#  'Bermuda': {'BEN': {}},
#  'Bhutan': {'BTN': {'NPL': {'Nepal': {'Number': 565795, 'Percentage': 0.989}}}},
#  'Bolivia (Plurinational State of)': {'BOL': {'AUT': {'Austria': {'Number': 115,
#                                                                   'Percentage': 0.019}},
#                                               'BRA': {'Brazil': {'Number': 1229,
#                                                                  'Percentage': 0.202}},
#                                               'CAN': {'Canada': {'Number': 1439,
#                                                                  'Percentage': 0.236}},
#                                               'CRI': {'Costa Rica': {'Number': 60,
#                                                                      'Percentage': 0.01}},
#                                               'DEU': {'Germany': {'Number': 259,
#                                                                   'Percentage': 0.043}},
#                                               'FIN': {'Finland': {'Number': 79,
#                                                                   'Percentage': 0.013}},
#                                               'FRA': {'France': {'Number': 412,
#                                                                  'Percentage': 0.068}},
#                                               'GBR': {'United Kingdom': {'Number': 174,
#                                                                          'Percentage': 0.029}},
#                                               'ITA': {'Italy': {'Number': 77,
#                                                                 'Percentage': 0.013}},
#                                               'PER': {'Peru': {'Number': 60,
#                                                                'Percentage': 0.01}},
#                                               'PRY': {'Paraguay': {'Number': 100,
#                                                                    'Percentage': 0.016}},
#                                               'SWE': {'Sweden': {'Number': 650,
#                                                                  'Percentage': 0.107}},
#                                               'USA': {'United States of America': {'Number': 1173,
#                                                                                    'Percentage': 0.193}}}},
#  'Bosnia and Herzegovina': {'BIH': {'CHE': {'Switzerland': {'Number': 33750,
#                                                             'Percentage': 0.068}},
#                                     'DEU': {'Germany': {'Number': 155068,
#                                                         'Percentage': 0.311}},
#                                     'DNK': {'Denmark': {'Number': 5155,
#                                                         'Percentage': 0.01}},
#                                     'FRA': {'France': {'Number': 44421,
#                                                        'Percentage': 0.089}},
#                                     'HRV': {'Croatia': {'Number': 6254,
#                                                         'Percentage': 0.013}},
#                                     'MNE': {'Montenegro': {'Number': 28250,
#                                                            'Percentage': 0.057}},
#                                     'SRB': {'Serbia and Kosovo (S/RES/1244 (1999))': {'Number': 190539,
#                                                                                       'Percentage': 0.382}},
#                                     'SWE': {'Sweden': {'Number': 17459,
#                                                        'Percentage': 0.035}}}},
#  'Botswana': {'BWA': {'CAN': {'Canada': {'Number': 1412, 'Percentage': 0.882}},
#                       'DEU': {'Germany': {'Number': 27, 'Percentage': 0.017}},
#                       'GBR': {'United Kingdom': {'Number': 110,
#                                                  'Percentage': 0.069}},
#                       'USA': {'United States of America': {'Number': 41,
#                                                            'Percentage': 0.026}}}},
#  'Brazil': {'BRA': {'CAN': {'Canada': {'Number': 1621, 'Percentage': 0.14}},
#                     'DEU': {'Germany': {'Number': 2419, 'Percentage': 0.208}},
#                     'ITA': {'Italy': {'Number': 307, 'Percentage': 0.026}},
#                     'USA': {'United States of America': {'Number': 6733,
#                                                          'Percentage': 0.58}}}},
#  'British Virgin Islands': {'BRA': {}},
#  'Brunei Darussalam': {'BRN': {'CHE': {'Switzerland': {'Number': 1,
#                                                        'Percentage': 0.1}},
#                                'IDN': {'Indonesia': {'Number': 1,
#                                                      'Percentage': 0.1}},
#                                'NOR': {'Norway': {'Number': 8,
#                                                   'Percentage': 0.8}}}},
#  'Bulgaria': {'BGR': {'BEL': {'Belgium': {'Number': 266, 'Percentage': 0.012}},
#                       'CAN': {'Canada': {'Number': 9442, 'Percentage': 0.421}},
#                       'CZE': {'Czech Rep.': {'Number': 240,
#                                              'Percentage': 0.011}},
#                       'DEU': {'Germany': {'Number': 1655, 'Percentage': 0.074}},
#                       'FRA': {'France': {'Number': 865, 'Percentage': 0.039}},
#                       'IRL': {'Ireland': {'Number': 315, 'Percentage': 0.014}},
#                       'SWE': {'Sweden': {'Number': 304, 'Percentage': 0.014}},
#                       'USA': {'United States of America': {'Number': 8595,
#                                                            'Percentage': 0.383}}}},
#  'Burkina Faso': {'BFA': {'BEL': {'Belgium': {'Number': 475,
#                                               'Percentage': 0.028}},
#                           'CAN': {'Canada': {'Number': 1387,
#                                              'Percentage': 0.083}},
#                           'DEU': {'Germany': {'Number': 1239,
#                                               'Percentage': 0.074}},
#                           'FRA': {'France': {'Number': 1014,
#                                              'Percentage': 0.06}},
#                           'ITA': {'Italy': {'Number': 5346,
#                                             'Percentage': 0.319}},
#                           'USA': {'United States of America': {'Number': 6510,
#                                                                'Percentage': 0.388}}}},
#  'Burundi': {'BDI': {'COD': {'Dem. Rep. of the Congo': {'Number': 206869,
#                                                         'Percentage': 0.09}},
#                      'RWA': {'Rwanda': {'Number': 249459, 'Percentage': 0.109}},
#                      'TZA': {'United Rep. of Tanzania': {'Number': 1488150,
#                                                          'Percentage': 0.648}},
#                      'UGA': {'Uganda': {'Number': 159552, 'Percentage': 0.07}},
#                      'ZAF': {'South Africa': {'Number': 29610,
#                                               'Percentage': 0.013}},
#                      'ZMB': {'Zambia': {'Number': 26803,
#                                         'Percentage': 0.012}}}},
#  'Cabo Verde': {'CPV': {'BRA': {'Brazil': {'Number': 11, 'Percentage': 0.042}},
#                         'CAN': {'Canada': {'Number': 3, 'Percentage': 0.012}},
#                         'CHE': {'Switzerland': {'Number': 6,
#                                                 'Percentage': 0.023}},
#                         'DEU': {'Germany': {'Number': 48, 'Percentage': 0.185}},
#                         'FRA': {'France': {'Number': 3, 'Percentage': 0.012}},
#                         'GAB': {'Gabon': {'Number': 4, 'Percentage': 0.015}},
#                         'GBR': {'United Kingdom': {'Number': 16,
#                                                    'Percentage': 0.062}},
#                         'ITA': {'Italy': {'Number': 155, 'Percentage': 0.598}},
#                         'NLD': {'Netherlands': {'Number': 5,
#                                                 'Percentage': 0.019}},
#                         'NOR': {'Norway': {'Number': 7, 'Percentage': 0.027}}}},
#  'Cambodia': {'KHM': {'CAN': {'Canada': {'Number': 1685, 'Percentage': 0.01}},
#                       'CHE': {'Switzerland': {'Number': 4211,
#                                               'Percentage': 0.026}},
#                       'FRA': {'France': {'Number': 137441, 'Percentage': 0.85}},
#                       'USA': {'United States of America': {'Number': 4306,
#                                                            'Percentage': 0.027}},
#                       'VNM': {'Viet Nam': {'Number': 9989,
#                                            'Percentage': 0.062}}}},
#  'Cameroon': {'CMR': {'AUT': {'Austria': {'Number': 2304, 'Percentage': 0.017}},
#                       'BEL': {'Belgium': {'Number': 3335, 'Percentage': 0.024}},
#                       'CAN': {'Canada': {'Number': 9490, 'Percentage': 0.069}},
#                       'CHE': {'Switzerland': {'Number': 1842,
#                                               'Percentage': 0.013}},
#                       'DEU': {'Germany': {'Number': 9273, 'Percentage': 0.067}},
#                       'FRA': {'France': {'Number': 8161, 'Percentage': 0.059}},
#                       'GBR': {'United Kingdom': {'Number': 7668,
#                                                  'Percentage': 0.056}},
#                       'IRL': {'Ireland': {'Number': 1319, 'Percentage': 0.01}},
#                       'ITA': {'Italy': {'Number': 7092, 'Percentage': 0.051}},
#                       'NGA': {'Nigeria': {'Number': 9690, 'Percentage': 0.07}},
#                       'NLD': {'Netherlands': {'Number': 1831,
#                                               'Percentage': 0.013}},
#                       'USA': {'United States of America': {'Number': 66362,
#                                                            'Percentage': 0.482}},
#                       'ZAF': {'South Africa': {'Number': 2712,
#                                                'Percentage': 0.02}}}},
#  'Canada': {'CAN': {'DEU': {'Germany': {'Number': 884, 'Percentage': 0.595}},
#                     'GBR': {'United Kingdom': {'Number': 47,
#                                                'Percentage': 0.032}},
#                     'USA': {'United States of America': {'Number': 497,
#                                                          'Percentage': 0.335}}}},
#  'Cayman Islands': {'CYM': {'CAN': {'Canada': {'Number': 1,
#                                                'Percentage': 0.029}},
#                             'USA': {'United States of America': {'Number': 33,
#                                                                  'Percentage': 0.971}}}},
#  'Central African Rep.': {'CAF': {'CMR': {'Cameroon': {'Number': 1597623,
#                                                        'Percentage': 0.524}},
#                                   'COD': {'Dem. Rep. of the Congo': {'Number': 517306,
#                                                                      'Percentage': 0.17}},
#                                   'COG': {'Congo': {'Number': 106747,
#                                                     'Percentage': 0.035}},
#                                   'TCD': {'Chad': {'Number': 759766,
#                                                    'Percentage': 0.249}}}},
#  'Chad': {'TCD': {'CAF': {'Central African Rep.': {'Number': 10850,
#                                                    'Percentage': 0.024}},
#                   'CAN': {'Canada': {'Number': 6132, 'Percentage': 0.014}},
#                   'CMR': {'Cameroon': {'Number': 47047, 'Percentage': 0.106}},
#                   'FRA': {'France': {'Number': 12273, 'Percentage': 0.028}},
#                   'GAB': {'Gabon': {'Number': 9287, 'Percentage': 0.021}},
#                   'SDN': {'Sudan': {'Number': 339887, 'Percentage': 0.765}}}},
#  'Chile': {'CHL': {'ARG': {'Argentina': {'Number': 1685, 'Percentage': 0.177}},
#                    'BEL': {'Belgium': {'Number': 556, 'Percentage': 0.059}},
#                    'BRA': {'Brazil': {'Number': 210, 'Percentage': 0.022}},
#                    'CAN': {'Canada': {'Number': 1628, 'Percentage': 0.171}},
#                    'CHE': {'Switzerland': {'Number': 144, 'Percentage': 0.015}},
#                    'DEU': {'Germany': {'Number': 3171, 'Percentage': 0.334}},
#                    'FRA': {'France': {'Number': 730, 'Percentage': 0.077}},
#                    'SWE': {'Sweden': {'Number': 385, 'Percentage': 0.041}},
#                    'USA': {'United States of America': {'Number': 655,
#                                                         'Percentage': 0.069}}}},
#  'China': {'CHN': {'AUS': {'Australia': {'Number': 25871, 'Percentage': 0.012}},
#                    'CAN': {'Canada': {'Number': 151444, 'Percentage': 0.072}},
#                    'CHE': {'Switzerland': {'Number': 22361,
#                                            'Percentage': 0.011}},
#                    'DEU': {'Germany': {'Number': 29355, 'Percentage': 0.014}},
#                    'FRA': {'France': {'Number': 22041, 'Percentage': 0.01}},
#                    'GBR': {'United Kingdom': {'Number': 23032,
#                                               'Percentage': 0.011}},
#                    'IND': {'India': {'Number': 1114440, 'Percentage': 0.529}},
#                    'USA': {'United States of America': {'Number': 675980,
#                                                         'Percentage': 0.321}}}},
#  'China, Hong Kong SAR': {'HKG': {'AUS': {'Australia': {'Number': 3,
#                                                         'Percentage': 0.016}},
#                                   'CAN': {'Canada': {'Number': 105,
#                                                      'Percentage': 0.565}},
#                                   'GBR': {'United Kingdom': {'Number': 6,
#                                                              'Percentage': 0.032}},
#                                   'USA': {'United States of America': {'Number': 72,
#                                                                        'Percentage': 0.387}}}},
#  'China, Macao SAR': {'MAC': {'NOR': {'Norway': {'Number': 40,
#                                                  'Percentage': 0.635}},
#                               'NZL': {'New Zealand': {'Number': 5,
#                                                       'Percentage': 0.079}},
#                               'USA': {'United States of America': {'Number': 7,
#                                                                    'Percentage': 0.111}},
#                               'ZAF': {'South Africa': {'Number': 11,
#                                                        'Percentage': 0.175}}}},
#  'Colombia': {'COL': {'CAN': {'Canada': {'Number': 153835,
#                                          'Percentage': 0.038}},
#                       'CRI': {'Costa Rica': {'Number': 100824,
#                                              'Percentage': 0.025}},
#                       'ECU': {'Ecuador': {'Number': 1358729,
#                                           'Percentage': 0.331}},
#                       'PAN': {'Panama': {'Number': 157634,
#                                          'Percentage': 0.038}},
#                       'USA': {'United States of America': {'Number': 186663,
#                                                            'Percentage': 0.046}},
#                       'VEN': {'Venezuela (Bolivarian Republic of)': {'Number': 2056200,
#                                                                      'Percentage': 0.501}}}},
#  'Comoros': {'COM': {'BEL': {'Belgium': {'Number': 225, 'Percentage': 0.047}},
#                      'CAN': {'Canada': {'Number': 48, 'Percentage': 0.01}},
#                      'DEU': {'Germany': {'Number': 46, 'Percentage': 0.01}},
#                      'FRA': {'France': {'Number': 4152, 'Percentage': 0.868}},
#                      'PRT': {'Portugal': {'Number': 144, 'Percentage': 0.03}},
#                      'USA': {'United States of America': {'Number': 66,
#                                                           'Percentage': 0.014}}}},
#  'Congo': {'COG': {'CAN': {'Canada': {'Number': 3136, 'Percentage': 0.018}},
#                    'COD': {'Dem. Rep. of the Congo': {'Number': 7803,
#                                                       'Percentage': 0.045}},
#                    'DEU': {'Germany': {'Number': 4378, 'Percentage': 0.025}},
#                    'FRA': {'France': {'Number': 34639, 'Percentage': 0.2}},
#                    'GAB': {'Gabon': {'Number': 31880, 'Percentage': 0.184}},
#                    'GBR': {'United Kingdom': {'Number': 5821,
#                                               'Percentage': 0.034}},
#                    'ITA': {'Italy': {'Number': 6080, 'Percentage': 0.035}},
#                    'NLD': {'Netherlands': {'Number': 7336,
#                                            'Percentage': 0.042}},
#                    'USA': {'United States of America': {'Number': 19876,
#                                                         'Percentage': 0.115}},
#                    'ZAF': {'South Africa': {'Number': 37082,
#                                             'Percentage': 0.214}}}},
#  'Cook Islands': {'COK': {'GBR': {'United Kingdom': {'Number': 8,
#                                                      'Percentage': 1.0}}}},
#  'Costa Rica': {'CRI': {'ARG': {'Argentina': {'Number': 49,
#                                               'Percentage': 0.013}},
#                         'CAN': {'Canada': {'Number': 2550,
#                                            'Percentage': 0.685}},
#                         'DEU': {'Germany': {'Number': 95, 'Percentage': 0.026}},
#                         'USA': {'United States of America': {'Number': 974,
#                                                              'Percentage': 0.262}}}},
#  'Croatia': {'HRV': {'BIH': {'Bosnia and Herzegovina': {'Number': 71887,
#                                                         'Percentage': 0.112}},
#                      'DEU': {'Germany': {'Number': 52861, 'Percentage': 0.083}},
#                      'MNE': {'Montenegro': {'Number': 10814,
#                                             'Percentage': 0.017}},
#                      'SRB': {'Serbia and Kosovo (S/RES/1244 (1999))': {'Number': 493734,
#                                                                        'Percentage': 0.772}}}},
#  'Cuba': {'CUB': {'ARG': {'Argentina': {'Number': 3418, 'Percentage': 0.043}},
#                   'BRA': {'Brazil': {'Number': 1484, 'Percentage': 0.019}},
#                   'CAN': {'Canada': {'Number': 17820, 'Percentage': 0.225}},
#                   'CRI': {'Costa Rica': {'Number': 7090, 'Percentage': 0.09}},
#                   'CZE': {'Czech Rep.': {'Number': 1440, 'Percentage': 0.018}},
#                   'DEU': {'Germany': {'Number': 3007, 'Percentage': 0.038}},
#                   'ECU': {'Ecuador': {'Number': 2295, 'Percentage': 0.029}},
#                   'ESP': {'Spain': {'Number': 7671, 'Percentage': 0.097}},
#                   'FRA': {'France': {'Number': 1473, 'Percentage': 0.019}},
#                   'ITA': {'Italy': {'Number': 1236, 'Percentage': 0.016}},
#                   'PAN': {'Panama': {'Number': 10544, 'Percentage': 0.133}},
#                   'PER': {'Peru': {'Number': 6005, 'Percentage': 0.076}},
#                   'SWE': {'Sweden': {'Number': 917, 'Percentage': 0.012}},
#                   'USA': {'United States of America': {'Number': 9159,
#                                                        'Percentage': 0.116}}}},
#  'CuraÌ¤ao': {'CUW': {'USA': {'United States of America': {'Number': 175,
#                                                            'Percentage': 1.0}}}},
#  'Cyprus': {'CYP': {'CAN': {'Canada': {'Number': 8, 'Percentage': 0.088}},
#                     'CHE': {'Switzerland': {'Number': 2, 'Percentage': 0.022}},
#                     'CRI': {'Costa Rica': {'Number': 32, 'Percentage': 0.352}},
#                     'DEU': {'Germany': {'Number': 4, 'Percentage': 0.044}},
#                     'GBR': {'United Kingdom': {'Number': 27,
#                                                'Percentage': 0.297}},
#                     'USA': {'United States of America': {'Number': 18,
#                                                          'Percentage': 0.198}}}},
#  'Czech Rep.': {'CZE': {'CAN': {'Canada': {'Number': 4348,
#                                            'Percentage': 0.358}},
#                         'DEU': {'Germany': {'Number': 4778,
#                                             'Percentage': 0.393}},
#                         'FRA': {'France': {'Number': 282, 'Percentage': 0.023}},
#                         'GBR': {'United Kingdom': {'Number': 594,
#                                                    'Percentage': 0.049}},
#                         'IRL': {'Ireland': {'Number': 936,
#                                             'Percentage': 0.077}},
#                         'NZL': {'New Zealand': {'Number': 558,
#                                                 'Percentage': 0.046}},
#                         'USA': {'United States of America': {'Number': 332,
#                                                              'Percentage': 0.027}}}},
#  "CÌ«te d'Ivoire": {'CIV': {'FRA': {'France': {'Number': 24761,
#                                                'Percentage': 0.036}},
#                             'GHA': {'Ghana': {'Number': 52233,
#                                               'Percentage': 0.077}},
#                             'GIN': {'Guinea': {'Number': 57898,
#                                                'Percentage': 0.085}},
#                             'ITA': {'Italy': {'Number': 43285,
#                                               'Percentage': 0.064}},
#                             'LBR': {'Liberia': {'Number': 394600,
#                                                 'Percentage': 0.58}},
#                             'MLI': {'Mali': {'Number': 16259,
#                                              'Percentage': 0.024}},
#                             'TGO': {'Togo': {'Number': 22782,
#                                              'Percentage': 0.033}},
#                             'USA': {'United States of America': {'Number': 16703,
#                                                                  'Percentage': 0.025}}}},
#  "Dem. People's Rep. of Korea": {'PRK': {'AUS': {'Australia': {'Number': 254,
#                                                                'Percentage': 0.022}},
#                                          'BEL': {'Belgium': {'Number': 395,
#                                                              'Percentage': 0.034}},
#                                          'CAN': {'Canada': {'Number': 1566,
#                                                             'Percentage': 0.135}},
#                                          'DEU': {'Germany': {'Number': 1521,
#                                                              'Percentage': 0.131}},
#                                          'FRA': {'France': {'Number': 146,
#                                                             'Percentage': 0.013}},
#                                          'GBR': {'United Kingdom': {'Number': 6035,
#                                                                     'Percentage': 0.52}},
#                                          'NLD': {'Netherlands': {'Number': 489,
#                                                                  'Percentage': 0.042}},
#                                          'NOR': {'Norway': {'Number': 136,
#                                                             'Percentage': 0.012}},
#                                          'RUS': {'Russian Federation': {'Number': 450,
#                                                                         'Percentage': 0.039}},
#                                          'USA': {'United States of America': {'Number': 232,
#                                                                               'Percentage': 0.02}}}},
#  'Dem. Rep. of the Congo': {'COD': {'AGO': {'Angola': {'Number': 183132,
#                                                        'Percentage': 0.034}},
#                                     'BDI': {'Burundi': {'Number': 444510,
#                                                         'Percentage': 0.083}},
#                                     'CAF': {'Central African Rep.': {'Number': 93582,
#                                                                      'Percentage': 0.017}},
#                                     'COG': {'Congo': {'Number': 582286,
#                                                       'Percentage': 0.108}},
#                                     'FRA': {'France': {'Number': 138163,
#                                                        'Percentage': 0.026}},
#                                     'KEN': {'Kenya': {'Number': 82202,
#                                                       'Percentage': 0.015}},
#                                     'RWA': {'Rwanda': {'Number': 700775,
#                                                        'Percentage': 0.13}},
#                                     'SSD': {'South Sudan': {'Number': 115253,
#                                                             'Percentage': 0.021}},
#                                     'TZA': {'United Rep. of Tanzania': {'Number': 706992,
#                                                                         'Percentage': 0.131}},
#                                     'UGA': {'Uganda': {'Number': 1449063,
#                                                        'Percentage': 0.269}},
#                                     'ZAF': {'South Africa': {'Number': 202486,
#                                                              'Percentage': 0.038}},
#                                     'ZMB': {'Zambia': {'Number': 275291,
#                                                        'Percentage': 0.051}}}},
#  'Denmark': {'DNK': {'AUS': {'Australia': {'Number': 16, 'Percentage': 0.168}},
#                      'BEL': {'Belgium': {'Number': 2, 'Percentage': 0.021}},
#                      'CAN': {'Canada': {'Number': 45, 'Percentage': 0.474}},
#                      'DEU': {'Germany': {'Number': 5, 'Percentage': 0.053}},
#                      'SWE': {'Sweden': {'Number': 15, 'Percentage': 0.158}},
#                      'USA': {'United States of America': {'Number': 12,
#                                                           'Percentage': 0.126}}}},
#  'Djibouti': {'DJI': {'BEL': {'Belgium': {'Number': 1435, 'Percentage': 0.149}},
#                       'CAN': {'Canada': {'Number': 4315, 'Percentage': 0.449}},
#                       'ETH': {'Ethiopia': {'Number': 761, 'Percentage': 0.079}},
#                       'FRA': {'France': {'Number': 1392, 'Percentage': 0.145}},
#                       'USA': {'United States of America': {'Number': 1273,
#                                                            'Percentage': 0.132}}}},
#  'Dominica': {'DMA': {'CAN': {'Canada': {'Number': 336, 'Percentage': 0.68}},
#                       'DEU': {'Germany': {'Number': 19, 'Percentage': 0.038}},
#                       'GBR': {'United Kingdom': {'Number': 31,
#                                                  'Percentage': 0.063}},
#                       'USA': {'United States of America': {'Number': 102,
#                                                            'Percentage': 0.206}}}},
#  'Dominican Rep.': {'DOM': {'CAN': {'Canada': {'Number': 1526,
#                                                'Percentage': 0.436}},
#                             'CRI': {'Costa Rica': {'Number': 48,
#                                                    'Percentage': 0.014}},
#                             'DEU': {'Germany': {'Number': 599,
#                                                 'Percentage': 0.171}},
#                             'FRA': {'France': {'Number': 164,
#                                                'Percentage': 0.047}},
#                             'ITA': {'Italy': {'Number': 39,
#                                               'Percentage': 0.011}},
#                             'MEX': {'Mexico': {'Number': 52,
#                                                'Percentage': 0.015}},
#                             'PER': {'Peru': {'Number': 44,
#                                              'Percentage': 0.013}},
#                             'USA': {'United States of America': {'Number': 857,
#                                                                  'Percentage': 0.245}}}},
#  'Ecuador': {'ECU': {'ARG': {'Argentina': {'Number': 136, 'Percentage': 0.013}},
#                      'AUS': {'Australia': {'Number': 293, 'Percentage': 0.027}},
#                      'BRA': {'Brazil': {'Number': 403, 'Percentage': 0.037}},
#                      'CAN': {'Canada': {'Number': 2172, 'Percentage': 0.201}},
#                      'CHL': {'Chile': {'Number': 168, 'Percentage': 0.016}},
#                      'DEU': {'Germany': {'Number': 915, 'Percentage': 0.084}},
#                      'FRA': {'France': {'Number': 302, 'Percentage': 0.028}},
#                      'GBR': {'United Kingdom': {'Number': 1600,
#                                                 'Percentage': 0.148}},
#                      'ITA': {'Italy': {'Number': 131, 'Percentage': 0.012}},
#                      'SWE': {'Sweden': {'Number': 418, 'Percentage': 0.039}},
#                      'USA': {'United States of America': {'Number': 3723,
#                                                           'Percentage': 0.344}}}},
#  'Egypt': {'EGY': {'AUS': {'Australia': {'Number': 9608, 'Percentage': 0.072}},
#                    'CAN': {'Canada': {'Number': 8170, 'Percentage': 0.061}},
#                    'DEU': {'Germany': {'Number': 8801, 'Percentage': 0.066}},
#                    'FRA': {'France': {'Number': 4529, 'Percentage': 0.034}},
#                    'GBR': {'United Kingdom': {'Number': 2765,
#                                               'Percentage': 0.021}},
#                    'ITA': {'Italy': {'Number': 7181, 'Percentage': 0.054}},
#                    'SWE': {'Sweden': {'Number': 2053, 'Percentage': 0.015}},
#                    'USA': {'United States of America': {'Number': 82440,
#                                                         'Percentage': 0.616}}}},
#  'El Salvador': {'SLV': {'BLZ': {'Belize': {'Number': 1125,
#                                             'Percentage': 0.01}},
#                          'CAN': {'Canada': {'Number': 12064,
#                                             'Percentage': 0.103}},
#                          'CRI': {'Costa Rica': {'Number': 2285,
#                                                 'Percentage': 0.02}},
#                          'ITA': {'Italy': {'Number': 1469,
#                                            'Percentage': 0.013}},
#                          'MEX': {'Mexico': {'Number': 9587,
#                                             'Percentage': 0.082}},
#                          'NIC': {'Nicaragua': {'Number': 1350,
#                                                'Percentage': 0.012}},
#                          'PAN': {'Panama': {'Number': 3000,
#                                             'Percentage': 0.026}},
#                          'USA': {'United States of America': {'Number': 83691,
#                                                               'Percentage': 0.716}}}},
#  'Equatorial Guinea': {'GNQ': {'BEN': {'Benin': {'Number': 58,
#                                                  'Percentage': 0.021}},
#                                'CAN': {'Canada': {'Number': 138,
#                                                   'Percentage': 0.051}},
#                                'CMR': {'Cameroon': {'Number': 184,
#                                                     'Percentage': 0.068}},
#                                'DEU': {'Germany': {'Number': 207,
#                                                    'Percentage': 0.076}},
#                                'ESP': {'Spain': {'Number': 1383,
#                                                  'Percentage': 0.509}},
#                                'FRA': {'France': {'Number': 336,
#                                                   'Percentage': 0.124}},
#                                'GAB': {'Gabon': {'Number': 132,
#                                                  'Percentage': 0.049}},
#                                'ITA': {'Italy': {'Number': 69,
#                                                  'Percentage': 0.025}},
#                                'NGA': {'Nigeria': {'Number': 30,
#                                                    'Percentage': 0.011}},
#                                'USA': {'United States of America': {'Number': 100,
#                                                                     'Percentage': 0.037}}}},
#  'Eritrea': {'ERI': {'CHE': {'Switzerland': {'Number': 142280,
#                                              'Percentage': 0.042}},
#                      'DEU': {'Germany': {'Number': 123680,
#                                          'Percentage': 0.037}},
#                      'ETH': {'Ethiopia': {'Number': 934938,
#                                           'Percentage': 0.276}},
#                      'GBR': {'United Kingdom': {'Number': 113423,
#                                                 'Percentage': 0.033}},
#                      'ISR': {'Israel': {'Number': 247265, 'Percentage': 0.073}},
#                      'ITA': {'Italy': {'Number': 116195, 'Percentage': 0.034}},
#                      'NLD': {'Netherlands': {'Number': 56404,
#                                              'Percentage': 0.017}},
#                      'NOR': {'Norway': {'Number': 87951, 'Percentage': 0.026}},
# ...
#                                                  'Percentage': 0.01}},
#                           'DEU': {'Germany': {'Number': 1438,
#                                               'Percentage': 0.221}},
#                           'FRA': {'France': {'Number': 120,
#                                              'Percentage': 0.018}},
#                           'GBR': {'United Kingdom': {'Number': 325,
#                                                      'Percentage': 0.05}},
#                           'NLD': {'Netherlands': {'Number': 187,
#                                                   'Percentage': 0.029}},
#                           'NOR': {'Norway': {'Number': 82,
#                                              'Percentage': 0.013}},
#                           'POL': {'Poland': {'Number': 124,
#                                              'Percentage': 0.019}},
#                           'RUS': {'Russian Federation': {'Number': 83,
#                                                          'Percentage': 0.013}},
#                           'SWE': {'Sweden': {'Number': 562,
#                                              'Percentage': 0.086}},
#                           'UKR': {'Ukraine': {'Number': 72,
#                                               'Percentage': 0.011}},
#                           'USA': {'United States of America': {'Number': 2790,
#                                                                'Percentage': 0.428}}}},
#  'Turks and Caicos Islands': {'TCA': {'CAN': {'Canada': {'Number': 2,
#                                                          'Percentage': 0.019}},
#                                       'USA': {'United States of America': {'Number': 104,
#                                                                            'Percentage': 0.981}}}},
#  'Tuvalu': {'TUV': {'DEU': {'Germany': {'Number': 4, 'Percentage': 0.286}},
#                     'GBR': {'United Kingdom': {'Number': 6,
#                                                'Percentage': 0.429}},
#                     'NLD': {'Netherlands': {'Number': 4,
#                                             'Percentage': 0.286}}}},
#  'Uganda': {'UGA': {'CAN': {'Canada': {'Number': 7277, 'Percentage': 0.082}},
#                     'COD': {'Dem. Rep. of the Congo': {'Number': 17962,
#                                                        'Percentage': 0.203}},
#                     'DEU': {'Germany': {'Number': 2064, 'Percentage': 0.023}},
#                     'GBR': {'United Kingdom': {'Number': 14375,
#                                                'Percentage': 0.163}},
#                     'KEN': {'Kenya': {'Number': 13403, 'Percentage': 0.152}},
#                     'NLD': {'Netherlands': {'Number': 3242,
#                                             'Percentage': 0.037}},
#                     'SDN': {'Sudan': {'Number': 1618, 'Percentage': 0.018}},
#                     'SWE': {'Sweden': {'Number': 3364, 'Percentage': 0.038}},
#                     'USA': {'United States of America': {'Number': 14472,
#                                                          'Percentage': 0.164}},
#                     'ZAF': {'South Africa': {'Number': 3340,
#                                              'Percentage': 0.038}},
#                     'ZMB': {'Zambia': {'Number': 936, 'Percentage': 0.011}}}},
#  'Ukraine': {'UKR': {'CAN': {'Canada': {'Number': 17715, 'Percentage': 0.016}},
#                      'DEU': {'Germany': {'Number': 121386,
#                                          'Percentage': 0.111}},
#                      'ITA': {'Italy': {'Number': 11242, 'Percentage': 0.01}},
#                      'RUS': {'Russian Federation': {'Number': 893070,
#                                                     'Percentage': 0.814}},
#                      'USA': {'United States of America': {'Number': 17234,
#                                                           'Percentage': 0.016}}}},
#  'United Arab Emirates': {'ARE': {'AUS': {'Australia': {'Number': 46,
#                                                         'Percentage': 0.015}},
#                                   'CAN': {'Canada': {'Number': 316,
#                                                      'Percentage': 0.106}},
#                                   'DEU': {'Germany': {'Number': 2162,
#                                                       'Percentage': 0.722}},
#                                   'GBR': {'United Kingdom': {'Number': 90,
#                                                              'Percentage': 0.03}},
#                                   'USA': {'United States of America': {'Number': 331,
#                                                                        'Percentage': 0.111}}}},
#  'United Kingdom': {'GBR': {'AUS': {'Australia': {'Number': 36,
#                                                   'Percentage': 0.023}},
#                             'CAN': {'Canada': {'Number': 581,
#                                                'Percentage': 0.368}},
#                             'DEU': {'Germany': {'Number': 130,
#                                                 'Percentage': 0.082}},
#                             'GBR': {'United Kingdom': {'Number': 23,
#                                                        'Percentage': 0.015}},
#                             'IRL': {'Ireland': {'Number': 48,
#                                                 'Percentage': 0.03}},
#                             'SWE': {'Sweden': {'Number': 47,
#                                                'Percentage': 0.03}},
#                             'USA': {'United States of America': {'Number': 683,
#                                                                  'Percentage': 0.433}}}},
#  'United Rep. of Tanzania': {'TZA': {'AUS': {'Australia': {'Number': 112,
#                                                            'Percentage': 0.01}},
#                                      'BEL': {'Belgium': {'Number': 420,
#                                                          'Percentage': 0.038}},
#                                      'CAN': {'Canada': {'Number': 4594,
#                                                         'Percentage': 0.414}},
#                                      'CHE': {'Switzerland': {'Number': 122,
#                                                              'Percentage': 0.011}},
#                                      'DEU': {'Germany': {'Number': 279,
#                                                          'Percentage': 0.025}},
#                                      'GBR': {'United Kingdom': {'Number': 1422,
#                                                                 'Percentage': 0.128}},
#                                      'SOM': {'Somalia': {'Number': 230,
#                                                          'Percentage': 0.021}},
#                                      'SWE': {'Sweden': {'Number': 244,
#                                                         'Percentage': 0.022}},
#                                      'USA': {'United States of America': {'Number': 1686,
#                                                                           'Percentage': 0.152}},
#                                      'ZAF': {'South Africa': {'Number': 1141,
#                                                               'Percentage': 0.103}}}},
#  'United States of America': {'USA': {'CAN': {'Canada': {'Number': 29178,
#                                                          'Percentage': 0.881}},
#                                       'DEU': {'Germany': {'Number': 3184,
#                                                           'Percentage': 0.096}}}},
#  'Uruguay': {'URY': {'BEL': {'Belgium': {'Number': 18, 'Percentage': 0.012}},
#                      'CAN': {'Canada': {'Number': 1203, 'Percentage': 0.791}},
#                      'DEU': {'Germany': {'Number': 89, 'Percentage': 0.059}},
#                      'ITA': {'Italy': {'Number': 33, 'Percentage': 0.022}},
#                      'USA': {'United States of America': {'Number': 133,
#                                                           'Percentage': 0.087}}}},
#  'Uzbekistan': {'UZB': {'AUT': {'Austria': {'Number': 1296,
#                                             'Percentage': 0.018}},
#                         'CAN': {'Canada': {'Number': 2640,
#                                            'Percentage': 0.036}},
#                         'CZE': {'Czech Rep.': {'Number': 826,
#                                                'Percentage': 0.011}},
#                         'DEU': {'Germany': {'Number': 12410,
#                                             'Percentage': 0.17}},
#                         'FRA': {'France': {'Number': 2223, 'Percentage': 0.03}},
#                         'KAZ': {'Kazakhstan': {'Number': 727,
#                                                'Percentage': 0.01}},
#                         'KGZ': {'Kyrgyzstan': {'Number': 12593,
#                                                'Percentage': 0.173}},
#                         'NLD': {'Netherlands': {'Number': 1870,
#                                                 'Percentage': 0.026}},
#                         'NOR': {'Norway': {'Number': 1587,
#                                            'Percentage': 0.022}},
#                         'RUS': {'Russian Federation': {'Number': 885,
#                                                        'Percentage': 0.012}},
#                         'SWE': {'Sweden': {'Number': 13842,
#                                            'Percentage': 0.19}},
#                         'USA': {'United States of America': {'Number': 16857,
#                                                              'Percentage': 0.231}}}},
#  'Vanuatu': {'VUT': {'AUS': {'Australia': {'Number': 7, 'Percentage': 0.875}},
#                      'CAN': {'Canada': {'Number': 1, 'Percentage': 0.125}}}},
#  'Various/Unknown': {None: {'BEL': {'Belgium': {'Number': 56019,
#                                                 'Percentage': 0.033}},
#                             'CRI': {'Costa Rica': {'Number': 44185,
#                                                    'Percentage': 0.026}},
#                             'DEU': {'Germany': {'Number': 156279,
#                                                 'Percentage': 0.093}},
#                             'ECU': {'Ecuador': {'Number': 46930,
#                                                 'Percentage': 0.028}},
#                             'FRA': {'France': {'Number': 567643,
#                                                'Percentage': 0.337}},
#                             'GBR': {'United Kingdom': {'Number': 511807,
#                                                        'Percentage': 0.304}},
#                             'GRC': {'Greece': {'Number': 17565,
#                                                'Percentage': 0.01}},
#                             'ITA': {'Italy': {'Number': 24888,
#                                               'Percentage': 0.015}},
#                             'LUX': {'Luxembourg': {'Number': 18104,
#                                                    'Percentage': 0.011}},
#                             'NLD': {'Netherlands': {'Number': 34079,
#                                                     'Percentage': 0.02}},
#                             'USA': {'United States of America': {'Number': 27039,
#                                                                  'Percentage': 0.016}},
#                             'ZAF': {'South Africa': {'Number': 79332,
#                                                      'Percentage': 0.047}}}},
#  'Venezuela (Bolivarian Republic of)': {'VEN': {'CAN': {'Canada': {'Number': 9250,
#                                                                    'Percentage': 0.115}},
#                                                 'CRI': {'Costa Rica': {'Number': 2317,
#                                                                        'Percentage': 0.029}},
#                                                 'MEX': {'Mexico': {'Number': 1563,
#                                                                    'Percentage': 0.019}},
#                                                 'USA': {'United States of America': {'Number': 63952,
#                                                                                      'Percentage': 0.797}}}},
#  'Viet Nam': {'VNM': {'CHN': {'China': {'Number': 3346670,
#                                         'Percentage': 0.926}},
#                       'DEU': {'Germany': {'Number': 132349,
#                                           'Percentage': 0.037}},
#                       'FRA': {'France': {'Number': 92860,
#                                          'Percentage': 0.026}}}},
#  'Wallis and Futuna Islands ': {'VNM': {}},
#  'Western Sahara': {'ESH': {'DZA': {'Algeria': {'Number': 990000,
#                                                 'Percentage': 0.772}},
#                             'MRT': {'Mauritania': {'Number': 286011,
#                                                    'Percentage': 0.223}}}},
#  'Yemen': {'YEM': {'CAN': {'Canada': {'Number': 3504, 'Percentage': 0.047}},
#                    'CHE': {'Switzerland': {'Number': 2808,
#                                            'Percentage': 0.037}},
#                    'DEU': {'Germany': {'Number': 4110, 'Percentage': 0.055}},
#                    'DJI': {'Djibouti': {'Number': 13411, 'Percentage': 0.178}},
#                    'EGY': {'Egypt': {'Number': 1849, 'Percentage': 0.025}},
#                    'ETH': {'Ethiopia': {'Number': 4302, 'Percentage': 0.057}},
#                    'GBR': {'United Kingdom': {'Number': 2423,
#                                               'Percentage': 0.032}},
#                    'JOR': {'Jordan': {'Number': 758, 'Percentage': 0.01}},
#                    'MAR': {'Morocco': {'Number': 1467, 'Percentage': 0.019}},
#                    'NLD': {'Netherlands': {'Number': 776, 'Percentage': 0.01}},
#                    'NOR': {'Norway': {'Number': 1405, 'Percentage': 0.019}},
#                    'SOM': {'Somalia': {'Number': 24221, 'Percentage': 0.322}},
#                    'SWE': {'Sweden': {'Number': 4817, 'Percentage': 0.064}},
#                    'USA': {'United States of America': {'Number': 4327,
#                                                         'Percentage': 0.058}}}},
#  'Zambia': {'ZMB': {'AGO': {'Angola': {'Number': 35, 'Percentage': 0.013}},
#                     'AUS': {'Australia': {'Number': 72, 'Percentage': 0.027}},
#                     'CAN': {'Canada': {'Number': 501, 'Percentage': 0.185}},
#                     'DEU': {'Germany': {'Number': 119, 'Percentage': 0.044}},
#                     'GBR': {'United Kingdom': {'Number': 439,
#                                                'Percentage': 0.162}},
#                     'IRL': {'Ireland': {'Number': 46, 'Percentage': 0.017}},
#                     'ITA': {'Italy': {'Number': 29, 'Percentage': 0.011}},
#                     'NLD': {'Netherlands': {'Number': 39, 'Percentage': 0.014}},
#                     'SWE': {'Sweden': {'Number': 52, 'Percentage': 0.019}},
#                     'USA': {'United States of America': {'Number': 913,
#                                                          'Percentage': 0.336}},
#                     'ZAF': {'South Africa': {'Number': 415,
#                                              'Percentage': 0.153}}}},
#  'Zimbabwe': {'ZWE': {'AUS': {'Australia': {'Number': 8649,
#                                             'Percentage': 0.039}},
#                       'BWA': {'Botswana': {'Number': 8406,
#                                            'Percentage': 0.038}},
#                       'CAN': {'Canada': {'Number': 34332, 'Percentage': 0.153}},
#                       'GBR': {'United Kingdom': {'Number': 120397,
#                                                  'Percentage': 0.537}},
#                       'IRL': {'Ireland': {'Number': 3263, 'Percentage': 0.015}},
#                       'USA': {'United States of America': {'Number': 16567,
#                                                            'Percentage': 0.074}},
#                       'ZAF': {'South Africa': {'Number': 27805,
#                                                'Percentage': 0.124}}}}}

# %% [markdown]
# # Country of Origin vs Destination Asylum Seekers 2007-2017

# %%
#Separate the seekers
seekers_df = complete_df.loc[complete_df['Type']=='Asylum-seekers',:]
seekers_df.reset_index(drop=True, inplace=True)
seekers_df.describe()
#88,033 rows
# Out:
#                Year          Value
# count  88033.000000   88033.000000
# mean    2010.306419     268.591028
# std        4.790444    4545.877383
# min     2000.000000      -1.000000
# 25%     2007.000000       1.000000
# 50%     2011.000000       3.000000
# 75%     2014.000000      23.000000
# max     2017.000000  940668.000000

# %%
# Create a df that just has COO asylum seeker totals 2007-2017
del seekers_df['Type']
seekers_2 = seekers_df.loc[seekers_df['Year'] >= 2007,:]
origins_as = seekers_2.groupby('Origin')
origins_as = origins_as['Value'].sum()
origins_as = pd.DataFrame(origins_as)
origins_as.to_csv("origins_as.csv")

# There are 222 rows in origins

# %%
# Create a df that has COO x COD asylum seeker totals 2007-2017
ref_dyads_as = seekers_2.groupby(['Origin', 'Destination'])
ref_dyads_as = ref_dyads_as['Value'].sum()
ref_dyads_as = pd.DataFrame(ref_dyads_as)
ref_dyads_as.head()
ref_dyads_as.to_csv('ref_dyads_as.csv')

# There should be 10,384 rows here!

# %%
# Merge uq_names AND uq_names_org with ref_dyads_as 
ref_dyads_as.reset_index(drop=False, inplace=True)
ref_dyads_as_2 = ref_dyads_as.merge(uq_names, left_on="Destination", right_on="country_name", how="left")
del ref_dyads_as_2['country_name']

ref_dyads_as_3 = ref_dyads_as_2.merge(uq_names_org, left_on="Origin", right_on="country_name", how="left")
ref_dyads_as_3
del ref_dyads_as_3['country_name']
#ref_dyads_as_3.head()

seekers_4 = ref_dyads_as_3.merge(origins_as, left_on="Origin", right_on="Origin", how="left")
seekers_4 = seekers_4.rename(columns={'Value_x': 'COO_COD', 'Value_y': 'COO_total'})
seekers_4.to_csv('seekers_4.csv')

# Execute a double_sort on Value and country of origin
seekers_4['Pct'] = seekers_4['COO_COD'] / seekers_4['COO_total'] 

seekers_4 = seekers_4.sort_values(['Origin', 'Pct'], ascending=[True, False])
seekers_4.reset_index(drop=True, inplace=True)
seekers_4.to_csv('seekers_4.csv')
seekers_4['Pct'] = round(seekers_4['Pct'], 3)

# %%
del seekers_4['level_0']
del seekers_4['index']
seekers_4.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-84e7a4a2d921> in <module>()
# ----> 1 del seekers_4['level_0']
#       2 del seekers_4['index']
#       3 seekers_4.head()
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    2738             # there was no match, this call should raise the appropriate
#    2739             # exception:
# -> 2740             self._data.delete(key)
#    2741
#    2742         # delete from the caches
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in delete(self, item)
#    4172         Delete selected item (items if non-unique) in-place.
#    4173         """
# -> 4174         indexer = self.items.get_loc(item)
#    4175
#    4176         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'

# %%
# Take the dataframe 'seekers_4' and jsonify
temp_df = pd.DataFrame()
coo_cod_as_array = {}

for country in seekers_4['Origin'].unique():
    temp_df = seekers_4.loc[seekers_4['Origin']==country,:]
    temp_df = temp_df.loc[temp_df['Pct'] >= 0.01,:]
    temp_array = {}
    for x in range(len(temp_df)):
        row = temp_df.iloc[x,:]
        temp_array[row[3]] = {row[1]: {'Number': row[2], 'Percentage': row[6]}}
        ocode = row[4]
    coo_cod_as_array[country] = {ocode: temp_array}
    
pprint(coo_cod_as_array)
# Out:
# {'Afghanistan': {'AFG': {'AUT': {'Austria': {'Number': 111338,
#                                              'Percentage': 0.083}},
#                          'BEL': {'Belgium': {'Number': 17036,
#                                              'Percentage': 0.013}},
#                          'BGR': {'Bulgaria': {'Number': 16740,
#                                               'Percentage': 0.013}},
#                          'CHE': {'Switzerland': {'Number': 29923,
#                                                  'Percentage': 0.022}},
#                          'DEU': {'Germany': {'Number': 331927,
#                                              'Percentage': 0.248}},
#                          'GBR': {'United Kingdom': {'Number': 13664,
#                                                     'Percentage': 0.01}},
#                          'GRC': {'Greece': {'Number': 23028,
#                                             'Percentage': 0.017}},
#                          'HUN': {'Hungary': {'Number': 13747,
#                                              'Percentage': 0.01}},
#                          'IDN': {'Indonesia': {'Number': 23031,
#                                                'Percentage': 0.017}},
#                          'IND': {'India': {'Number': 20179,
#                                            'Percentage': 0.015}},
#                          'NOR': {'Norway': {'Number': 20979,
#                                             'Percentage': 0.016}},
#                          'PAK': {'Pakistan': {'Number': 38780,
#                                               'Percentage': 0.029}},
#                          'SWE': {'Sweden': {'Number': 105158,
#                                             'Percentage': 0.079}},
#                          'TUR': {'Turkey': {'Number': 442448,
#                                             'Percentage': 0.331}},
#                          'UKR': {'Ukraine': {'Number': 19576,
#                                              'Percentage': 0.015}}}},
#  'Albania': {'ALB': {'AUT': {'Austria': {'Number': 1699, 'Percentage': 0.014}},
#                      'BEL': {'Belgium': {'Number': 2496, 'Percentage': 0.02}},
#                      'CAN': {'Canada': {'Number': 4289, 'Percentage': 0.035}},
#                      'DEU': {'Germany': {'Number': 57280, 'Percentage': 0.469}},
#                      'FRA': {'France': {'Number': 19181, 'Percentage': 0.157}},
#                      'GBR': {'United Kingdom': {'Number': 11644,
#                                                 'Percentage': 0.095}},
#                      'GRC': {'Greece': {'Number': 6496, 'Percentage': 0.053}},
#                      'IRL': {'Ireland': {'Number': 2090, 'Percentage': 0.017}},
#                      'ITA': {'Italy': {'Number': 1612, 'Percentage': 0.013}},
#                      'SWE': {'Sweden': {'Number': 4928, 'Percentage': 0.04}},
#                      'USA': {'United States of America': {'Number': 7184,
#                                                           'Percentage': 0.059}}}},
#  'Algeria': {'DZA': {'AUT': {'Austria': {'Number': 3618, 'Percentage': 0.087}},
#                      'BEL': {'Belgium': {'Number': 601, 'Percentage': 0.014}},
#                      'CAN': {'Canada': {'Number': 1860, 'Percentage': 0.044}},
#                      'CHE': {'Switzerland': {'Number': 1878,
#                                              'Percentage': 0.045}},
#                      'DEU': {'Germany': {'Number': 14154, 'Percentage': 0.339}},
#                      'ESP': {'Spain': {'Number': 1408, 'Percentage': 0.034}},
#                      'FRA': {'France': {'Number': 6103, 'Percentage': 0.146}},
#                      'GBR': {'United Kingdom': {'Number': 1432,
#                                                 'Percentage': 0.034}},
#                      'GRC': {'Greece': {'Number': 1290, 'Percentage': 0.031}},
#                      'IRL': {'Ireland': {'Number': 1331, 'Percentage': 0.032}},
#                      'ITA': {'Italy': {'Number': 535, 'Percentage': 0.013}},
#                      'NLD': {'Netherlands': {'Number': 640,
#                                              'Percentage': 0.015}},
#                      'NOR': {'Norway': {'Number': 433, 'Percentage': 0.01}},
#                      'SWE': {'Sweden': {'Number': 1687, 'Percentage': 0.04}},
#                      'USA': {'United States of America': {'Number': 706,
#                                                           'Percentage': 0.017}},
#                      'ZAF': {'South Africa': {'Number': 981,
#                                               'Percentage': 0.023}}}},
#  'American Samoa': {'ASM': {'AUS': {'Australia': {'Number': 3,
#                                                   'Percentage': 1.0}}}},
#  'Andorra': {'AND': {'AUS': {'Australia': {'Number': 6, 'Percentage': 0.333}},
#                      'AUT': {'Austria': {'Number': 1, 'Percentage': 0.056}},
#                      'DEU': {'Germany': {'Number': 1, 'Percentage': 0.056}},
#                      'ECU': {'Ecuador': {'Number': 10, 'Percentage': 0.556}}}},
#  'Angola': {'AGO': {'AUT': {'Austria': {'Number': 270, 'Percentage': 0.011}},
#                     'BEL': {'Belgium': {'Number': 565, 'Percentage': 0.024}},
#                     'BRA': {'Brazil': {'Number': 8544, 'Percentage': 0.356}},
#                     'CAN': {'Canada': {'Number': 454, 'Percentage': 0.019}},
#                     'CHE': {'Switzerland': {'Number': 766,
#                                             'Percentage': 0.032}},
#                     'COG': {'Congo': {'Number': 571, 'Percentage': 0.024}},
#                     'DEU': {'Germany': {'Number': 2291, 'Percentage': 0.095}},
#                     'ESP': {'Spain': {'Number': 337, 'Percentage': 0.014}},
#                     'FRA': {'France': {'Number': 3219, 'Percentage': 0.134}},
#                     'GBR': {'United Kingdom': {'Number': 409,
#                                                'Percentage': 0.017}},
#                     'IRL': {'Ireland': {'Number': 456, 'Percentage': 0.019}},
#                     'NLD': {'Netherlands': {'Number': 249, 'Percentage': 0.01}},
#                     'USA': {'United States of America': {'Number': 3078,
#                                                          'Percentage': 0.128}},
#                     'ZAF': {'South Africa': {'Number': 648,
#                                              'Percentage': 0.027}}}},
#  'Anguilla': {'AGO': {}},
#  'Antigua and Barbuda': {'ATG': {'CAN': {'Canada': {'Number': 257,
#                                                     'Percentage': 0.829}},
#                                  'GBR': {'United Kingdom': {'Number': 12,
#                                                             'Percentage': 0.039}},
#                                  'ITA': {'Italy': {'Number': 8,
#                                                    'Percentage': 0.026}},
#                                  'USA': {'United States of America': {'Number': 31,
#                                                                       'Percentage': 0.1}}}},
#  'Argentina': {'ARG': {'AUS': {'Australia': {'Number': 38,
#                                              'Percentage': 0.024}},
#                        'BRA': {'Brazil': {'Number': 61, 'Percentage': 0.039}},
#                        'CAN': {'Canada': {'Number': 331, 'Percentage': 0.213}},
#                        'DEU': {'Germany': {'Number': 20, 'Percentage': 0.013}},
#                        'ECU': {'Ecuador': {'Number': 42, 'Percentage': 0.027}},
#                        'ESP': {'Spain': {'Number': 28, 'Percentage': 0.018}},
#                        'ITA': {'Italy': {'Number': 18, 'Percentage': 0.012}},
#                        'SWE': {'Sweden': {'Number': 22, 'Percentage': 0.014}},
#                        'URY': {'Uruguay': {'Number': 21, 'Percentage': 0.014}},
#                        'USA': {'United States of America': {'Number': 870,
#                                                             'Percentage': 0.561}}}},
#  'Armenia': {'ARM': {'AUT': {'Austria': {'Number': 9594, 'Percentage': 0.139}},
#                      'BEL': {'Belgium': {'Number': 1079, 'Percentage': 0.016}},
#                      'CHE': {'Switzerland': {'Number': 1077,
#                                              'Percentage': 0.016}},
#                      'DEU': {'Germany': {'Number': 31256, 'Percentage': 0.452}},
#                      'FRA': {'France': {'Number': 6613, 'Percentage': 0.096}},
#                      'NLD': {'Netherlands': {'Number': 2543,
#                                              'Percentage': 0.037}},
#                      'SWE': {'Sweden': {'Number': 3020, 'Percentage': 0.044}},
#                      'USA': {'United States of America': {'Number': 8526,
#                                                           'Percentage': 0.123}}}},
#  'Aruba': {'ABW': {'CAN': {'Canada': {'Number': 1, 'Percentage': 1.0}}}},
#  'Australia': {'AUS': {'AUS': {'Australia': {'Number': 2, 'Percentage': 0.023}},
#                        'AUT': {'Austria': {'Number': 7, 'Percentage': 0.08}},
#                        'BGR': {'Bulgaria': {'Number': 2, 'Percentage': 0.023}},
#                        'CAN': {'Canada': {'Number': 48, 'Percentage': 0.545}},
#                        'CHE': {'Switzerland': {'Number': 1,
#                                                'Percentage': 0.011}},
#                        'CRI': {'Costa Rica': {'Number': 4,
#                                               'Percentage': 0.045}},
#                        'DEU': {'Germany': {'Number': 5, 'Percentage': 0.057}},
#                        'GBR': {'United Kingdom': {'Number': 11,
#                                                   'Percentage': 0.125}},
#                        'ITA': {'Italy': {'Number': 1, 'Percentage': 0.011}},
#                        'NLD': {'Netherlands': {'Number': 2,
#                                                'Percentage': 0.023}},
#                        'NPL': {'Nepal': {'Number': 1, 'Percentage': 0.011}},
#                        'NZL': {'New Zealand': {'Number': 1,
#                                                'Percentage': 0.011}},
#                        'USA': {'United States of America': {'Number': 3,
#                                                             'Percentage': 0.034}}}},
#  'Austria': {'AUT': {'AUS': {'Australia': {'Number': 3, 'Percentage': 0.045}},
#                      'CAN': {'Canada': {'Number': 30, 'Percentage': 0.448}},
#                      'DEU': {'Germany': {'Number': 4, 'Percentage': 0.06}},
#                      'ECU': {'Ecuador': {'Number': 2, 'Percentage': 0.03}},
#                      'IRL': {'Ireland': {'Number': 3, 'Percentage': 0.045}},
#                      'USA': {'United States of America': {'Number': 25,
#                                                           'Percentage': 0.373}}}},
#  'Azerbaijan': {'AZE': {'AUT': {'Austria': {'Number': 2309,
#                                             'Percentage': 0.053}},
#                         'BEL': {'Belgium': {'Number': 484,
#                                             'Percentage': 0.011}},
#                         'CAN': {'Canada': {'Number': 840, 'Percentage': 0.019}},
#                         'DEU': {'Germany': {'Number': 27260,
#                                             'Percentage': 0.623}},
#                         'FRA': {'France': {'Number': 3641,
#                                            'Percentage': 0.083}},
#                         'NLD': {'Netherlands': {'Number': 774,
#                                                 'Percentage': 0.018}},
#                         'NOR': {'Norway': {'Number': 436, 'Percentage': 0.01}},
#                         'SWE': {'Sweden': {'Number': 4040,
#                                            'Percentage': 0.092}},
#                         'USA': {'United States of America': {'Number': 1966,
#                                                              'Percentage': 0.045}}}},
#  'Bahamas': {'BHS': {'CAN': {'Canada': {'Number': 469, 'Percentage': 0.681}},
#                      'ITA': {'Italy': {'Number': 9, 'Percentage': 0.013}},
#                      'USA': {'United States of America': {'Number': 190,
#                                                           'Percentage': 0.276}},
#                      'ZAF': {'South Africa': {'Number': 11,
#                                               'Percentage': 0.016}}}},
#  'Bahrain': {'BHR': {'AUS': {'Australia': {'Number': 108, 'Percentage': 0.137}},
#                      'CAN': {'Canada': {'Number': 72, 'Percentage': 0.091}},
#                      'CHE': {'Switzerland': {'Number': 22,
#                                              'Percentage': 0.028}},
#                      'DEU': {'Germany': {'Number': 93, 'Percentage': 0.118}},
#                      'GBR': {'United Kingdom': {'Number': 122,
#                                                 'Percentage': 0.155}},
#                      'IRL': {'Ireland': {'Number': 34, 'Percentage': 0.043}},
#                      'IRQ': {'Iraq': {'Number': 46, 'Percentage': 0.058}},
#                      'LBN': {'Lebanon': {'Number': 49, 'Percentage': 0.062}},
#                      'NLD': {'Netherlands': {'Number': 8, 'Percentage': 0.01}},
#                      'NZL': {'New Zealand': {'Number': 8, 'Percentage': 0.01}},
#                      'SWE': {'Sweden': {'Number': 61, 'Percentage': 0.077}},
#                      'SYR': {'Syrian Arab Rep.': {'Number': 10,
#                                                   'Percentage': 0.013}},
#                      'THA': {'Thailand': {'Number': 9, 'Percentage': 0.011}},
#                      'USA': {'United States of America': {'Number': 121,
#                                                           'Percentage': 0.154}}}},
#  'Bangladesh': {'BGD': {'AUS': {'Australia': {'Number': 3849,
#                                               'Percentage': 0.019}},
#                         'AUT': {'Austria': {'Number': 4428,
#                                             'Percentage': 0.022}},
#                         'BRA': {'Brazil': {'Number': 9562,
#                                            'Percentage': 0.047}},
#                         'CAN': {'Canada': {'Number': 2822,
#                                            'Percentage': 0.014}},
#                         'DEU': {'Germany': {'Number': 10227,
#                                             'Percentage': 0.05}},
#                         'FRA': {'France': {'Number': 15999,
#                                            'Percentage': 0.078}},
#                         'GBR': {'United Kingdom': {'Number': 6886,
#                                                    'Percentage': 0.034}},
#                         'GRC': {'Greece': {'Number': 15873,
#                                            'Percentage': 0.077}},
#                         'ITA': {'Italy': {'Number': 33299,
#                                           'Percentage': 0.162}},
#                         'JPN': {'Japan': {'Number': 3733, 'Percentage': 0.018}},
#                         'SWE': {'Sweden': {'Number': 2068, 'Percentage': 0.01}},
#                         'USA': {'United States of America': {'Number': 17687,
#                                                              'Percentage': 0.086}},
#                         'ZAF': {'South Africa': {'Number': 64319,
#                                                  'Percentage': 0.313}}}},
#  'Barbados': {'BRB': {'CAN': {'Canada': {'Number': 480, 'Percentage': 0.863}},
#                       'GBR': {'United Kingdom': {'Number': 37,
#                                                  'Percentage': 0.067}},
#                       'GRC': {'Greece': {'Number': 11, 'Percentage': 0.02}},
#                       'USA': {'United States of America': {'Number': 23,
#                                                            'Percentage': 0.041}}}},
#  'Belarus': {'BLR': {'AUT': {'Austria': {'Number': 933, 'Percentage': 0.066}},
#                      'BEL': {'Belgium': {'Number': 191, 'Percentage': 0.014}},
#                      'CAN': {'Canada': {'Number': 319, 'Percentage': 0.023}},
#                      'CHE': {'Switzerland': {'Number': 438,
#                                              'Percentage': 0.031}},
#                      'CZE': {'Czech Rep.': {'Number': 625,
#                                             'Percentage': 0.044}},
#                      'DEU': {'Germany': {'Number': 1929, 'Percentage': 0.137}},
#                      'FIN': {'Finland': {'Number': 211, 'Percentage': 0.015}},
#                      'FRA': {'France': {'Number': 208, 'Percentage': 0.015}},
#                      'IRL': {'Ireland': {'Number': 172, 'Percentage': 0.012}},
#                      'NLD': {'Netherlands': {'Number': 324,
#                                              'Percentage': 0.023}},
#                      'NOR': {'Norway': {'Number': 141, 'Percentage': 0.01}},
#                      'POL': {'Poland': {'Number': 403, 'Percentage': 0.029}},
#                      'SWE': {'Sweden': {'Number': 2571, 'Percentage': 0.183}},
#                      'UKR': {'Ukraine': {'Number': 203, 'Percentage': 0.014}},
#                      'USA': {'United States of America': {'Number': 4430,
#                                                           'Percentage': 0.315}}}},
#  'Belgium': {'BEL': {'AUS': {'Australia': {'Number': 9, 'Percentage': 0.038}},
#                      'BRA': {'Brazil': {'Number': 6, 'Percentage': 0.026}},
#                      'CAN': {'Canada': {'Number': 95, 'Percentage': 0.404}},
#                      'DEU': {'Germany': {'Number': 12, 'Percentage': 0.051}},
#                      'MWI': {'Malawi': {'Number': 6, 'Percentage': 0.026}},
#                      'USA': {'United States of America': {'Number': 95,
#                                                           'Percentage': 0.404}}}},
#  'Belize': {'BLZ': {'CAN': {'Canada': {'Number': 55, 'Percentage': 0.079}},
#                     'GBR': {'United Kingdom': {'Number': 9,
#                                                'Percentage': 0.013}},
#                     'MEX': {'Mexico': {'Number': 23, 'Percentage': 0.033}},
#                     'USA': {'United States of America': {'Number': 594,
#                                                          'Percentage': 0.857}}}},
#  'Benin': {'BEN': {'AUT': {'Austria': {'Number': 223, 'Percentage': 0.036}},
#                    'BEL': {'Belgium': {'Number': 407, 'Percentage': 0.066}},
#                    'BRA': {'Brazil': {'Number': 506, 'Percentage': 0.082}},
#                    'CAN': {'Canada': {'Number': 150, 'Percentage': 0.024}},
#                    'CHE': {'Switzerland': {'Number': 160, 'Percentage': 0.026}},
#                    'DEU': {'Germany': {'Number': 2434, 'Percentage': 0.393}},
#                    'FRA': {'France': {'Number': 90, 'Percentage': 0.015}},
#                    'IRL': {'Ireland': {'Number': 134, 'Percentage': 0.022}},
#                    'ITA': {'Italy': {'Number': 655, 'Percentage': 0.106}},
#                    'MAR': {'Morocco': {'Number': 78, 'Percentage': 0.013}},
#                    'USA': {'United States of America': {'Number': 582,
#                                                         'Percentage': 0.094}},
#                    'ZAF': {'South Africa': {'Number': 228,
#                                             'Percentage': 0.037}}}},
#  'Bermuda': {'BMU': {'CAN': {'Canada': {'Number': 12, 'Percentage': 0.923}},
#                      'GBR': {'United Kingdom': {'Number': 1,
#                                                 'Percentage': 0.077}}}},
#  'Bhutan': {'BTN': {'BRA': {'Brazil': {'Number': 136, 'Percentage': 0.019}},
#                     'DEU': {'Germany': {'Number': 166, 'Percentage': 0.023}},
#                     'FRA': {'France': {'Number': 182, 'Percentage': 0.025}},
#                     'IRL': {'Ireland': {'Number': 300, 'Percentage': 0.042}},
#                     'NOR': {'Norway': {'Number': 98, 'Percentage': 0.014}},
#                     'NPL': {'Nepal': {'Number': 5261, 'Percentage': 0.735}},
#                     'USA': {'United States of America': {'Number': 745,
#                                                          'Percentage': 0.104}}}},
#  'Bolivia (Plurinational State of)': {'BOL': {'AUT': {'Austria': {'Number': 75,
#                                                                   'Percentage': 0.023}},
#                                               'BRA': {'Brazil': {'Number': 545,
#                                                                  'Percentage': 0.164}},
#                                               'CAN': {'Canada': {'Number': 202,
#                                                                  'Percentage': 0.061}},
#                                               'CHL': {'Chile': {'Number': 104,
#                                                                 'Percentage': 0.031}},
#                                               'ECU': {'Ecuador': {'Number': 49,
#                                                                   'Percentage': 0.015}},
#                                               'ESP': {'Spain': {'Number': 38,
#                                                                 'Percentage': 0.011}},
#                                               'GBR': {'United Kingdom': {'Number': 87,
#                                                                          'Percentage': 0.026}},
#                                               'IRL': {'Ireland': {'Number': 75,
#                                                                   'Percentage': 0.023}},
#                                               'SWE': {'Sweden': {'Number': 639,
#                                                                  'Percentage': 0.193}},
#                                               'USA': {'United States of America': {'Number': 1337,
#                                                                                    'Percentage': 0.403}},
#                                               'VEN': {'Venezuela (Bolivarian Republic of)': {'Number': 42,
#                                                                                              'Percentage': 0.013}}}},
#  'Bosnia and Herzegovina': {'BIH': {'AUT': {'Austria': {'Number': 2201,
#                                                         'Percentage': 0.068}},
#                                     'BEL': {'Belgium': {'Number': 309,
#                                                         'Percentage': 0.01}},
#                                     'CAN': {'Canada': {'Number': 452,
#                                                        'Percentage': 0.014}},
#                                     'CHE': {'Switzerland': {'Number': 1349,
#                                                             'Percentage': 0.042}},
#                                     'DEU': {'Germany': {'Number': 21366,
#                                                         'Percentage': 0.659}},
#                                     'FRA': {'France': {'Number': 1409,
#                                                        'Percentage': 0.043}},
#                                     'ITA': {'Italy': {'Number': 1125,
#                                                       'Percentage': 0.035}},
#                                     'SWE': {'Sweden': {'Number': 2389,
#                                                        'Percentage': 0.074}},
#                                     'USA': {'United States of America': {'Number': 636,
#                                                                          'Percentage': 0.02}}}},
#  'Botswana': {'BWA': {'CAN': {'Canada': {'Number': 949, 'Percentage': 0.705}},
#                       'DEU': {'Germany': {'Number': 42, 'Percentage': 0.031}},
#                       'GBR': {'United Kingdom': {'Number': 124,
#                                                  'Percentage': 0.092}},
#                       'IRL': {'Ireland': {'Number': 72, 'Percentage': 0.053}},
#                       'USA': {'United States of America': {'Number': 29,
#                                                            'Percentage': 0.022}},
#                       'ZAF': {'South Africa': {'Number': 79,
#                                                'Percentage': 0.059}}}},
#  'Brazil': {'BRA': {'CAN': {'Canada': {'Number': 1264, 'Percentage': 0.078}},
#                     'GBR': {'United Kingdom': {'Number': 156,
#                                                'Percentage': 0.01}},
#                     'IRL': {'Ireland': {'Number': 176, 'Percentage': 0.011}},
#                     'ITA': {'Italy': {'Number': 255, 'Percentage': 0.016}},
#                     'USA': {'United States of America': {'Number': 13803,
#                                                          'Percentage': 0.85}}}},
#  'British Virgin Islands': {'VGB': {'DEU': {'Germany': {'Number': 1,
#                                                         'Percentage': 1.0}}}},
#  'Brunei Darussalam': {'BRN': {'AUS': {'Australia': {'Number': 18,
#                                                      'Percentage': 0.818}},
#                                'CAN': {'Canada': {'Number': 1,
#                                                   'Percentage': 0.045}},
#                                'CHE': {'Switzerland': {'Number': 2,
#                                                        'Percentage': 0.091}},
#                                'FIN': {'Finland': {'Number': 1,
#                                                    'Percentage': 0.045}}}},
#  'Bulgaria': {'BGR': {'AUT': {'Austria': {'Number': 94, 'Percentage': 0.034}},
#                       'BEL': {'Belgium': {'Number': 46, 'Percentage': 0.017}},
#                       'CAN': {'Canada': {'Number': 522, 'Percentage': 0.191}},
#                       'CHE': {'Switzerland': {'Number': 89,
#                                               'Percentage': 0.032}},
#                       'DEU': {'Germany': {'Number': 244, 'Percentage': 0.089}},
#                       'FIN': {'Finland': {'Number': 209, 'Percentage': 0.076}},
#                       'SWE': {'Sweden': {'Number': 86, 'Percentage': 0.031}},
#                       'USA': {'United States of America': {'Number': 1299,
#                                                            'Percentage': 0.474}}}},
#  'Burkina Faso': {'BFA': {'BEL': {'Belgium': {'Number': 341,
#                                               'Percentage': 0.02}},
#                           'BRA': {'Brazil': {'Number': 392,
#                                              'Percentage': 0.023}},
#                           'CAN': {'Canada': {'Number': 238,
#                                              'Percentage': 0.014}},
#                           'DEU': {'Germany': {'Number': 1931,
#                                               'Percentage': 0.112}},
#                           'FRA': {'France': {'Number': 619,
#                                              'Percentage': 0.036}},
#                           'GRC': {'Greece': {'Number': 502,
#                                              'Percentage': 0.029}},
#                           'ITA': {'Italy': {'Number': 2755,
#                                             'Percentage': 0.159}},
#                           'USA': {'United States of America': {'Number': 9258,
#                                                                'Percentage': 0.535}}}},
#  'Burundi': {'BDI': {'CAN': {'Canada': {'Number': 3047, 'Percentage': 0.016}},
#                      'COD': {'Dem. Rep. of the Congo': {'Number': 5427,
#                                                         'Percentage': 0.028}},
#                      'KEN': {'Kenya': {'Number': 41674, 'Percentage': 0.215}},
#                      'MOZ': {'Mozambique': {'Number': 29872,
#                                             'Percentage': 0.154}},
#                      'MWI': {'Malawi': {'Number': 34103, 'Percentage': 0.176}},
#                      'TZA': {'United Rep. of Tanzania': {'Number': 25223,
#                                                          'Percentage': 0.13}},
#                      'UGA': {'Uganda': {'Number': 20375, 'Percentage': 0.105}},
#                      'USA': {'United States of America': {'Number': 2824,
#                                                           'Percentage': 0.015}},
#                      'ZAF': {'South Africa': {'Number': 16644,
#                                               'Percentage': 0.086}},
#                      'ZMB': {'Zambia': {'Number': 2896, 'Percentage': 0.015}}}},
#  'Cabo Verde': {'CPV': {'BRA': {'Brazil': {'Number': 347, 'Percentage': 0.695}},
#                         'CHE': {'Switzerland': {'Number': 11,
#                                                 'Percentage': 0.022}},
#                         'DEU': {'Germany': {'Number': 5, 'Percentage': 0.01}},
#                         'ECU': {'Ecuador': {'Number': 8, 'Percentage': 0.016}},
#                         'GBR': {'United Kingdom': {'Number': 10,
#                                                    'Percentage': 0.02}},
#                         'IRL': {'Ireland': {'Number': 15, 'Percentage': 0.03}},
#                         'SWE': {'Sweden': {'Number': 8, 'Percentage': 0.016}},
#                         'USA': {'United States of America': {'Number': 71,
#                                                              'Percentage': 0.142}}}},
#  'Cambodia': {'KHM': {'AUS': {'Australia': {'Number': 502,
#                                             'Percentage': 0.119}},
#                       'CAN': {'Canada': {'Number': 370, 'Percentage': 0.087}},
#                       'DEU': {'Germany': {'Number': 236, 'Percentage': 0.056}},
#                       'FRA': {'France': {'Number': 148, 'Percentage': 0.035}},
#                       'JPN': {'Japan': {'Number': 1231, 'Percentage': 0.291}},
#                       'KOR': {'Rep. of Korea': {'Number': 43,
#                                                 'Percentage': 0.01}},
#                       'MYS': {'Malaysia': {'Number': 315, 'Percentage': 0.074}},
#                       'THA': {'Thailand': {'Number': 793, 'Percentage': 0.187}},
#                       'USA': {'United States of America': {'Number': 470,
#                                                            'Percentage': 0.111}}}},
#  'Cameroon': {'CMR': {'AUT': {'Austria': {'Number': 1151, 'Percentage': 0.017}},
#                       'BEL': {'Belgium': {'Number': 1416, 'Percentage': 0.021}},
#                       'BRA': {'Brazil': {'Number': 709, 'Percentage': 0.01}},
#                       'CAN': {'Canada': {'Number': 2157, 'Percentage': 0.032}},
#                       'CHE': {'Switzerland': {'Number': 802,
#                                               'Percentage': 0.012}},
#                       'CYP': {'Cyprus': {'Number': 1050, 'Percentage': 0.015}},
#                       'DEU': {'Germany': {'Number': 10667,
#                                           'Percentage': 0.156}},
#                       'DZA': {'Algeria': {'Number': 1770, 'Percentage': 0.026}},
#                       'ESP': {'Spain': {'Number': 1558, 'Percentage': 0.023}},
#                       'FRA': {'France': {'Number': 1922, 'Percentage': 0.028}},
#                       'GBR': {'United Kingdom': {'Number': 1015,
#                                                  'Percentage': 0.015}},
#                       'GRC': {'Greece': {'Number': 795, 'Percentage': 0.012}},
#                       'IRL': {'Ireland': {'Number': 829, 'Percentage': 0.012}},
#                       'ITA': {'Italy': {'Number': 4621, 'Percentage': 0.067}},
#                       'JPN': {'Japan': {'Number': 987, 'Percentage': 0.014}},
#                       'KOR': {'Rep. of Korea': {'Number': 661,
#                                                 'Percentage': 0.01}},
#                       'MAR': {'Morocco': {'Number': 1899, 'Percentage': 0.028}},
#                       'NGA': {'Nigeria': {'Number': 8335, 'Percentage': 0.122}},
#                       'TCD': {'Chad': {'Number': 1088, 'Percentage': 0.016}},
#                       'UKR': {'Ukraine': {'Number': 846, 'Percentage': 0.012}},
#                       'USA': {'United States of America': {'Number': 11955,
#                                                            'Percentage': 0.175}},
#                       'ZAF': {'South Africa': {'Number': 6282,
#                                                'Percentage': 0.092}}}},
#  'Canada': {'CAN': {'AUS': {'Australia': {'Number': 22, 'Percentage': 0.031}},
#                     'BEL': {'Belgium': {'Number': 7, 'Percentage': 0.01}},
#                     'CAN': {'Canada': {'Number': 92, 'Percentage': 0.129}},
#                     'ECU': {'Ecuador': {'Number': 7, 'Percentage': 0.01}},
#                     'GBR': {'United Kingdom': {'Number': 52,
#                                                'Percentage': 0.073}},
#                     'ITA': {'Italy': {'Number': 275, 'Percentage': 0.385}},
#                     'SWE': {'Sweden': {'Number': 21, 'Percentage': 0.029}},
#                     'USA': {'United States of America': {'Number': 202,
#                                                          'Percentage': 0.283}}}},
#  'Cayman Islands': {'CYM': {'CAN': {'Canada': {'Number': 2,
#                                                'Percentage': 1.0}}}},
#  'Central African Rep.': {'CAF': {'BEN': {'Benin': {'Number': 628,
#                                                     'Percentage': 0.01}},
#                                   'BFA': {'Burkina Faso': {'Number': 706,
#                                                            'Percentage': 0.011}},
#                                   'CIV': {"CÌ«te d'Ivoire": {'Number': 644,
#                                                              'Percentage': 0.01}},
#                                   'CMR': {'Cameroon': {'Number': 32776,
#                                                        'Percentage': 0.506}},
#                                   'COG': {'Congo': {'Number': 11988,
#                                                     'Percentage': 0.185}},
#                                   'FRA': {'France': {'Number': 3478,
#                                                      'Percentage': 0.054}},
#                                   'GAB': {'Gabon': {'Number': 1240,
#                                                     'Percentage': 0.019}},
#                                   'GHA': {'Ghana': {'Number': 660,
#                                                     'Percentage': 0.01}},
#                                   'MLI': {'Mali': {'Number': 1269,
#                                                    'Percentage': 0.02}},
#                                   'SEN': {'Senegal': {'Number': 2197,
#                                                       'Percentage': 0.034}},
#                                   'TCD': {'Chad': {'Number': 3898,
#                                                    'Percentage': 0.06}},
#                                   'TGO': {'Togo': {'Number': 804,
#                                                    'Percentage': 0.012}}}},
#  'Chad': {'TCD': {'AGO': {'Angola': {'Number': 4185, 'Percentage': 0.121}},
#                   'BFA': {'Burkina Faso': {'Number': 604, 'Percentage': 0.017}},
#                   'CAF': {'Central African Rep.': {'Number': 3639,
#                                                    'Percentage': 0.105}},
#                   'CAN': {'Canada': {'Number': 957, 'Percentage': 0.028}},
#                   'CMR': {'Cameroon': {'Number': 5295, 'Percentage': 0.153}},
#                   'COG': {'Congo': {'Number': 1204, 'Percentage': 0.035}},
#                   'DEU': {'Germany': {'Number': 1463, 'Percentage': 0.042}},
#                   'EGY': {'Egypt': {'Number': 417, 'Percentage': 0.012}},
#                   'FRA': {'France': {'Number': 2122, 'Percentage': 0.061}},
#                   'GAB': {'Gabon': {'Number': 7809, 'Percentage': 0.225}},
#                   'GHA': {'Ghana': {'Number': 445, 'Percentage': 0.013}},
#                   'ITA': {'Italy': {'Number': 357, 'Percentage': 0.01}},
#                   'LBY': {'Libya': {'Number': 1196, 'Percentage': 0.034}},
#                   'NGA': {'Nigeria': {'Number': 1347, 'Percentage': 0.039}},
#                   'SEN': {'Senegal': {'Number': 474, 'Percentage': 0.014}},
#                   'USA': {'United States of America': {'Number': 1010,
#                                                        'Percentage': 0.029}}}},
#  'Chile': {'CHL': {'ARG': {'Argentina': {'Number': 59, 'Percentage': 0.035}},
#                    'AUS': {'Australia': {'Number': 23, 'Percentage': 0.014}},
#                    'AUT': {'Austria': {'Number': 20, 'Percentage': 0.012}},
#                    'BEL': {'Belgium': {'Number': 19, 'Percentage': 0.011}},
#                    'BRA': {'Brazil': {'Number': 25, 'Percentage': 0.015}},
#                    'CAN': {'Canada': {'Number': 623, 'Percentage': 0.369}},
#                    'DEU': {'Germany': {'Number': 25, 'Percentage': 0.015}},
#                    'ECU': {'Ecuador': {'Number': 87, 'Percentage': 0.051}},
#                    'ESP': {'Spain': {'Number': 43, 'Percentage': 0.025}},
#                    'SWE': {'Sweden': {'Number': 191, 'Percentage': 0.113}},
#                    'USA': {'United States of America': {'Number': 480,
#                                                         'Percentage': 0.284}}}},
#  'China': {'CHN': {'AUS': {'Australia': {'Number': 21609, 'Percentage': 0.057}},
#                    'AUT': {'Austria': {'Number': 6360, 'Percentage': 0.017}},
#                    'CAN': {'Canada': {'Number': 26182, 'Percentage': 0.069}},
#                    'CHE': {'Switzerland': {'Number': 6617,
#                                            'Percentage': 0.017}},
#                    'DEU': {'Germany': {'Number': 8621, 'Percentage': 0.023}},
#                    'FRA': {'France': {'Number': 6736, 'Percentage': 0.018}},
#                    'GBR': {'United Kingdom': {'Number': 6188,
#                                               'Percentage': 0.016}},
#                    'USA': {'United States of America': {'Number': 264101,
#                                                         'Percentage': 0.695}},
#                    'ZAF': {'South Africa': {'Number': 10973,
#                                             'Percentage': 0.029}}}},
#  'China, Hong Kong SAR': {'HKG': {'AUS': {'Australia': {'Number': 222,
#                                                         'Percentage': 0.321}},
#                                   'CAN': {'Canada': {'Number': 358,
#                                                      'Percentage': 0.517}},
#                                   'GBR': {'United Kingdom': {'Number': 17,
#                                                              'Percentage': 0.025}},
#                                   'IRL': {'Ireland': {'Number': 29,
#                                                       'Percentage': 0.042}},
#                                   'USA': {'United States of America': {'Number': 56,
#                                                                        'Percentage': 0.081}}}},
#  'China, Macao SAR': {'MAC': {'AUS': {'Australia': {'Number': 7,
#                                                     'Percentage': 0.123}},
#                               'JOR': {'Jordan': {'Number': 4,
#                                                  'Percentage': 0.07}},
#                               'NZL': {'New Zealand': {'Number': 1,
#                                                       'Percentage': 0.018}},
#                               'USA': {'United States of America': {'Number': 41,
#                                                                    'Percentage': 0.719}},
#                               'ZAF': {'South Africa': {'Number': 4,
#                                                        'Percentage': 0.07}}}},
#  'Colombia': {'COL': {'CAN': {'Canada': {'Number': 21364, 'Percentage': 0.06}},
#                       'CHL': {'Chile': {'Number': 11121, 'Percentage': 0.031}},
#                       'CRI': {'Costa Rica': {'Number': 4355,
#                                              'Percentage': 0.012}},
#                       'ECU': {'Ecuador': {'Number': 194724,
#                                           'Percentage': 0.55}},
#                       'ESP': {'Spain': {'Number': 3954, 'Percentage': 0.011}},
#                       'PAN': {'Panama': {'Number': 8066, 'Percentage': 0.023}},
#                       'USA': {'United States of America': {'Number': 24428,
#                                                            'Percentage': 0.069}},
#                       'VEN': {'Venezuela (Bolivarian Republic of)': {'Number': 72151,
#                                                                      'Percentage': 0.204}}}},
#  'Comoros': {'COM': {'BDI': {'Burundi': {'Number': 24, 'Percentage': 0.014}},
#                      'CYP': {'Cyprus': {'Number': 29, 'Percentage': 0.017}},
#                      'DEU': {'Germany': {'Number': 53, 'Percentage': 0.032}},
#                      'FRA': {'France': {'Number': 1059, 'Percentage': 0.637}},
#                      'GBR': {'United Kingdom': {'Number': 21,
#                                                 'Percentage': 0.013}},
#                      'GRC': {'Greece': {'Number': 52, 'Percentage': 0.031}},
#                      'HUN': {'Hungary': {'Number': 40, 'Percentage': 0.024}},
#                      'ITA': {'Italy': {'Number': 46, 'Percentage': 0.028}},
#                      'MKD': {'The former Yugoslav Republic of Macedonia': {'Number': 46,
#                                                                            'Percentage': 0.028}},
#                      'SYR': {'Syrian Arab Rep.': {'Number': 20,
#                                                   'Percentage': 0.012}},
#                      'ZAF': {'South Africa': {'Number': 189,
#                                               'Percentage': 0.114}}}},
#  'Congo': {'COG': {'AGO': {'Angola': {'Number': 1353, 'Percentage': 0.027}},
#                    'BFA': {'Burkina Faso': {'Number': 535,
#                                             'Percentage': 0.011}},
#                    'CAN': {'Canada': {'Number': 677, 'Percentage': 0.014}},
#                    'CIV': {"CÌ«te d'Ivoire": {'Number': 789,
#                                               'Percentage': 0.016}},
#                    'DEU': {'Germany': {'Number': 1116, 'Percentage': 0.022}},
#                    'FRA': {'France': {'Number': 3970, 'Percentage': 0.079}},
#                    'GAB': {'Gabon': {'Number': 7945, 'Percentage': 0.159}},
#                    'NLD': {'Netherlands': {'Number': 566, 'Percentage': 0.011}},
#                    'SEN': {'Senegal': {'Number': 2616, 'Percentage': 0.052}},
#                    'TUR': {'Turkey': {'Number': 780, 'Percentage': 0.016}},
#                    'USA': {'United States of America': {'Number': 5263,
#                                                         'Percentage': 0.105}},
#                    'ZAF': {'South Africa': {'Number': 17612,
#                                             'Percentage': 0.352}}}},
#  'Cook Islands': {'COK': {'AUS': {'Australia': {'Number': 1,
#                                                 'Percentage': 1.0}}}},
#  'Costa Rica': {'CRI': {'CAN': {'Canada': {'Number': 318, 'Percentage': 0.163}},
#                         'MEX': {'Mexico': {'Number': 20, 'Percentage': 0.01}},
#                         'USA': {'United States of America': {'Number': 1544,
#                                                              'Percentage': 0.79}}}},
#  'Croatia': {'HRV': {'AUT': {'Austria': {'Number': 86, 'Percentage': 0.019}},
#                      'CAN': {'Canada': {'Number': 3639, 'Percentage': 0.793}},
#                      'DEU': {'Germany': {'Number': 265, 'Percentage': 0.058}},
#                      'IRL': {'Ireland': {'Number': 104, 'Percentage': 0.023}},
#                      'ISL': {'Iceland': {'Number': 51, 'Percentage': 0.011}},
#                      'SWE': {'Sweden': {'Number': 98, 'Percentage': 0.021}},
#                      'USA': {'United States of America': {'Number': 119,
#                                                           'Percentage': 0.026}}}},
#  'Cuba': {'CUB': {'ARG': {'Argentina': {'Number': 1749, 'Percentage': 0.052}},
#                   'BRA': {'Brazil': {'Number': 8006, 'Percentage': 0.236}},
#                   'CAN': {'Canada': {'Number': 1928, 'Percentage': 0.057}},
#                   'CHL': {'Chile': {'Number': 1869, 'Percentage': 0.055}},
#                   'COL': {'Colombia': {'Number': 440, 'Percentage': 0.013}},
#                   'CRI': {'Costa Rica': {'Number': 793, 'Percentage': 0.023}},
#                   'DEU': {'Germany': {'Number': 815, 'Percentage': 0.024}},
#                   'ECU': {'Ecuador': {'Number': 5497, 'Percentage': 0.162}},
#                   'ESP': {'Spain': {'Number': 646, 'Percentage': 0.019}},
#                   'MEX': {'Mexico': {'Number': 874, 'Percentage': 0.026}},
#                   'PAN': {'Panama': {'Number': 898, 'Percentage': 0.026}},
#                   'PER': {'Peru': {'Number': 1903, 'Percentage': 0.056}},
#                   'SWE': {'Sweden': {'Number': 402, 'Percentage': 0.012}},
#                   'TTO': {'Trinidad and Tobago': {'Number': 928,
#                                                   'Percentage': 0.027}},
#                   'URY': {'Uruguay': {'Number': 2325, 'Percentage': 0.068}},
#                   'USA': {'United States of America': {'Number': 2480,
#                                                        'Percentage': 0.073}}}},
#  'CuraÌ¤ao': {'CUW': {'USA': {'United States of America': {'Number': 59,
#                                                            'Percentage': 1.0}}}},
#  'Cyprus': {'CYP': {'AUS': {'Australia': {'Number': 15, 'Percentage': 0.273}},
#                     'BRA': {'Brazil': {'Number': 2, 'Percentage': 0.036}},
#                     'CAN': {'Canada': {'Number': 22, 'Percentage': 0.4}},
#                     'CHE': {'Switzerland': {'Number': 5, 'Percentage': 0.091}},
#                     'DEU': {'Germany': {'Number': 3, 'Percentage': 0.055}},
#                     'GBR': {'United Kingdom': {'Number': 5,
#                                                'Percentage': 0.091}},
#                     'GNB': {'Guinea-Bissau': {'Number': 1,
#                                               'Percentage': 0.018}},
#                     'MDA': {'Rep. of Moldova': {'Number': 1,
#                                                 'Percentage': 0.018}},
#                     'SWE': {'Sweden': {'Number': 1, 'Percentage': 0.018}}}},
#  'Czech Rep.': {'CZE': {'CAN': {'Canada': {'Number': 5545,
#                                            'Percentage': 0.933}},
#                         'DEU': {'Germany': {'Number': 65, 'Percentage': 0.011}},
#                         'NZL': {'New Zealand': {'Number': 63,
#                                                 'Percentage': 0.011}},
#                         'USA': {'United States of America': {'Number': 165,
#                                                              'Percentage': 0.028}}}},
#  "CÌ«te d'Ivoire": {'CIV': {'AGO': {'Angola': {'Number': 39131,
#                                                'Percentage': 0.284}},
#                             'CMR': {'Cameroon': {'Number': 1675,
#                                                  'Percentage': 0.012}},
#                             'DEU': {'Germany': {'Number': 6481,
#                                                 'Percentage': 0.047}},
#                             'DZA': {'Algeria': {'Number': 1457,
#                                                 'Percentage': 0.011}},
#                             'ESP': {'Spain': {'Number': 2197,
#                                               'Percentage': 0.016}},
#                             'FRA': {'France': {'Number': 7781,
#                                                'Percentage': 0.056}},
#                             'GHA': {'Ghana': {'Number': 14749,
#                                               'Percentage': 0.107}},
#                             'GIN': {'Guinea': {'Number': 1790,
#                                                'Percentage': 0.013}},
#                             'ISR': {'Israel': {'Number': 3756,
#                                                'Percentage': 0.027}},
#                             'ITA': {'Italy': {'Number': 20936,
#                                               'Percentage': 0.152}},
#                             'MAR': {'Morocco': {'Number': 2401,
#                                                 'Percentage': 0.017}},
#                             'MLI': {'Mali': {'Number': 7364,
#                                              'Percentage': 0.053}},
#                             'MRT': {'Mauritania': {'Number': 1688,
# ...
#                     'JPN': {'Japan': {'Number': 484, 'Percentage': 0.011}},
#                     'KEN': {'Kenya': {'Number': 7226, 'Percentage': 0.165}},
#                     'KOR': {'Rep. of Korea': {'Number': 960,
#                                               'Percentage': 0.022}},
#                     'NLD': {'Netherlands': {'Number': 495,
#                                             'Percentage': 0.011}},
#                     'SWE': {'Sweden': {'Number': 1161, 'Percentage': 0.027}},
#                     'TUR': {'Turkey': {'Number': 2167, 'Percentage': 0.05}},
#                     'USA': {'United States of America': {'Number': 5477,
#                                                          'Percentage': 0.125}},
#                     'ZAF': {'South Africa': {'Number': 17954,
#                                              'Percentage': 0.411}}}},
#  'Ukraine': {'UKR': {'AUT': {'Austria': {'Number': 5014, 'Percentage': 0.044}},
#                      'CAN': {'Canada': {'Number': 3452, 'Percentage': 0.03}},
#                      'CYP': {'Cyprus': {'Number': 1336, 'Percentage': 0.012}},
#                      'CZE': {'Czech Rep.': {'Number': 1774,
#                                             'Percentage': 0.016}},
#                      'DEU': {'Germany': {'Number': 20483, 'Percentage': 0.179}},
#                      'ESP': {'Spain': {'Number': 10735, 'Percentage': 0.094}},
#                      'FRA': {'France': {'Number': 3904, 'Percentage': 0.034}},
#                      'ISR': {'Israel': {'Number': 11512, 'Percentage': 0.101}},
#                      'ITA': {'Italy': {'Number': 11682, 'Percentage': 0.102}},
#                      'POL': {'Poland': {'Number': 2807, 'Percentage': 0.025}},
#                      'RUS': {'Russian Federation': {'Number': 7092,
#                                                     'Percentage': 0.062}},
#                      'SWE': {'Sweden': {'Number': 4645, 'Percentage': 0.041}},
#                      'USA': {'United States of America': {'Number': 20851,
#                                                           'Percentage': 0.182}}}},
#  'United Arab Emirates': {'ARE': {'AUS': {'Australia': {'Number': 13,
#                                                         'Percentage': 0.019}},
#                                   'BEL': {'Belgium': {'Number': 8,
#                                                       'Percentage': 0.012}},
#                                   'CAN': {'Canada': {'Number': 99,
#                                                      'Percentage': 0.143}},
#                                   'DEU': {'Germany': {'Number': 25,
#                                                       'Percentage': 0.036}},
#                                   'GBR': {'United Kingdom': {'Number': 48,
#                                                              'Percentage': 0.069}},
#                                   'NZL': {'New Zealand': {'Number': 7,
#                                                           'Percentage': 0.01}},
#                                   'SWE': {'Sweden': {'Number': 10,
#                                                      'Percentage': 0.014}},
#                                   'TUR': {'Turkey': {'Number': 62,
#                                                      'Percentage': 0.09}},
#                                   'USA': {'United States of America': {'Number': 376,
#                                                                        'Percentage': 0.543}}}},
#  'United Kingdom': {'GBR': {'AUS': {'Australia': {'Number': 136,
#                                                   'Percentage': 0.173}},
#                             'BEL': {'Belgium': {'Number': 8,
#                                                 'Percentage': 0.01}},
#                             'CAN': {'Canada': {'Number': 122,
#                                                'Percentage': 0.155}},
#                             'DEU': {'Germany': {'Number': 25,
#                                                 'Percentage': 0.032}},
#                             'GBR': {'United Kingdom': {'Number': 9,
#                                                        'Percentage': 0.011}},
#                             'USA': {'United States of America': {'Number': 447,
#                                                                  'Percentage': 0.569}}}},
#  'United Rep. of Tanzania': {'TZA': {'BEL': {'Belgium': {'Number': 168,
#                                                          'Percentage': 0.012}},
#                                      'BRA': {'Brazil': {'Number': 303,
#                                                         'Percentage': 0.022}},
#                                      'CAN': {'Canada': {'Number': 423,
#                                                         'Percentage': 0.03}},
#                                      'DEU': {'Germany': {'Number': 541,
#                                                          'Percentage': 0.039}},
#                                      'GBR': {'United Kingdom': {'Number': 270,
#                                                                 'Percentage': 0.019}},
#                                      'KEN': {'Kenya': {'Number': 256,
#                                                        'Percentage': 0.018}},
#                                      'SOM': {'Somalia': {'Number': 215,
#                                                          'Percentage': 0.015}},
#                                      'SWE': {'Sweden': {'Number': 300,
#                                                         'Percentage': 0.021}},
#                                      'USA': {'United States of America': {'Number': 640,
#                                                                           'Percentage': 0.046}},
#                                      'ZAF': {'South Africa': {'Number': 9805,
#                                                               'Percentage': 0.702}}}},
#  'United States of America': {'USA': {'AUS': {'Australia': {'Number': 123,
#                                                             'Percentage': 0.013}},
#                                       'CAN': {'Canada': {'Number': 8383,
#                                                          'Percentage': 0.887}},
#                                       'DEU': {'Germany': {'Number': 114,
#                                                           'Percentage': 0.012}},
#                                       'GBR': {'United Kingdom': {'Number': 202,
#                                                                  'Percentage': 0.021}}}},
#  'Uruguay': {'URY': {'ARG': {'Argentina': {'Number': 9, 'Percentage': 0.013}},
#                      'AUS': {'Australia': {'Number': 13, 'Percentage': 0.019}},
#                      'BRA': {'Brazil': {'Number': 35, 'Percentage': 0.051}},
#                      'CAN': {'Canada': {'Number': 237, 'Percentage': 0.347}},
#                      'ESP': {'Spain': {'Number': 18, 'Percentage': 0.026}},
#                      'ITA': {'Italy': {'Number': 9, 'Percentage': 0.013}},
#                      'USA': {'United States of America': {'Number': 337,
#                                                           'Percentage': 0.493}}}},
#  'Uzbekistan': {'UZB': {'AUT': {'Austria': {'Number': 923, 'Percentage': 0.04}},
#                         'CAN': {'Canada': {'Number': 499, 'Percentage': 0.022}},
#                         'CYP': {'Cyprus': {'Number': 231, 'Percentage': 0.01}},
#                         'DEU': {'Germany': {'Number': 627,
#                                             'Percentage': 0.027}},
#                         'EGY': {'Egypt': {'Number': 514, 'Percentage': 0.022}},
#                         'KAZ': {'Kazakhstan': {'Number': 380,
#                                                'Percentage': 0.017}},
#                         'KGZ': {'Kyrgyzstan': {'Number': 1247,
#                                                'Percentage': 0.054}},
#                         'NOR': {'Norway': {'Number': 1386,
#                                            'Percentage': 0.061}},
#                         'RUS': {'Russian Federation': {'Number': 474,
#                                                        'Percentage': 0.021}},
#                         'SWE': {'Sweden': {'Number': 4777,
#                                            'Percentage': 0.209}},
#                         'TUR': {'Turkey': {'Number': 3107,
#                                            'Percentage': 0.136}},
#                         'UKR': {'Ukraine': {'Number': 754,
#                                             'Percentage': 0.033}},
#                         'USA': {'United States of America': {'Number': 6027,
#                                                              'Percentage': 0.263}}}},
#  'Vanuatu': {'VUT': {'AUS': {'Australia': {'Number': 8, 'Percentage': 0.364}},
#                      'BRA': {'Brazil': {'Number': 8, 'Percentage': 0.364}},
#                      'CAN': {'Canada': {'Number': 4, 'Percentage': 0.182}},
#                      'NZL': {'New Zealand': {'Number': 1, 'Percentage': 0.045}},
#                      'SWE': {'Sweden': {'Number': 1, 'Percentage': 0.045}}}},
#  'Various/Unknown': {None: {'BEL': {'Belgium': {'Number': 96931,
#                                                 'Percentage': 0.027}},
#                             'DEU': {'Germany': {'Number': 61391,
#                                                 'Percentage': 0.017}},
#                             'ECU': {'Ecuador': {'Number': 48880,
#                                                 'Percentage': 0.014}},
#                             'FRA': {'France': {'Number': 239041,
#                                                'Percentage': 0.067}},
#                             'GBR': {'United Kingdom': {'Number': 89298,
#                                                        'Percentage': 0.025}},
#                             'GRC': {'Greece': {'Number': 244955,
#                                                'Percentage': 0.069}},
#                             'ISR': {'Israel': {'Number': 42552,
#                                                'Percentage': 0.012}},
#                             'ZAF': {'South Africa': {'Number': 2582479,
#                                                      'Percentage': 0.725}}}},
#  'Venezuela (Bolivarian Republic of)': {'VEN': {'BRA': {'Brazil': {'Number': 27736,
#                                                                    'Percentage': 0.126}},
#                                                 'CAN': {'Canada': {'Number': 3442,
#                                                                    'Percentage': 0.016}},
#                                                 'CRI': {'Costa Rica': {'Number': 5018,
#                                                                        'Percentage': 0.023}},
#                                                 'ESP': {'Spain': {'Number': 18818,
#                                                                   'Percentage': 0.085}},
#                                                 'MEX': {'Mexico': {'Number': 3361,
#                                                                    'Percentage': 0.015}},
#                                                 'PAN': {'Panama': {'Number': 4790,
#                                                                    'Percentage': 0.022}},
#                                                 'PER': {'Peru': {'Number': 39817,
#                                                                  'Percentage': 0.18}},
#                                                 'USA': {'United States of America': {'Number': 108384,
#                                                                                      'Percentage': 0.491}}}},
#  'Viet Nam': {'VNM': {'AUS': {'Australia': {'Number': 3612,
#                                             'Percentage': 0.122}},
#                       'AUT': {'Austria': {'Number': 289, 'Percentage': 0.01}},
#                       'CYP': {'Cyprus': {'Number': 942, 'Percentage': 0.032}},
#                       'CZE': {'Czech Rep.': {'Number': 392,
#                                              'Percentage': 0.013}},
#                       'DEU': {'Germany': {'Number': 6962, 'Percentage': 0.234}},
#                       'GBR': {'United Kingdom': {'Number': 3790,
#                                                  'Percentage': 0.128}},
#                       'HKG': {'China, Hong Kong SAR': {'Number': 1237,
#                                                        'Percentage': 0.042}},
#                       'HUN': {'Hungary': {'Number': 940, 'Percentage': 0.032}},
#                       'JPN': {'Japan': {'Number': 4042, 'Percentage': 0.136}},
#                       'KHM': {'Cambodia': {'Number': 501, 'Percentage': 0.017}},
#                       'SWE': {'Sweden': {'Number': 544, 'Percentage': 0.018}},
#                       'THA': {'Thailand': {'Number': 3306,
#                                            'Percentage': 0.111}},
#                       'USA': {'United States of America': {'Number': 1355,
#                                                            'Percentage': 0.046}}}},
#  'Wallis and Futuna Islands ': {'WLF': {'ZAF': {'South Africa': {'Number': 3,
#                                                                  'Percentage': 1.0}}}},
#  'Western Sahara': {'ESH': {'AGO': {'Angola': {'Number': 2668,
#                                                'Percentage': 0.374}},
#                             'ESP': {'Spain': {'Number': 230,
#                                               'Percentage': 0.032}},
#                             'FRA': {'France': {'Number': 3979,
#                                                'Percentage': 0.558}}}},
#  'Yemen': {'YEM': {'CAN': {'Canada': {'Number': 1261, 'Percentage': 0.021}},
#                    'CHE': {'Switzerland': {'Number': 729, 'Percentage': 0.012}},
#                    'DEU': {'Germany': {'Number': 2752, 'Percentage': 0.046}},
#                    'EGY': {'Egypt': {'Number': 8991, 'Percentage': 0.15}},
#                    'ETH': {'Ethiopia': {'Number': 952, 'Percentage': 0.016}},
#                    'IND': {'India': {'Number': 1730, 'Percentage': 0.029}},
#                    'JOR': {'Jordan': {'Number': 18339, 'Percentage': 0.306}},
#                    'KOR': {'Rep. of Korea': {'Number': 636,
#                                              'Percentage': 0.011}},
#                    'MYS': {'Malaysia': {'Number': 5265, 'Percentage': 0.088}},
#                    'NOR': {'Norway': {'Number': 861, 'Percentage': 0.014}},
#                    'SDN': {'Sudan': {'Number': 4876, 'Percentage': 0.081}},
#                    'SWE': {'Sweden': {'Number': 2031, 'Percentage': 0.034}},
#                    'SYR': {'Syrian Arab Rep.': {'Number': 1057,
#                                                 'Percentage': 0.018}},
#                    'TUR': {'Turkey': {'Number': 1692, 'Percentage': 0.028}},
#                    'USA': {'United States of America': {'Number': 3060,
#                                                         'Percentage': 0.051}}}},
#  'Zambia': {'ZMB': {'AUS': {'Australia': {'Number': 111, 'Percentage': 0.036}},
#                     'CAN': {'Canada': {'Number': 132, 'Percentage': 0.043}},
#                     'DEU': {'Germany': {'Number': 50, 'Percentage': 0.016}},
#                     'GBR': {'United Kingdom': {'Number': 190,
#                                                'Percentage': 0.062}},
#                     'MWI': {'Malawi': {'Number': 51, 'Percentage': 0.017}},
#                     'SWE': {'Sweden': {'Number': 32, 'Percentage': 0.01}},
#                     'USA': {'United States of America': {'Number': 199,
#                                                          'Percentage': 0.065}},
#                     'ZAF': {'South Africa': {'Number': 2142,
#                                              'Percentage': 0.698}}}},
#  'Zimbabwe': {'ZWE': {'GBR': {'United Kingdom': {'Number': 3747,
#                                                  'Percentage': 0.011}},
#                       'ZAF': {'South Africa': {'Number': 339995,
#                                                'Percentage': 0.953}}}}}

# %% [markdown]
# # Countries of Origin over Time

# %%
# Manipulate the Country of Origin over time

#complete_df['Value'] = complete_df['Value'].replace('*', 0)
#complete_df['Value'] = pd.to_numeric(complete_df['Value'])
country_over_time = complete_df.groupby(["Origin","Year","Type"])
country_over_time = country_over_time['Value'].sum()
country_over_time = pd.DataFrame(country_over_time)
country_over_time.head(50)
# Out:
#                                                              Value
# Origin      Year Type
# Afghanistan 1979 Refugees (incl. refugee-like situations)   500000
#             1980 Refugees (incl. refugee-like situations)  1734921
#             1981 Refugees (incl. refugee-like situations)  3879984
#             1982 Refugees (incl. refugee-like situations)  4488214
#             1983 Refugees (incl. refugee-like situations)  4712735
#             1984 Refugees (incl. refugee-like situations)  4417651
#             1985 Refugees (incl. refugee-like situations)  4653193
#             1986 Refugees (incl. refugee-like situations)  5094283
#             1987 Refugees (incl. refugee-like situations)  5511740
#             1988 Refugees (incl. refugee-like situations)  5622982
#             1989 Refugees (incl. refugee-like situations)  5643989
#             1990 Refugees (incl. refugee-like situations)  6339095
#             1991 Refugees (incl. refugee-like situations)  6306301
#             1992 Refugees (incl. refugee-like situations)  4552153
#             1993 Refugees (incl. refugee-like situations)  3374576
#             1994 Refugees (incl. refugee-like situations)  2731169
#             1995 Refugees (incl. refugee-like situations)  2679133
#             1996 Refugees (incl. refugee-like situations)  2674236
#             1997 Refugees (incl. refugee-like situations)  2676674
#             1998 Refugees (incl. refugee-like situations)  2667115
#             1999 Refugees (incl. refugee-like situations)  2601691
#             2000 Asylum-seekers                              40294
#                  Refugees (incl. refugee-like situations)  3587336
#             2001 Asylum-seekers                              30793
#                  Refugees (incl. refugee-like situations)  3809767
#             2002 Asylum-seekers                              26694
#                  Refugees (incl. refugee-like situations)  2510294
#             2003 Asylum-seekers                              26315
#                  Refugees (incl. refugee-like situations)  2136043
#             2004 Asylum-seekers                              16990
#                  Refugees (incl. refugee-like situations)  2414468
#             2005 Asylum-seekers                              14033
#                  Refugees (incl. refugee-like situations)  2166149
#             2006 Asylum-seekers                              14977
#                  Refugees (incl. refugee-like situations)  2107519
#             2007 Asylum-seekers                              16088
#                  Refugees (incl. refugee-like situations)  3057661
#             2008 Asylum-seekers                              23179
#                  Refugees (incl. refugee-like situations)  2833128
#             2009 Asylum-seekers                              30412
#                  Refugees (incl. refugee-like situations)  2887123
#             2010 Asylum-seekers                              37120
#                  Refugees (incl. refugee-like situations)  3054709
#             2011 Asylum-seekers                              39203
#                  Refugees (incl. refugee-like situations)  2664436
#             2012 Asylum-seekers                              62313
#                  Refugees (incl. refugee-like situations)  2586152
#             2013 Asylum-seekers                              75295
#                  Refugees (incl. refugee-like situations)  2556502
#             2014 Asylum-seekers                              92382

# %%
# Countries over time (to be compared with conflict data)
cot=country_over_time.reset_index(drop=False)
cot = cot.merge(uq_names_org, left_on="Origin", right_on="country_name", how="left")
del cot['country_name']
## It gets really sparse before 1964
cot.to_csv("countries_over_time.csv", index=False)

# %%
#cot.head(50)
cot['Year'].value_counts()

# %%
temp_df = pd.DataFrame()
cot_array = {}

for country in cot['Origin'].unique():
    temp_df = cot.loc[cot['Origin']==country,:]
    temp_array = {}
    counter = iter(range(len(temp_df)))
    for x in counter:
        row = temp_df.iloc[x,:]
        if (x == len(temp_df)-1):
            temp_array[row[1]] = {row[2]: row[3]}
        else:
            row2 = temp_df.iloc[(x+1),:]
            if row[1] == row2[1]:
                temp_array[row[1]] = {row[2]: row[3], row2[2]: row2[3]}
                next(islice(counter,1,1), None)
            else:
                temp_array[row[1]] = {row[2]: row[3]}
        ccode = row[4]
    cot_array[country] = {ccode: temp_array}
    
pprint(cot_array)

# This is now in a json array... that I might host somewhere? 
#(mlab or mongoDB?)
# Out:
# {'Afghanistan': {'AFG': {1979: {'Refugees (incl. refugee-like situations)': 500000},
#                          1980: {'Refugees (incl. refugee-like situations)': 1734921},
#                          1981: {'Refugees (incl. refugee-like situations)': 3879984},
#                          1982: {'Refugees (incl. refugee-like situations)': 4488214},
#                          1983: {'Refugees (incl. refugee-like situations)': 4712735},
#                          1984: {'Refugees (incl. refugee-like situations)': 4417651},
#                          1985: {'Refugees (incl. refugee-like situations)': 4653193},
#                          1986: {'Refugees (incl. refugee-like situations)': 5094283},
#                          1987: {'Refugees (incl. refugee-like situations)': 5511740},
#                          1988: {'Refugees (incl. refugee-like situations)': 5622982},
#                          1989: {'Refugees (incl. refugee-like situations)': 5643989},
#                          1990: {'Refugees (incl. refugee-like situations)': 6339095},
#                          1991: {'Refugees (incl. refugee-like situations)': 6306301},
#                          1992: {'Refugees (incl. refugee-like situations)': 4552153},
#                          1993: {'Refugees (incl. refugee-like situations)': 3374576},
#                          1994: {'Refugees (incl. refugee-like situations)': 2731169},
#                          1995: {'Refugees (incl. refugee-like situations)': 2679133},
#                          1996: {'Refugees (incl. refugee-like situations)': 2674236},
#                          1997: {'Refugees (incl. refugee-like situations)': 2676674},
#                          1998: {'Refugees (incl. refugee-like situations)': 2667115},
#                          1999: {'Refugees (incl. refugee-like situations)': 2601691},
#                          2000: {'Asylum-seekers': 40294,
#                                 'Refugees (incl. refugee-like situations)': 3587336},
#                          2001: {'Asylum-seekers': 30793,
#                                 'Refugees (incl. refugee-like situations)': 3809767},
#                          2002: {'Asylum-seekers': 26694,
#                                 'Refugees (incl. refugee-like situations)': 2510294},
#                          2003: {'Asylum-seekers': 26315,
#                                 'Refugees (incl. refugee-like situations)': 2136043},
#                          2004: {'Asylum-seekers': 16990,
#                                 'Refugees (incl. refugee-like situations)': 2414468},
#                          2005: {'Asylum-seekers': 14033,
#                                 'Refugees (incl. refugee-like situations)': 2166149},
#                          2006: {'Asylum-seekers': 14977,
#                                 'Refugees (incl. refugee-like situations)': 2107519},
#                          2007: {'Asylum-seekers': 16088,
#                                 'Refugees (incl. refugee-like situations)': 3057661},
#                          2008: {'Asylum-seekers': 23179,
#                                 'Refugees (incl. refugee-like situations)': 2833128},
#                          2009: {'Asylum-seekers': 30412,
#                                 'Refugees (incl. refugee-like situations)': 2887123},
#                          2010: {'Asylum-seekers': 37120,
#                                 'Refugees (incl. refugee-like situations)': 3054709},
#                          2011: {'Asylum-seekers': 39203,
#                                 'Refugees (incl. refugee-like situations)': 2664436},
#                          2012: {'Asylum-seekers': 62313,
#                                 'Refugees (incl. refugee-like situations)': 2586152},
#                          2013: {'Asylum-seekers': 75295,
#                                 'Refugees (incl. refugee-like situations)': 2556502},
#                          2014: {'Asylum-seekers': 92382,
#                                 'Refugees (incl. refugee-like situations)': 2596270},
#                          2015: {'Asylum-seekers': 258889,
#                                 'Refugees (incl. refugee-like situations)': 2666305},
#                          2016: {'Asylum-seekers': 368957,
#                                 'Refugees (incl. refugee-like situations)': 2501445},
#                          2017: {'Asylum-seekers': 333983,
#                                 'Refugees (incl. refugee-like situations)': 2624225}}},
#  'Albania': {'ALB': {1964: {'Refugees (incl. refugee-like situations)': 100},
#                      1965: {'Refugees (incl. refugee-like situations)': 4860},
#                      1966: {'Refugees (incl. refugee-like situations)': 4860},
#                      1967: {'Refugees (incl. refugee-like situations)': 4260},
#                      1968: {'Refugees (incl. refugee-like situations)': 4120},
#                      1969: {'Refugees (incl. refugee-like situations)': 4290},
#                      1970: {'Refugees (incl. refugee-like situations)': 4310},
#                      1971: {'Refugees (incl. refugee-like situations)': 390},
#                      1972: {'Refugees (incl. refugee-like situations)': 2300},
#                      1973: {'Refugees (incl. refugee-like situations)': 2090},
#                      1974: {'Refugees (incl. refugee-like situations)': 380},
#                      1975: {'Refugees (incl. refugee-like situations)': 380},
#                      1977: {'Refugees (incl. refugee-like situations)': 2000},
#                      1978: {'Refugees (incl. refugee-like situations)': 1980},
#                      1979: {'Refugees (incl. refugee-like situations)': 1610},
#                      1980: {'Refugees (incl. refugee-like situations)': 1681},
#                      1981: {'Refugees (incl. refugee-like situations)': 1680},
#                      1982: {'Refugees (incl. refugee-like situations)': 1645},
#                      1983: {'Refugees (incl. refugee-like situations)': 1610},
#                      1984: {'Refugees (incl. refugee-like situations)': 1576},
#                      1985: {'Refugees (incl. refugee-like situations)': 1587},
#                      1986: {'Refugees (incl. refugee-like situations)': 90},
#                      1987: {'Refugees (incl. refugee-like situations)': 129},
#                      1988: {'Refugees (incl. refugee-like situations)': 358},
#                      1989: {'Refugees (incl. refugee-like situations)': 367},
#                      1990: {'Refugees (incl. refugee-like situations)': 1822},
#                      1991: {'Refugees (incl. refugee-like situations)': 3540},
#                      1992: {'Refugees (incl. refugee-like situations)': 4353},
#                      1993: {'Refugees (incl. refugee-like situations)': 4744},
#                      1994: {'Refugees (incl. refugee-like situations)': 5019},
#                      1995: {'Refugees (incl. refugee-like situations)': 5803},
#                      1996: {'Refugees (incl. refugee-like situations)': 5785},
#                      1997: {'Refugees (incl. refugee-like situations)': 5379},
#                      1998: {'Refugees (incl. refugee-like situations)': 5353},
#                      1999: {'Refugees (incl. refugee-like situations)': 6288},
#                      2000: {'Asylum-seekers': 2817,
#                             'Refugees (incl. refugee-like situations)': 6802},
#                      2001: {'Asylum-seekers': 3978,
#                             'Refugees (incl. refugee-like situations)': 7626},
#                      2002: {'Asylum-seekers': 4992,
#                             'Refugees (incl. refugee-like situations)': 10761},
#                      2003: {'Asylum-seekers': 4535,
#                             'Refugees (incl. refugee-like situations)': 10385},
#                      2004: {'Asylum-seekers': 3328,
#                             'Refugees (incl. refugee-like situations)': 10478},
#                      2005: {'Asylum-seekers': 2579,
#                             'Refugees (incl. refugee-like situations)': 12722},
#                      2006: {'Asylum-seekers': 2279,
#                             'Refugees (incl. refugee-like situations)': 14079},
#                      2007: {'Asylum-seekers': 1640,
#                             'Refugees (incl. refugee-like situations)': 15340},
#                      2008: {'Asylum-seekers': 1822,
#                             'Refugees (incl. refugee-like situations)': 15006},
#                      2009: {'Asylum-seekers': 1592,
#                             'Refugees (incl. refugee-like situations)': 15711},
#                      2010: {'Asylum-seekers': 1358,
#                             'Refugees (incl. refugee-like situations)': 14772},
#                      2011: {'Asylum-seekers': 2203,
#                             'Refugees (incl. refugee-like situations)': 13551},
#                      2012: {'Asylum-seekers': 3718,
#                             'Refugees (incl. refugee-like situations)': 12568},
#                      2013: {'Asylum-seekers': 9765,
#                             'Refugees (incl. refugee-like situations)': 10103},
#                      2014: {'Asylum-seekers': 15212,
#                             'Refugees (incl. refugee-like situations)': 10158},
#                      2015: {'Asylum-seekers': 42162,
#                             'Refugees (incl. refugee-like situations)': 10408},
#                      2016: {'Asylum-seekers': 23787,
#                             'Refugees (incl. refugee-like situations)': 11065},
#                      2017: {'Asylum-seekers': 18745,
#                             'Refugees (incl. refugee-like situations)': 12163}}},
#  'Algeria': {'DZA': {1980: {'Refugees (incl. refugee-like situations)': 2},
#                      1981: {'Refugees (incl. refugee-like situations)': 3},
#                      1982: {'Refugees (incl. refugee-like situations)': 3},
#                      1983: {'Refugees (incl. refugee-like situations)': 3},
#                      1984: {'Refugees (incl. refugee-like situations)': 3},
#                      1985: {'Refugees (incl. refugee-like situations)': 3},
#                      1986: {'Refugees (incl. refugee-like situations)': 1},
#                      1987: {'Refugees (incl. refugee-like situations)': 1},
#                      1988: {'Refugees (incl. refugee-like situations)': 5},
#                      1989: {'Refugees (incl. refugee-like situations)': 6},
#                      1990: {'Refugees (incl. refugee-like situations)': 19},
#                      1991: {'Refugees (incl. refugee-like situations)': 55},
#                      1992: {'Refugees (incl. refugee-like situations)': 71},
#                      1993: {'Refugees (incl. refugee-like situations)': 86},
#                      1994: {'Refugees (incl. refugee-like situations)': 20743},
#                      1995: {'Refugees (incl. refugee-like situations)': 1520},
#                      1996: {'Refugees (incl. refugee-like situations)': 2247},
#                      1997: {'Refugees (incl. refugee-like situations)': 3418},
#                      1998: {'Refugees (incl. refugee-like situations)': 5727},
#                      1999: {'Refugees (incl. refugee-like situations)': 7151},
#                      2000: {'Asylum-seekers': 2330,
#                             'Refugees (incl. refugee-like situations)': 8034},
#                      2001: {'Asylum-seekers': 2751,
#                             'Refugees (incl. refugee-like situations)': 8418},
#                      2002: {'Asylum-seekers': 2380,
#                             'Refugees (incl. refugee-like situations)': 12107},
#                      2003: {'Asylum-seekers': 1922,
#                             'Refugees (incl. refugee-like situations)': 11667},
#                      2004: {'Asylum-seekers': 1348,
#                             'Refugees (incl. refugee-like situations)': 10673},
#                      2005: {'Asylum-seekers': 1391,
#                             'Refugees (incl. refugee-like situations)': 12041},
#                      2006: {'Asylum-seekers': 1544,
#                             'Refugees (incl. refugee-like situations)': 8353},
#                      2007: {'Asylum-seekers': 1356,
#                             'Refugees (incl. refugee-like situations)': 10615},
#                      2008: {'Asylum-seekers': 1536,
#                             'Refugees (incl. refugee-like situations)': 9060},
#                      2009: {'Asylum-seekers': 1546,
#                             'Refugees (incl. refugee-like situations)': 8185},
#                      2010: {'Asylum-seekers': 1713,
#                             'Refugees (incl. refugee-like situations)': 6689},
#                      2011: {'Asylum-seekers': 2187,
#                             'Refugees (incl. refugee-like situations)': 6121},
#                      2012: {'Asylum-seekers': 2463,
#                             'Refugees (incl. refugee-like situations)': 5677},
#                      2013: {'Asylum-seekers': 4295,
#                             'Refugees (incl. refugee-like situations)': 3660},
#                      2014: {'Asylum-seekers': 5536,
#                             'Refugees (incl. refugee-like situations)': 3524},
#                      2015: {'Asylum-seekers': 7622,
#                             'Refugees (incl. refugee-like situations)': 3490},
#                      2016: {'Asylum-seekers': 7162,
#                             'Refugees (incl. refugee-like situations)': 3726},
#                      2017: {'Asylum-seekers': 6396,
#                             'Refugees (incl. refugee-like situations)': 3991}}},
#  'American Samoa': {'ASM': {2016: {'Asylum-seekers': 3,
#                                    'Refugees (incl. refugee-like situations)': 0},
#                             2017: {'Asylum-seekers': 0,
#                                    'Refugees (incl. refugee-like situations)': 0}}},
#  'Andorra': {'AND': {1994: {'Refugees (incl. refugee-like situations)': 2},
#                      1995: {'Refugees (incl. refugee-like situations)': 2},
#                      1996: {'Refugees (incl. refugee-like situations)': 3},
#                      1997: {'Refugees (incl. refugee-like situations)': 1},
#                      1998: {'Refugees (incl. refugee-like situations)': 2},
#                      1999: {'Refugees (incl. refugee-like situations)': 3},
#                      2000: {'Asylum-seekers': 1,
#                             'Refugees (incl. refugee-like situations)': 2},
#                      2001: {'Asylum-seekers': 7,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2002: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2003: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2004: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 3},
#                      2005: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 9},
#                      2006: {'Asylum-seekers': 1,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2007: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 9},
#                      2008: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 6},
#                      2009: {'Asylum-seekers': 2,
#                             'Refugees (incl. refugee-like situations)': 6},
#                      2010: {'Asylum-seekers': 2,
#                             'Refugees (incl. refugee-like situations)': 6},
#                      2011: {'Asylum-seekers': 0,
#                             'Refugees (incl. refugee-like situations)': 6},
#                      2012: {'Asylum-seekers': 0,
#                             'Refugees (incl. refugee-like situations)': 7},
#                      2013: {'Asylum-seekers': 0,
#                             'Refugees (incl. refugee-like situations)': 5},
#                      2014: {'Asylum-seekers': 0,
#                             'Refugees (incl. refugee-like situations)': 7},
#                      2015: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 5},
#                      2016: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 2},
#                      2017: {'Asylum-seekers': 0,
#                             'Refugees (incl. refugee-like situations)': 0}}},
#  'Angola': {'AGO': {1960: {'Refugees (incl. refugee-like situations)': 150000},
#                     1961: {'Refugees (incl. refugee-like situations)': 150000},
#                     1962: {'Refugees (incl. refugee-like situations)': 170000},
#                     1963: {'Refugees (incl. refugee-like situations)': 175000},
#                     1964: {'Refugees (incl. refugee-like situations)': 200000},
#                     1965: {'Refugees (incl. refugee-like situations)': 220000},
#                     1966: {'Refugees (incl. refugee-like situations)': 303800},
#                     1967: {'Refugees (incl. refugee-like situations)': 356200},
#                     1968: {'Refugees (incl. refugee-like situations)': 381360},
#                     1969: {'Refugees (incl. refugee-like situations)': 408190},
#                     1970: {'Refugees (incl. refugee-like situations)': 414120},
#                     1971: {'Refugees (incl. refugee-like situations)': 419690},
#                     1972: {'Refugees (incl. refugee-like situations)': 421500},
#                     1973: {'Refugees (incl. refugee-like situations)': 426550},
#                     1974: {'Refugees (incl. refugee-like situations)': 487390},
#                     1975: {'Refugees (incl. refugee-like situations)': 496830},
#                     1976: {'Refugees (incl. refugee-like situations)': 499190},
#                     1977: {'Refugees (incl. refugee-like situations)': 529830},
#                     1978: {'Refugees (incl. refugee-like situations)': 646110},
#                     1979: {'Refugees (incl. refugee-like situations)': 652980},
#                     1980: {'Refugees (incl. refugee-like situations)': 449030},
#                     1981: {'Refugees (incl. refugee-like situations)': 457060},
#                     1982: {'Refugees (incl. refugee-like situations)': 465891},
#                     1983: {'Refugees (incl. refugee-like situations)': 298110},
#                     1984: {'Refugees (incl. refugee-like situations)': 357821},
#                     1985: {'Refugees (incl. refugee-like situations)': 317392},
#                     1986: {'Refugees (incl. refugee-like situations)': 355412},
#                     1987: {'Refugees (incl. refugee-like situations)': 391733},
#                     1988: {'Refugees (incl. refugee-like situations)': 407566},
#                     1989: {'Refugees (incl. refugee-like situations)': 408692},
#                     1990: {'Refugees (incl. refugee-like situations)': 407760},
#                     1991: {'Refugees (incl. refugee-like situations)': 381636},
#                     1992: {'Refugees (incl. refugee-like situations)': 300492},
#                     1993: {'Refugees (incl. refugee-like situations)': 323831},
#                     1994: {'Refugees (incl. refugee-like situations)': 282577},
#                     1995: {'Refugees (incl. refugee-like situations)': 246657},
#                     1996: {'Refugees (incl. refugee-like situations)': 249687},
#                     1997: {'Refugees (incl. refugee-like situations)': 267696},
#                     1998: {'Refugees (incl. refugee-like situations)': 319430},
#                     1999: {'Refugees (incl. refugee-like situations)': 353478},
#                     2000: {'Asylum-seekers': 5493,
#                            'Refugees (incl. refugee-like situations)': 433760},
#                     2001: {'Asylum-seekers': 9853,
#                            'Refugees (incl. refugee-like situations)': 470625},
#                     2002: {'Asylum-seekers': 14282,
#                            'Refugees (incl. refugee-like situations)': 435421},
#                     2003: {'Asylum-seekers': 11718,
#                            'Refugees (incl. refugee-like situations)': 329583},
#                     2004: {'Asylum-seekers': 9548,
#                            'Refugees (incl. refugee-like situations)': 228851},
#                     2005: {'Asylum-seekers': 8352,
#                            'Refugees (incl. refugee-like situations)': 215827},
#                     2006: {'Asylum-seekers': 1581,
#                            'Refugees (incl. refugee-like situations)': 206501},
#                     2007: {'Asylum-seekers': 798,
#                            'Refugees (incl. refugee-like situations)': 186155},
#                     2008: {'Asylum-seekers': 741,
#                            'Refugees (incl. refugee-like situations)': 171393},
#                     2009: {'Asylum-seekers': 699,
#                            'Refugees (incl. refugee-like situations)': 141021},
#                     2010: {'Asylum-seekers': 732,
#                            'Refugees (incl. refugee-like situations)': 134858},
#                     2011: {'Asylum-seekers': 783,
#                            'Refugees (incl. refugee-like situations)': 128664},
#                     2012: {'Asylum-seekers': 1166,
#                            'Refugees (incl. refugee-like situations)': 19258},
#                     2013: {'Asylum-seekers': 1460,
#                            'Refugees (incl. refugee-like situations)': 10286},
#                     2014: {'Asylum-seekers': 1774,
#                            'Refugees (incl. refugee-like situations)': 9484},
#                     2015: {'Asylum-seekers': 3281,
#                            'Refugees (incl. refugee-like situations)': 11869},
#                     2016: {'Asylum-seekers': 4773,
#                            'Refugees (incl. refugee-like situations)': 8404},
#                     2017: {'Asylum-seekers': 7808,
#                            'Refugees (incl. refugee-like situations)': 8267}}},
#  'Anguilla': {'AIA': {2014: {'Asylum-seekers': 0,
#                              'Refugees (incl. refugee-like situations)': 1},
#                       2015: {'Asylum-seekers': 0,
#                              'Refugees (incl. refugee-like situations)': 1},
#                       2016: {'Asylum-seekers': 0,
#                              'Refugees (incl. refugee-like situations)': 1}}},
#  'Antigua and Barbuda': {'ATG': {1997: {'Refugees (incl. refugee-like situations)': 1},
#                                  1998: {'Refugees (incl. refugee-like situations)': 2},
#                                  1999: {'Refugees (incl. refugee-like situations)': 2},
#                                  2000: {'Asylum-seekers': 8,
#                                         'Refugees (incl. refugee-like situations)': 1},
#                                  2001: {'Asylum-seekers': 9,
#                                         'Refugees (incl. refugee-like situations)': 4},
#                                  2002: {'Asylum-seekers': 41,
#                                         'Refugees (incl. refugee-like situations)': 5},
#                                  2003: {'Asylum-seekers': 26,
#                                         'Refugees (incl. refugee-like situations)': 5},
#                                  2004: {'Asylum-seekers': 15,
#                                         'Refugees (incl. refugee-like situations)': 13},
#                                  2005: {'Asylum-seekers': 11,
#                                         'Refugees (incl. refugee-like situations)': 13},
#                                  2006: {'Asylum-seekers': 9,
#                                         'Refugees (incl. refugee-like situations)': 19},
#                                  2007: {'Asylum-seekers': 0,
#                                         'Refugees (incl. refugee-like situations)': 25},
#                                  2008: {'Asylum-seekers': 26,
#                                         'Refugees (incl. refugee-like situations)': 26},
#                                  2009: {'Asylum-seekers': 42,
#                                         'Refugees (incl. refugee-like situations)': 28},
#                                  2010: {'Asylum-seekers': 31,
#                                         'Refugees (incl. refugee-like situations)': 30},
#                                  2011: {'Asylum-seekers': 33,
#                                         'Refugees (incl. refugee-like situations)': 32},
#                                  2012: {'Asylum-seekers': 34,
#                                         'Refugees (incl. refugee-like situations)': 45},
#                                  2013: {'Asylum-seekers': 29,
#                                         'Refugees (incl. refugee-like situations)': 49},
#                                  2014: {'Asylum-seekers': 17,
#                                         'Refugees (incl. refugee-like situations)': 53},
#                                  2015: {'Asylum-seekers': 12,
#                                         'Refugees (incl. refugee-like situations)': 56},
#                                  2016: {'Asylum-seekers': 32,
#                                         'Refugees (incl. refugee-like situations)': 83},
#                                  2017: {'Asylum-seekers': 54,
#                                         'Refugees (incl. refugee-like situations)': 94}}},
#  'Argentina': {'ARG': {1980: {'Refugees (incl. refugee-like situations)': 38},
#                        1981: {'Refugees (incl. refugee-like situations)': 38},
#                        1982: {'Refugees (incl. refugee-like situations)': 1019},
#                        1983: {'Refugees (incl. refugee-like situations)': 42},
#                        1984: {'Refugees (incl. refugee-like situations)': 42},
#                        1985: {'Refugees (incl. refugee-like situations)': 51},
#                        1986: {'Refugees (incl. refugee-like situations)': 52},
#                        1987: {'Refugees (incl. refugee-like situations)': 47},
#                        1988: {'Refugees (incl. refugee-like situations)': 46},
#                        1989: {'Refugees (incl. refugee-like situations)': 103},
#                        1990: {'Refugees (incl. refugee-like situations)': 334},
#                        1991: {'Refugees (incl. refugee-like situations)': 198},
#                        1992: {'Refugees (incl. refugee-like situations)': 113},
#                        1993: {'Refugees (incl. refugee-like situations)': 98},
#                        1994: {'Refugees (incl. refugee-like situations)': 469},
#                        1995: {'Refugees (incl. refugee-like situations)': 330},
#                        1996: {'Refugees (incl. refugee-like situations)': 217},
#                        1997: {'Refugees (incl. refugee-like situations)': 159},
#                        1998: {'Refugees (incl. refugee-like situations)': 142},
#                        1999: {'Refugees (incl. refugee-like situations)': 586},
#                        2000: {'Asylum-seekers': 1562,
#                               'Refugees (incl. refugee-like situations)': 609},
#                        2001: {'Asylum-seekers': 1453,
#                               'Refugees (incl. refugee-like situations)': 659},
#                        2002: {'Asylum-seekers': 1333,
#                               'Refugees (incl. refugee-like situations)': 771},
#                        2003: {'Asylum-seekers': 1135,
#                               'Refugees (incl. refugee-like situations)': 784},
#                        2004: {'Asylum-seekers': 507,
#                               'Refugees (incl. refugee-like situations)': 796},
#                        2005: {'Asylum-seekers': 292,
#                               'Refugees (incl. refugee-like situations)': 856},
#                        2006: {'Asylum-seekers': 179,
#                               'Refugees (incl. refugee-like situations)': 894},
#                        2007: {'Asylum-seekers': 121,
#                               'Refugees (incl. refugee-like situations)': 1171},
#                        2008: {'Asylum-seekers': 143,
#                               'Refugees (incl. refugee-like situations)': 1047},
#                        2009: {'Asylum-seekers': 157,
#                               'Refugees (incl. refugee-like situations)': 608},
#                        2010: {'Asylum-seekers': 90,
#                               'Refugees (incl. refugee-like situations)': 557},
#                        2011: {'Asylum-seekers': 60,
#                               'Refugees (incl. refugee-like situations)': 518},
#                        2012: {'Asylum-seekers': 48,
#                               'Refugees (incl. refugee-like situations)': 447},
#                        2013: {'Asylum-seekers': 84,
#                               'Refugees (incl. refugee-like situations)': 388},
#                        2014: {'Asylum-seekers': 117,
#                               'Refugees (incl. refugee-like situations)': 318},
#                        2015: {'Asylum-seekers': 170,
#                               'Refugees (incl. refugee-like situations)': 194},
#                        2016: {'Asylum-seekers': 214,
#                               'Refugees (incl. refugee-like situations)': 128},
#                        2017: {'Asylum-seekers': 348,
#                               'Refugees (incl. refugee-like situations)': 111}}},
#  'Armenia': {'ARM': {1964: {'Refugees (incl. refugee-like situations)': 170},
#                      1968: {'Refugees (incl. refugee-like situations)': 200},
#                      1969: {'Refugees (incl. refugee-like situations)': 200},
#                      1970: {'Refugees (incl. refugee-like situations)': 200},
#                      1971: {'Refugees (incl. refugee-like situations)': 4070},
#                      1972: {'Refugees (incl. refugee-like situations)': 3500},
#                      1977: {'Refugees (incl. refugee-like situations)': 440},
#                      1978: {'Refugees (incl. refugee-like situations)': 420},
#                      1979: {'Refugees (incl. refugee-like situations)': 700},
#                      1980: {'Refugees (incl. refugee-like situations)': 333},
#                      1981: {'Refugees (incl. refugee-like situations)': 333},
#                      1982: {'Refugees (incl. refugee-like situations)': 733},
#                      1983: {'Refugees (incl. refugee-like situations)': 333},
#                      1984: {'Refugees (incl. refugee-like situations)': 333},
#                      1985: {'Refugees (incl. refugee-like situations)': 333},
#                      1986: {'Refugees (incl. refugee-like situations)': 528},
#                      1987: {'Refugees (incl. refugee-like situations)': 208},
#                      1988: {'Refugees (incl. refugee-like situations)': 301},
#                      1989: {'Refugees (incl. refugee-like situations)': 1},
#                      1990: {'Refugees (incl. refugee-like situations)': 1},
#                      1991: {'Refugees (incl. refugee-like situations)': 1},
#                      1992: {'Refugees (incl. refugee-like situations)': 195003},
#                      1993: {'Refugees (incl. refugee-like situations)': 200116},
#                      1994: {'Refugees (incl. refugee-like situations)': 201842},
#                      1995: {'Refugees (incl. refugee-like situations)': 201442},
#                      1996: {'Refugees (incl. refugee-like situations)': 203231},
#                      1997: {'Refugees (incl. refugee-like situations)': 203690},
#                      1998: {'Refugees (incl. refugee-like situations)': 193150},
#                      1999: {'Refugees (incl. refugee-like situations)': 193231},
#                      2000: {'Asylum-seekers': 5228,
#                             'Refugees (incl. refugee-like situations)': 5786},
#                      2001: {'Asylum-seekers': 6078,
#                             'Refugees (incl. refugee-like situations)': 7207},
#                      2002: {'Asylum-seekers': 5669,
#                             'Refugees (incl. refugee-like situations)': 13249},
#                      2003: {'Asylum-seekers': 4967,
#                             'Refugees (incl. refugee-like situations)': 13162},
#                      2004: {'Asylum-seekers': 4049,
#                             'Refugees (incl. refugee-like situations)': 13410},
#                      2005: {'Asylum-seekers': 4352,
#                             'Refugees (incl. refugee-like situations)': 13965},
#                      2006: {'Asylum-seekers': 5402,
#                             'Refugees (incl. refugee-like situations)': 14917},
#                      2007: {'Asylum-seekers': 3983,
#                             'Refugees (incl. refugee-like situations)': 15436},
#                      2008: {'Asylum-seekers': 3768,
#                             'Refugees (incl. refugee-like situations)': 16336},
#                      2009: {'Asylum-seekers': 4081,
#                             'Refugees (incl. refugee-like situations)': 18000},
#                      2010: {'Asylum-seekers': 2957,
#                             'Refugees (incl. refugee-like situations)': 17547},
#                      2011: {'Asylum-seekers': 2657,
#                             'Refugees (incl. refugee-like situations)': 16487},
#                      2012: {'Asylum-seekers': 2889,
#                             'Refugees (incl. refugee-like situations)': 15935},
#                      2013: {'Asylum-seekers': 5369,
#                             'Refugees (incl. refugee-like situations)': 11998},
#                      2014: {'Asylum-seekers': 6943,
#                             'Refugees (incl. refugee-like situations)': 11848},
#                      2015: {'Asylum-seekers': 8502,
#                             'Refugees (incl. refugee-like situations)': 11214},
#                      2016: {'Asylum-seekers': 13100,
#                             'Refugees (incl. refugee-like situations)': 10719},
#                      2017: {'Asylum-seekers': 14907,
#                             'Refugees (incl. refugee-like situations)': 10766}}},
#  'Aruba': {'ABW': {2010: {'Asylum-seekers': 1},
#                    2011: {'Asylum-seekers': 0},
#                    2012: {'Asylum-seekers': 0},
#                    2014: {'Asylum-seekers': 0,
#                           'Refugees (incl. refugee-like situations)': 0}}},
#  'Australia': {'AUS': {1994: {'Refugees (incl. refugee-like situations)': 2},
#                        1995: {'Refugees (incl. refugee-like situations)': 1},
#                        1996: {'Refugees (incl. refugee-like situations)': 1},
#                        1997: {'Refugees (incl. refugee-like situations)': 2},
#                        1998: {'Refugees (incl. refugee-like situations)': 1},
#                        1999: {'Refugees (incl. refugee-like situations)': 3},
#                        2000: {'Asylum-seekers': 4,
#                               'Refugees (incl. refugee-like situations)': 3},
#                        2001: {'Asylum-seekers': 11,
#                               'Refugees (incl. refugee-like situations)': 1},
#                        2002: {'Asylum-seekers': 15,
#                               'Refugees (incl. refugee-like situations)': 10},
#                        2003: {'Asylum-seekers': 7,
#                               'Refugees (incl. refugee-like situations)': 15},
#                        2004: {'Asylum-seekers': 12,
#                               'Refugees (incl. refugee-like situations)': 13},
#                        2005: {'Asylum-seekers': 4,
#                               'Refugees (incl. refugee-like situations)': 44},
#                        2006: {'Asylum-seekers': 7,
#                               'Refugees (incl. refugee-like situations)': 29},
#                        2007: {'Asylum-seekers': 1,
#                               'Refugees (incl. refugee-like situations)': 63},
#                        2008: {'Asylum-seekers': 10,
#                               'Refugees (incl. refugee-like situations)': 43},
#                        2009: {'Asylum-seekers': 11,
#                               'Refugees (incl. refugee-like situations)': 28},
#                        2010: {'Asylum-seekers': 10,
#                               'Refugees (incl. refugee-like situations)': 37},
#                        2011: {'Asylum-seekers': 8,
#                               'Refugees (incl. refugee-like situations)': 39},
#                        2012: {'Asylum-seekers': 9,
#                               'Refugees (incl. refugee-like situations)': 48},
#                        2013: {'Asylum-seekers': 12,
#                               'Refugees (incl. refugee-like situations)': 28},
#                        2014: {'Asylum-seekers': 7,
#                               'Refugees (incl. refugee-like situations)': 25},
#                        2015: {'Asylum-seekers': 5,
#                               'Refugees (incl. refugee-like situations)': 20},
#                        2016: {'Asylum-seekers': 15,
#                               'Refugees (incl. refugee-like situations)': 14},
#                        2017: {'Asylum-seekers': 0,
#                               'Refugees (incl. refugee-like situations)': 0}}},
#  'Austria': {'AUT': {1994: {'Refugees (incl. refugee-like situations)': 60},
#                      1995: {'Refugees (incl. refugee-like situations)': 49},
#                      1996: {'Refugees (incl. refugee-like situations)': 52},
#                      1997: {'Refugees (incl. refugee-like situations)': 55},
#                      1998: {'Refugees (incl. refugee-like situations)': 60},
#                      1999: {'Refugees (incl. refugee-like situations)': 48},
#                      2000: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 35},
#                      2001: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 29},
#                      2002: {'Asylum-seekers': 12,
#                             'Refugees (incl. refugee-like situations)': 72},
#                      2003: {'Asylum-seekers': 11,
#                             'Refugees (incl. refugee-like situations)': 66},
#                      2004: {'Asylum-seekers': 5,
#                             'Refugees (incl. refugee-like situations)': 47},
#                      2005: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 66},
#                      2006: {'Asylum-seekers': 16,
#                             'Refugees (incl. refugee-like situations)': 34},
#                      2007: {'Asylum-seekers': 6,
#                             'Refugees (incl. refugee-like situations)': 23},
#                      2008: {'Asylum-seekers': 2,
#                             'Refugees (incl. refugee-like situations)': 14},
#                      2009: {'Asylum-seekers': 2,
#                             'Refugees (incl. refugee-like situations)': 12},
#                      2010: {'Asylum-seekers': 3,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2011: {'Asylum-seekers': 2,
#                             'Refugees (incl. refugee-like situations)': 11},
#                      2012: {'Asylum-seekers': 6,
#                             'Refugees (incl. refugee-like situations)': 12},
#                      2013: {'Asylum-seekers': 9,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2014: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 10},
#                      2015: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 4},
#                      2016: {'Asylum-seekers': 6,
#                             'Refugees (incl. refugee-like situations)': 6},
#                      2017: {'Asylum-seekers': 23,
#                             'Refugees (incl. refugee-like situations)': 0}}},
#  'Azerbaijan': {'AZE': {1992: {'Refugees (incl. refugee-like situations)': 300000},
#                         1993: {'Refugees (incl. refugee-like situations)': 328005},
#                         1994: {'Refugees (incl. refugee-like situations)': 299095},
#                         1995: {'Refugees (incl. refugee-like situations)': 200520},
#                         1996: {'Refugees (incl. refugee-like situations)': 236086},
#                         1997: {'Refugees (incl. refugee-like situations)': 234950},
#                         1998: {'Refugees (incl. refugee-like situations)': 329657},
#                         1999: {'Refugees (incl. refugee-like situations)': 311131},
#                         2000: {'Asylum-seekers': 5285,
#                                'Refugees (incl. refugee-like situations)': 284277},
#                         2001: {'Asylum-seekers': 5746,
#                                'Refugees (incl. refugee-like situations)': 268759},
#                         2002: {'Asylum-seekers': 4999,
#                                'Refugees (incl. refugee-like situations)': 260214},
#                         2003: {'Asylum-seekers': 4630,
#                                'Refugees (incl. refugee-like situations)': 253255},
#                         2004: {'Asylum-seekers': 3951,
#                                'Refugees (incl. refugee-like situations)': 250589},
#                         2005: {'Asylum-seekers': 4125,
#                                'Refugees (incl. refugee-like situations)': 233675},
#                         2006: {'Asylum-seekers': 3098,
#                                'Refugees (incl. refugee-like situations)': 126068},
#                         2007: {'Asylum-seekers': 1902,
#                                'Refugees (incl. refugee-like situations)': 15916},
#                         2008: {'Asylum-seekers': 1872,
#                                'Refugees (incl. refugee-like situations)': 16319},
#                         2009: {'Asylum-seekers': 2470,
#                                'Refugees (incl. refugee-like situations)': 16939},
#                         2010: {'Asylum-seekers': 2072,
#                                'Refugees (incl. refugee-like situations)': 16753},
#                         2011: {'Asylum-seekers': 2193,
#                                'Refugees (incl. refugee-like situations)': 16162},
#                         2012: {'Asylum-seekers': 2193,
#                                'Refugees (incl. refugee-like situations)': 15537},
#                         2013: {'Asylum-seekers': 3622,
#                                'Refugees (incl. refugee-like situations)': 10814},
#                         2014: {'Asylum-seekers': 4584,
#                                'Refugees (incl. refugee-like situations)': 10515},
#                         2015: {'Asylum-seekers': 5230,
#                                'Refugees (incl. refugee-like situations)': 9710},
#                         2016: {'Asylum-seekers': 8097,
#                                'Refugees (incl. refugee-like situations)': 10112},
#                         2017: {'Asylum-seekers': 9537,
#                                'Refugees (incl. refugee-like situations)': 10878}}},
#  'Bahamas': {'BHS': {1998: {'Refugees (incl. refugee-like situations)': 1},
#                      1999: {'Refugees (incl. refugee-like situations)': 1},
#                      2000: {'Asylum-seekers': 10,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2001: {'Asylum-seekers': 24},
#                      2002: {'Asylum-seekers': 161,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2003: {'Asylum-seekers': 18,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2004: {'Asylum-seekers': 20,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2005: {'Asylum-seekers': 18,
#                             'Refugees (incl. refugee-like situations)': 1},
#                      2006: {'Asylum-seekers': 19,
#                             'Refugees (incl. refugee-like situations)': 14},
#                      2007: {'Asylum-seekers': 25,
#                             'Refugees (incl. refugee-like situations)': 14},
#                      2008: {'Asylum-seekers': 25,
#                             'Refugees (incl. refugee-like situations)': 15},
#                      2009: {'Asylum-seekers': 32,
#                             'Refugees (incl. refugee-like situations)': 15},
#                      2010: {'Asylum-seekers': 30,
#                             'Refugees (incl. refugee-like situations)': 17},
#                      2011: {'Asylum-seekers': 37,
#                             'Refugees (incl. refugee-like situations)': 185},
#                      2012: {'Asylum-seekers': 38,
#                             'Refugees (incl. refugee-like situations)': 196},
#                      2013: {'Asylum-seekers': 27,
#                             'Refugees (incl. refugee-like situations)': 210},
#                      2014: {'Asylum-seekers': 42,
#                             'Refugees (incl. refugee-like situations)': 215},
#                      2015: {'Asylum-seekers': 82,
#                             'Refugees (incl. refugee-like situations)': 215},
#                      2016: {'Asylum-seekers': 121,
#                             'Refugees (incl. refugee-like situations)': 299},
#                      2017: {'Asylum-seekers': 230,
#                             'Refugees (incl. refugee-like situations)': 373}}},
#  'Bahrain': {'BHR': {1990: {'Refugees (incl. refugee-like situations)': 39},
#                      1991: {'Refugees (incl. refugee-like situations)': 52},
#                      1992: {'Refugees (incl. refugee-like situations)': 53},
#                      1993: {'Refugees (incl. refugee-like situations)': 60},
#                      1994: {'Refugees (incl. refugee-like situations)': 75},
#                      1995: {'Refugees (incl. refugee-like situations)': 71},
#                      1996: {'Refugees (incl. refugee-like situations)': 63},
#                      1997: {'Refugees (incl. refugee-like situations)': 82},
#                      1998: {'Refugees (incl. refugee-like situations)': 97},
#                      1999: {'Refugees (incl. refugee-like situations)': 129},
#                      2000: {'Asylum-seekers': 55,
#                             'Refugees (incl. refugee-like situations)': 95},
#                      2001: {'Asylum-seekers': 9,
#                             'Refugees (incl. refugee-like situations)': 46},
#                      2002: {'Asylum-seekers': 14,
#                             'Refugees (incl. refugee-like situations)': 50},
#                      2003: {'Asylum-seekers': 12,
#                             'Refugees (incl. refugee-like situations)': 52},
#                      2004: {'Asylum-seekers': 22,
#                             'Refugees (incl. refugee-like situations)': 52},
#                      2005: {'Asylum-seekers': 27,
#                             'Refugees (incl. refugee-like situations)': 41},
#                      2006: {'Asylum-seekers': 20,
#                             'Refugees (incl. refugee-like situations)': 62},
#                      2007: {'Asylum-seekers': 18,
#                             'Refugees (incl. refugee-like situations)': 73},
#                      2008: {'Asylum-seekers': 13,
#                             'Refugees (incl. refugee-like situations)': 80},
#                      2009: {'Asylum-seekers': 4,
#                             'Refugees (incl. refugee-like situations)': 79},
#                      2010: {'Asylum-seekers': 26,
#                             'Refugees (incl. refugee-like situations)': 87},
#                      2011: {'Asylum-seekers': 76,
#                             'Refugees (incl. refugee-like situations)': 215},
#                      2012: {'Asylum-seekers': 110,
#                             'Refugees (incl. refugee-like situations)': 297},
#                      2013: {'Asylum-seekers': 91,
#                             'Refugees (incl. refugee-like situations)': 275},
#                      2014: {'Asylum-seekers': 101,
# ...
#                             1991: {'Refugees (incl. refugee-like situations)': 165000},
#                             1992: {'Refugees (incl. refugee-like situations)': 165000},
#                             1993: {'Refugees (incl. refugee-like situations)': 165000},
#                             1994: {'Refugees (incl. refugee-like situations)': 166493},
#                             1995: {'Refugees (incl. refugee-like situations)': 165000},
#                             1996: {'Refugees (incl. refugee-like situations)': 166328},
#                             1997: {'Refugees (incl. refugee-like situations)': 166099},
#                             1998: {'Refugees (incl. refugee-like situations)': 165967},
#                             1999: {'Refugees (incl. refugee-like situations)': 165868},
#                             2000: {'Asylum-seekers': 4,
#                                    'Refugees (incl. refugee-like situations)': 165810},
#                             2001: {'Asylum-seekers': 3,
#                                    'Refugees (incl. refugee-like situations)': 165910},
#                             2002: {'Asylum-seekers': 5,
#                                    'Refugees (incl. refugee-like situations)': 165884},
#                             2003: {'Asylum-seekers': 20,
#                                    'Refugees (incl. refugee-like situations)': 165729},
#                             2004: {'Asylum-seekers': 21,
#                                    'Refugees (incl. refugee-like situations)': 165731},
#                             2005: {'Asylum-seekers': 24,
#                                    'Refugees (incl. refugee-like situations)': 90652},
#                             2006: {'Asylum-seekers': 28,
#                                    'Refugees (incl. refugee-like situations)': 90614},
#                             2007: {'Asylum-seekers': 29,
#                                    'Refugees (incl. refugee-like situations)': 116594},
#                             2008: {'Asylum-seekers': 31,
#                                    'Refugees (incl. refugee-like situations)': 116530},
#                             2009: {'Asylum-seekers': 21,
#                                    'Refugees (incl. refugee-like situations)': 116474},
#                             2010: {'Asylum-seekers': 34,
#                                    'Refugees (incl. refugee-like situations)': 116415},
#                             2011: {'Asylum-seekers': 14,
#                                    'Refugees (incl. refugee-like situations)': 116413},
#                             2012: {'Asylum-seekers': 126,
#                                    'Refugees (incl. refugee-like situations)': 116452},
#                             2013: {'Asylum-seekers': 411,
#                                    'Refugees (incl. refugee-like situations)': 116504},
#                             2014: {'Asylum-seekers': 1180,
#                                    'Refugees (incl. refugee-like situations)': 116482},
#                             2015: {'Asylum-seekers': 1446,
#                                    'Refugees (incl. refugee-like situations)': 116547},
#                             2016: {'Asylum-seekers': 1999,
#                                    'Refugees (incl. refugee-like situations)': 116649},
#                             2017: {'Asylum-seekers': 1839,
#                                    'Refugees (incl. refugee-like situations)': 116758}}},
#  'Yemen': {'YEM': {1978: {'Refugees (incl. refugee-like situations)': 15000},
#                    1979: {'Refugees (incl. refugee-like situations)': 15000},
#                    1980: {'Refugees (incl. refugee-like situations)': 15001},
#                    1981: {'Refugees (incl. refugee-like situations)': 1},
#                    1982: {'Refugees (incl. refugee-like situations)': 1},
#                    1983: {'Refugees (incl. refugee-like situations)': 1},
#                    1984: {'Refugees (incl. refugee-like situations)': 1},
#                    1985: {'Refugees (incl. refugee-like situations)': 1},
#                    1986: {'Refugees (incl. refugee-like situations)': 100001},
#                    1987: {'Refugees (incl. refugee-like situations)': 70001},
#                    1988: {'Refugees (incl. refugee-like situations)': 77001},
#                    1989: {'Refugees (incl. refugee-like situations)': 77003},
#                    1990: {'Refugees (incl. refugee-like situations)': 8},
#                    1991: {'Refugees (incl. refugee-like situations)': 73},
#                    1992: {'Refugees (incl. refugee-like situations)': 31},
#                    1993: {'Refugees (incl. refugee-like situations)': 39},
#                    1994: {'Refugees (incl. refugee-like situations)': 150},
#                    1995: {'Refugees (incl. refugee-like situations)': 369},
#                    1996: {'Refugees (incl. refugee-like situations)': 1154},
#                    1997: {'Refugees (incl. refugee-like situations)': 1721},
#                    1998: {'Refugees (incl. refugee-like situations)': 1935},
#                    1999: {'Refugees (incl. refugee-like situations)': 2022},
#                    2000: {'Asylum-seekers': 856,
#                           'Refugees (incl. refugee-like situations)': 2113},
#                    2001: {'Asylum-seekers': 743,
#                           'Refugees (incl. refugee-like situations)': 1985},
#                    2002: {'Asylum-seekers': 640,
#                           'Refugees (incl. refugee-like situations)': 1600},
#                    2003: {'Asylum-seekers': 479,
#                           'Refugees (incl. refugee-like situations)': 1597},
#                    2004: {'Asylum-seekers': 338,
#                           'Refugees (incl. refugee-like situations)': 1606},
#                    2005: {'Asylum-seekers': 419,
#                           'Refugees (incl. refugee-like situations)': 1325},
#                    2006: {'Asylum-seekers': 359,
#                           'Refugees (incl. refugee-like situations)': 1362},
#                    2007: {'Asylum-seekers': 320,
#                           'Refugees (incl. refugee-like situations)': 1632},
#                    2008: {'Asylum-seekers': 473,
#                           'Refugees (incl. refugee-like situations)': 1777},
#                    2009: {'Asylum-seekers': 620,
#                           'Refugees (incl. refugee-like situations)': 1934},
#                    2010: {'Asylum-seekers': 627,
#                           'Refugees (incl. refugee-like situations)': 2076},
#                    2011: {'Asylum-seekers': 1162,
#                           'Refugees (incl. refugee-like situations)': 2323},
#                    2012: {'Asylum-seekers': 1592,
#                           'Refugees (incl. refugee-like situations)': 2594},
#                    2013: {'Asylum-seekers': 1882,
#                           'Refugees (incl. refugee-like situations)': 2428},
#                    2014: {'Asylum-seekers': 2760,
#                           'Refugees (incl. refugee-like situations)': 2631},
#                    2015: {'Asylum-seekers': 10074,
#                           'Refugees (incl. refugee-like situations)': 15897},
#                    2016: {'Asylum-seekers': 15858,
#                           'Refugees (incl. refugee-like situations)': 18452},
#                    2017: {'Asylum-seekers': 24599,
#                           'Refugees (incl. refugee-like situations)': 23500}}},
#  'Zambia': {'ZMB': {1968: {'Refugees (incl. refugee-like situations)': 15000},
#                     1969: {'Refugees (incl. refugee-like situations)': 13000},
#                     1970: {'Refugees (incl. refugee-like situations)': 9000},
#                     1971: {'Refugees (incl. refugee-like situations)': 750},
#                     1972: {'Refugees (incl. refugee-like situations)': 750},
#                     1973: {'Refugees (incl. refugee-like situations)': 750},
#                     1974: {'Refugees (incl. refugee-like situations)': 4000},
#                     1975: {'Refugees (incl. refugee-like situations)': 750},
#                     1976: {'Refugees (incl. refugee-like situations)': 750},
#                     1979: {'Refugees (incl. refugee-like situations)': 1000},
#                     1980: {'Refugees (incl. refugee-like situations)': 1210},
#                     1981: {'Refugees (incl. refugee-like situations)': 1200},
#                     1982: {'Refugees (incl. refugee-like situations)': 1200},
#                     1983: {'Refugees (incl. refugee-like situations)': 1200},
#                     1988: {'Refugees (incl. refugee-like situations)': 1},
#                     1989: {'Refugees (incl. refugee-like situations)': 1},
#                     1990: {'Refugees (incl. refugee-like situations)': 1},
#                     1991: {'Refugees (incl. refugee-like situations)': 1},
#                     1992: {'Refugees (incl. refugee-like situations)': 1990},
#                     1993: {'Refugees (incl. refugee-like situations)': 1574},
#                     1994: {'Refugees (incl. refugee-like situations)': 16},
#                     1995: {'Refugees (incl. refugee-like situations)': 20},
#                     1996: {'Refugees (incl. refugee-like situations)': 40},
#                     1997: {'Refugees (incl. refugee-like situations)': 63},
#                     1998: {'Refugees (incl. refugee-like situations)': 77},
#                     1999: {'Refugees (incl. refugee-like situations)': 87},
#                     2000: {'Asylum-seekers': 123,
#                            'Refugees (incl. refugee-like situations)': 98},
#                     2001: {'Asylum-seekers': 107,
#                            'Refugees (incl. refugee-like situations)': 62},
#                     2002: {'Asylum-seekers': 177,
#                            'Refugees (incl. refugee-like situations)': 92},
#                     2003: {'Asylum-seekers': 263,
#                            'Refugees (incl. refugee-like situations)': 100},
#                     2004: {'Asylum-seekers': 382,
#                            'Refugees (incl. refugee-like situations)': 124},
#                     2005: {'Asylum-seekers': 481,
#                            'Refugees (incl. refugee-like situations)': 151},
#                     2006: {'Asylum-seekers': 67,
#                            'Refugees (incl. refugee-like situations)': 204},
#                     2007: {'Asylum-seekers': 496,
#                            'Refugees (incl. refugee-like situations)': 196},
#                     2008: {'Asylum-seekers': 495,
#                            'Refugees (incl. refugee-like situations)': 195},
#                     2009: {'Asylum-seekers': 54,
#                            'Refugees (incl. refugee-like situations)': 206},
#                     2010: {'Asylum-seekers': 58,
#                            'Refugees (incl. refugee-like situations)': 228},
#                     2011: {'Asylum-seekers': 190,
#                            'Refugees (incl. refugee-like situations)': 240},
#                     2012: {'Asylum-seekers': 260,
#                            'Refugees (incl. refugee-like situations)': 243},
#                     2013: {'Asylum-seekers': 305,
#                            'Refugees (incl. refugee-like situations)': 232},
#                     2014: {'Asylum-seekers': 301,
#                            'Refugees (incl. refugee-like situations)': 316},
#                     2015: {'Asylum-seekers': 442,
#                            'Refugees (incl. refugee-like situations)': 344},
#                     2016: {'Asylum-seekers': 310,
#                            'Refugees (incl. refugee-like situations)': 265},
#                     2017: {'Asylum-seekers': 158,
#                            'Refugees (incl. refugee-like situations)': 250}}},
#  'Zimbabwe': {'ZWE': {1975: {'Refugees (incl. refugee-like situations)': 14720},
#                       1976: {'Refugees (incl. refugee-like situations)': 31220},
#                       1977: {'Refugees (incl. refugee-like situations)': 76520},
#                       1978: {'Refugees (incl. refugee-like situations)': 163160},
#                       1979: {'Refugees (incl. refugee-like situations)': 197640},
#                       1980: {'Refugees (incl. refugee-like situations)': 160},
#                       1981: {'Refugees (incl. refugee-like situations)': 190},
#                       1983: {'Refugees (incl. refugee-like situations)': 3200},
#                       1984: {'Refugees (incl. refugee-like situations)': 3760},
#                       1985: {'Refugees (incl. refugee-like situations)': 4250},
#                       1986: {'Refugees (incl. refugee-like situations)': 3230},
#                       1987: {'Refugees (incl. refugee-like situations)': 3830},
#                       1988: {'Refugees (incl. refugee-like situations)': 627},
#                       1989: {'Refugees (incl. refugee-like situations)': 3},
#                       1990: {'Refugees (incl. refugee-like situations)': 4},
#                       1991: {'Refugees (incl. refugee-like situations)': 128},
#                       1992: {'Refugees (incl. refugee-like situations)': 9},
#                       1993: {'Refugees (incl. refugee-like situations)': 17},
#                       1994: {'Refugees (incl. refugee-like situations)': 42},
#                       1995: {'Refugees (incl. refugee-like situations)': 36},
#                       1996: {'Refugees (incl. refugee-like situations)': 34},
#                       1997: {'Refugees (incl. refugee-like situations)': 38},
#                       1998: {'Refugees (incl. refugee-like situations)': 42},
#                       1999: {'Refugees (incl. refugee-like situations)': 43},
#                       2000: {'Asylum-seekers': 209,
#                              'Refugees (incl. refugee-like situations)': 109},
#                       2001: {'Asylum-seekers': 2699,
#                              'Refugees (incl. refugee-like situations)': 257},
#                       2002: {'Asylum-seekers': 1161,
#                              'Refugees (incl. refugee-like situations)': 4030},
#                       2003: {'Asylum-seekers': 3471,
#                              'Refugees (incl. refugee-like situations)': 7162},
#                       2004: {'Asylum-seekers': 9414,
#                              'Refugees (incl. refugee-like situations)': 9568},
#                       2005: {'Asylum-seekers': 17326,
#                              'Refugees (incl. refugee-like situations)': 11251},
#                       2006: {'Asylum-seekers': 1215,
#                              'Refugees (incl. refugee-like situations)': 12781},
#                       2007: {'Asylum-seekers': 34333,
#                              'Refugees (incl. refugee-like situations)': 14374},
#                       2008: {'Asylum-seekers': 34795,
#                              'Refugees (incl. refugee-like situations)': 16841},
#                       2009: {'Asylum-seekers': 1404,
#                              'Refugees (incl. refugee-like situations)': 22449},
#                       2010: {'Asylum-seekers': 1016,
#                              'Refugees (incl. refugee-like situations)': 24089},
#                       2011: {'Asylum-seekers': 36699,
#                              'Refugees (incl. refugee-like situations)': 25048},
#                       2012: {'Asylum-seekers': 41730,
#                              'Refugees (incl. refugee-like situations)': 22101},
#                       2013: {'Asylum-seekers': 41838,
#                              'Refugees (incl. refugee-like situations)': 19734},
#                       2014: {'Asylum-seekers': 42434,
#                              'Refugees (incl. refugee-like situations)': 22492},
#                       2015: {'Asylum-seekers': 57391,
#                              'Refugees (incl. refugee-like situations)': 21344},
#                       2016: {'Asylum-seekers': 43202,
#                              'Refugees (incl. refugee-like situations)': 18156},
#                       2017: {'Asylum-seekers': 21754,
#                              'Refugees (incl. refugee-like situations)': 17390}}}}

# %%
refugees_4.head()
# Out:
#         Origin             Destination   COO_COD dcode ocode  COO_total    Pct
# 0  Afghanistan                Pakistan  18220178   PAK   AFG   30027956  0.607
# 1  Afghanistan  Iran (Islamic Rep. of)  10173716   IRN   AFG   30027956  0.339
# 2  Afghanistan                 Germany    404959   DEU   AFG   30027956  0.013
# 3  Afghanistan          United Kingdom    165161   GBR   AFG   30027956  0.006
# 4  Afghanistan                 Austria    133448   AUT   AFG   30027956  0.004

# %%
# Country Codes for Kaori
cc_articles = refugees_4[["Origin", "ocode"]]
cc_articles = cc_articles.drop_duplicates()
cc_articles.reset_index(drop=True, inplace=True)
cc_articles.head()
# Out:
#            Origin ocode
# 0     Afghanistan   AFG
# 1         Albania   ALB
# 2         Algeria   DZA
# 3  American Samoa   ASM
# 4         Andorra   AND

# %%
cc_articles = cc_articles.rename(columns={'Origin':'Country Name', 'ocode':'Country Code'})
cc_articles.head()
# Out:
#      Country Name Country Code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
cc_dict = {}
for x in range(len(cc_articles)):
    row = cc_articles.iloc[x,:]
    cc_dict[row[1]] = row[0]
pprint(cc_dict)
# Out:
# {None: 'Various/Unknown',
#  'ABW': 'Aruba',
#  'AFG': 'Afghanistan',
#  'AGO': 'Angola',
#  'AIA': 'Anguilla',
#  'ALB': 'Albania',
#  'AND': 'Andorra',
#  'ARE': 'United Arab Emirates',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ASM': 'American Samoa',
#  'ATG': 'Antigua and Barbuda',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AZE': 'Azerbaijan',
#  'BDI': 'Burundi',
#  'BEL': 'Belgium',
#  'BEN': 'Benin',
#  'BFA': 'Burkina Faso',
#  'BGD': 'Bangladesh',
#  'BGR': 'Bulgaria',
#  'BHR': 'Bahrain',
#  'BHS': 'Bahamas',
#  'BIH': 'Bosnia and Herzegovina',
#  'BLR': 'Belarus',
#  'BLZ': 'Belize',
#  'BMU': 'Bermuda',
#  'BOL': 'Bolivia (Plurinational State of)',
#  'BRA': 'Brazil',
#  'BRB': 'Barbados',
#  'BRN': 'Brunei Darussalam',
#  'BTN': 'Bhutan',
#  'BWA': 'Botswana',
#  'CAF': 'Central African Rep.',
#  'CAN': 'Canada',
#  'CHE': 'Switzerland',
#  'CHL': 'Chile',
#  'CHN': 'China',
#  'CIV': "CÌ«te d'Ivoire",
#  'CMR': 'Cameroon',
#  'COD': 'Dem. Rep. of the Congo',
#  'COG': 'Congo',
#  'COK': 'Cook Islands',
#  'COL': 'Colombia',
#  'COM': 'Comoros',
#  'CPV': 'Cabo Verde',
#  'CRI': 'Costa Rica',
#  'CUB': 'Cuba',
#  'CUW': 'CuraÌ¤ao',
#  'CYM': 'Cayman Islands',
#  'CYP': 'Cyprus',
#  'CZE': 'Czech Rep.',
#  'DEU': 'Germany',
#  'DJI': 'Djibouti',
#  'DMA': 'Dominica',
#  'DNK': 'Denmark',
#  'DOM': 'Dominican Rep.',
#  'DZA': 'Algeria',
#  'ECU': 'Ecuador',
#  'EGY': 'Egypt',
#  'ERI': 'Eritrea',
#  'ESH': 'Western Sahara',
#  'ESP': 'Spain',
#  'EST': 'Estonia',
#  'ETH': 'Ethiopia',
#  'FIN': 'Finland',
#  'FJI': 'Fiji',
#  'FRA': 'France',
#  'FSM': 'Micronesia (Federated States of)',
#  'GAB': 'Gabon',
#  'GBR': 'United Kingdom',
#  'GEO': 'Georgia',
#  'GHA': 'Ghana',
#  'GIB': 'Gibraltar',
#  'GIN': 'Guinea',
#  'GLP': 'Guadeloupe',
#  'GMB': 'Gambia',
#  'GNB': 'Guinea-Bissau',
#  'GNQ': 'Equatorial Guinea',
#  'GRC': 'Greece',
#  'GRD': 'Grenada',
#  'GTM': 'Guatemala',
#  'GUF': 'French Guiana',
#  'GUM': 'Guam',
#  'GUY': 'Guyana',
#  'HKG': 'China, Hong Kong SAR',
#  'HND': 'Honduras',
#  'HRV': 'Croatia',
#  'HTI': 'Haiti',
#  'HUN': 'Hungary',
#  'IDN': 'Indonesia',
#  'IND': 'India',
#  'IRL': 'Ireland',
#  'IRN': 'Iran (Islamic Rep. of)',
#  'IRQ': 'Iraq',
#  'ISL': 'Iceland',
#  'ISR': 'Israel',
#  'ITA': 'Italy',
#  'JAM': 'Jamaica',
#  'JOR': 'Jordan',
#  'JPN': 'Japan',
#  'KAZ': 'Kazakhstan',
#  'KEN': 'Kenya',
#  'KGZ': 'Kyrgyzstan',
#  'KHM': 'Cambodia',
#  'KIR': 'Kiribati',
#  'KNA': 'Saint Kitts and Nevis',
#  'KOR': 'Rep. of Korea',
#  'KWT': 'Kuwait',
#  'LAO': "Lao People's Dem. Rep.",
#  'LBN': 'Lebanon',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'LCA': 'Saint Lucia',
#  'LIE': 'Liechtenstein',
#  'LKA': 'Sri Lanka',
#  'LSO': 'Lesotho',
#  'LTU': 'Lithuania',
#  'LUX': 'Luxembourg',
#  'LVA': 'Latvia',
#  'MAC': 'China, Macao SAR',
#  'MAR': 'Morocco',
#  'MCO': 'Monaco',
#  'MDA': 'Rep. of Moldova',
#  'MDG': 'Madagascar',
#  'MDV': 'Maldives',
#  'MEX': 'Mexico',
#  'MHL': 'Marshall Islands',
#  'MKD': 'The former Yugoslav Republic of Macedonia',
#  'MLI': 'Mali',
#  'MLT': 'Malta',
#  'MMR': 'Myanmar',
#  'MNE': 'Montenegro',
#  'MNG': 'Mongolia',
#  'MOZ': 'Mozambique',
#  'MRT': 'Mauritania',
#  'MUS': 'Mauritius',
#  'MWI': 'Malawi',
#  'MYS': 'Malaysia',
#  'NAM': 'Namibia',
#  'NER': 'Niger',
#  'NFK': 'Norfolk Island',
#  'NGA': 'Nigeria',
#  'NIC': 'Nicaragua',
#  'NIU': 'Niue',
#  'NLD': 'Netherlands',
#  'NOR': 'Norway',
#  'NPL': 'Nepal',
#  'NRU': 'Nauru',
#  'NZL': 'New Zealand',
#  'OMN': 'Oman',
#  'PAK': 'Pakistan',
#  'PAN': 'Panama',
#  'PER': 'Peru',
#  'PHL': 'Philippines',
#  'PLW': 'Palau',
#  'PNG': 'Papua New Guinea',
#  'POL': 'Poland',
#  'PRI': 'Puerto Rico',
#  'PRK': "Dem. People's Rep. of Korea",
#  'PRT': 'Portugal',
#  'PRY': 'Paraguay',
#  'PSE': 'Palestinian',
#  'PYF': 'French Polynesia',
#  'QAT': 'Qatar',
#  'ROU': 'Romania',
#  'RUS': 'Russian Federation',
#  'RWA': 'Rwanda',
#  'SAU': 'Saudi Arabia',
#  'SDN': 'Sudan',
#  'SEN': 'Senegal',
#  'SGP': 'Singapore',
#  'SJM': 'Svalbard and Jan Mayen',
#  'SLB': 'Solomon Islands',
#  'SLE': 'Sierra Leone',
#  'SLV': 'El Salvador',
#  'SMR': 'San Marino',
#  'SOM': 'Somalia',
#  'SPM': 'Saint-Pierre-et-Miquelon',
#  'SRB': 'Serbia and Kosovo (S/RES/1244 (1999))',
#  'SSD': 'South Sudan',
#  'STP': 'Sao Tome and Principe',
#  'SUR': 'Suriname',
#  'SVK': 'Slovakia',
#  'SVN': 'Slovenia',
#  'SWE': 'Sweden',
#  'SWZ': 'Swaziland',
#  'SYC': 'Seychelles',
#  'SYR': 'Syrian Arab Rep.',
#  'TAR': 'Tibetan',
#  'TCA': 'Turks and Caicos Islands',
#  'TCD': 'Chad',
#  'TGO': 'Togo',
#  'THA': 'Thailand',
#  'TJK': 'Tajikistan',
#  'TKM': 'Turkmenistan',
#  'TLS': 'Timor-Leste',
#  'TON': 'Tonga',
#  'TTO': 'Trinidad and Tobago',
#  'TUN': 'Tunisia',
#  'TUR': 'Turkey',
#  'TUV': 'Tuvalu',
#  'TZA': 'United Rep. of Tanzania',
#  'UGA': 'Uganda',
#  'UKR': 'Ukraine',
#  'URY': 'Uruguay',
#  'USA': 'United States of America',
#  'UZB': 'Uzbekistan',
#  'VAT': 'Holy See (the)',
#  'VCT': 'Saint Vincent and the Grenadines',
#  'VEN': 'Venezuela (Bolivarian Republic of)',
#  'VGB': 'British Virgin Islands',
#  'VNM': 'Viet Nam',
#  'VUT': 'Vanuatu',
#  'WLF': 'Wallis and Futuna Islands ',
#  'WSM': 'Samoa',
#  'YEM': 'Yemen',
#  'ZAF': 'South Africa',
#  'ZMB': 'Zambia',
#  'ZWE': 'Zimbabwe'}
